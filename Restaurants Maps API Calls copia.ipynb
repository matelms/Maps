# %% [markdown]
# Importamos las librerias necesarias para ejecutar el código

# %%
import googlemaps
import pandas as pd
import time
from datetime import datetime
from datetime import date
#import seaborn as sns
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# Realizamos la llamada a la API con los valores definidos en los pop ups

# %%
# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'
#API_KEY = open('API_KEy.txt','r').read()

# Define the Client
gmaps = googlemaps.Client(API_KEY)


#pip install easygui
import easygui
pais= easygui.enterbox(msg="Introduzca Pais")
ciudad= easygui.enterbox(msg="Introduzca Ciudad")
barrio= easygui.enterbox(msg="IntEsroduzca Zona/Barrio")
comida= easygui.enterbox(msg="Introduzca Tipo de comida")
# Prints--> Bob <class 'str'> 150 <class 'int'>

#location = (40.424941441889885, -3.6581815406804017)
#search_string = 'pizza'
#distance = 100
list = []
#dir(gmaps)

response = gmaps.places(query= pais + ',' + ciudad + ',' + barrio + ',' + comida)

#response
#response.keys()

list.extend(response.get('results'))

next_page_token = response.get('next_page_token')

while next_page_token:
    time.sleep(2)
    response = gmaps.places(query= pais + ',' + ciudad + ',' + barrio + ',' + comida,
                    page_token=next_page_token)
    list.extend(response.get('results'))
    next_page_token = response.get('next_page_token')


normalize = pd.json_normalize(list)


list
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'C/ de Francisco Silvela, 63, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.435008, 'lng': -3.675265},
#    'viewport': {'northeast': {'lat': 40.43639897989272,
#      'lng': -3.673825620107278},
#     'southwest': {'lat': 40.43369932010727, 'lng': -3.676525279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'SUMO Grill Francisco Silvela',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113797491737178075366">javy97</a>'],
#     'photo_reference': 'AW30NDyqVLkakb-6Y7VAXQVViiyZeg4BHtsP_CJp_d9eRJRbeWfNOjDZkON7YDzoOTf5_fe4T-nS1ozJjrjZII8QQpw2PwSU2WeXzpxbauZN7HP_6xOW5aKOFPYTthbsjVc7_jvslKjPrtt71dFS4mShYHzMyX1dF3KrkAsLE15_4Lfae-FP',
#     'width': 4032}],
#   'place_id': 'ChIJp6A_C8coQg0RaKdu1CSPX8I',
#   'plus_code': {'compound_code': 'C8PF+2V Madrid',
#    'global_code': '8CGRC8PF+2V'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJp6A_C8coQg0RaKdu1CSPX8I',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 3005},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Eraso, 14, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4341224, 'lng': -3.6710394},
#    'viewport': {'northeast': {'lat': 40.43541977989272,
#      'lng': -3.669794070107278},
#     'southwest': {'lat': 40.43272012010728, 'lng': -3.672493729892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Hiwakaya Sushi Fusión',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104682860952484025304">Connoisseur Troy</a>'],
#     'photo_reference': 'AW30NDzKlVtI2_7_TVjPe19sWRHJ93RIvJIKegzDei5481ye-zVlAVkASuU3_RmMDbOx2UjHWtW7cZIjwaEHLutphsnXR55shfxL8n4fuimg3OCQQMufeoiq1GdqiQkqIq4UxWiH0FKY_ZXRDEsQtSrXVcAB33Agy1jfBKRlFJepHZwyzUME',
#     'width': 1920}],
#   'place_id': 'ChIJQ0kH37coQg0RLuWWLhXatJ4',
#   'plus_code': {'compound_code': 'C8MH+JH Madrid',
#    'global_code': '8CGRC8MH+JH'},
#   'price_level': 2,
#   'rating': 4.8,
#   'reference': 'ChIJQ0kH37coQg0RLuWWLhXatJ4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 110},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C/ de Francisco Silvela, 92, 28002 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.438435, 'lng': -3.6781611},
#    'viewport': {'northeast': {'lat': 40.43975657989272,
#      'lng': -3.676855570107278},
#     'southwest': {'lat': 40.43705692010728, 'lng': -3.679555229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sushi Sano Madrid',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3226,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108101950906385336926">A Google User</a>'],
#     'photo_reference': 'AW30NDwICAEBfaESS4rBZAAlRgBKrRDrAAIMw8IVC4i52tRU8EdmzenTwOmwD-6OSU_2XYl8-6xomq36INgCnQYvXJf-76aoSF2VckPm29R3FX7RQxLLLCuo6gTdhgW0YrkidXY0SeeUem6wcoKPfHNZ0xyvqaHsekl8is18OVGfBB_jACI3',
#     'width': 3883}],
#   'place_id': 'ChIJZV8dy4EpQg0RvAyBDhGnx6c',
#   'plus_code': {'compound_code': 'C8QC+9P Madrid',
#    'global_code': '8CGRC8QC+9P'},
#   'rating': 4.9,
#   'reference': 'ChIJZV8dy4EpQg0RvAyBDhGnx6c',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 98},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Claudio Coello, 114, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4359544, 'lng': -3.6852231},
#    'viewport': {'northeast': {'lat': 40.43734412989272,
#      'lng': -3.683937020107278},
#     'southwest': {'lat': 40.43464447010728, 'lng': -3.686636679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ta-Kumi | Restaurante Japonés - Madrid',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110821853116971616276">Maria Soledad Paloma Sanchez Garcia</a>'],
#     'photo_reference': 'AW30NDwC75ixKLQCczXR295jh-A9FpSU9itQSVSOVQCh_POKIFEJ1M39Vz9_TodJpyUN5rnOl137tEc8zFQ-_hEy-VxK24MLIVd2lHI8wJ_ZRndN8UDhmQrYbPNiNHVuuBjsFi3KkM3JHZjj23oIt5AQd7ZBYi-8Bq6iV9_6ml1vhYNKOa1S',
#     'width': 4032}],
#   'place_id': 'ChIJi_0REaQpQg0RR9BZOC8xqYo',
#   'plus_code': {'compound_code': 'C8P7+9W Madrid',
#    'global_code': '8CGRC8P7+9W'},
#   'rating': 5,
#   'reference': 'ChIJi_0REaQpQg0RR9BZOC8xqYo',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 15},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Azcona, 4, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4324565, 'lng': -3.6718943},
#    'viewport': {'northeast': {'lat': 40.43395542989271,
#      'lng': -3.670668520107278},
#     'southwest': {'lat': 40.43125577010727, 'lng': -3.673368179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sushi Yummy',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1836,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111782604025568876630">marc carrasco</a>'],
#     'photo_reference': 'AW30NDxvRECGGiXyNq_vhO0xbqDt6PSwMxX-jSbp2TqDF1WHfK03eoXkp1Zcm3BlUvWyfEFM3YZIYw3DnIRilBfLakgmfugp_5VAXRVI0AfqUSfgYQKM6xX1-8HFrzhiBLrfixhN8oVVoj7Z1y6N0pfZ1HN4F2uUTPohvn18L07aG0L_IU37',
#     'width': 3264}],
#   'place_id': 'ChIJY2V3i7coQg0RejYVg_z_HBk',
#   'plus_code': {'compound_code': 'C8MH+44 Madrid',
#    'global_code': '8CGRC8MH+44'},
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'ChIJY2V3i7coQg0RejYVg_z_HBk',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 179},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Ferrer del Río, 27, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4352758, 'lng': -3.671132},
#    'viewport': {'northeast': {'lat': 40.43659347989272,
#      'lng': -3.669776070107278},
#     'southwest': {'lat': 40.43389382010728, 'lng': -3.672475729892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Tokyo Garden',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 6936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104427262179223774982">Simon Garcia</a>'],
#     'photo_reference': 'AW30NDzrSFAEZ0cmpHxntX-BAAkZw0TTdV0TecjXTNAMh5f2MsIpCTTCCSQdxasXLm6ldNY8_qqXjhMwKBx8SfsqqBOUTGalFy1NaJEHq_j2H7aKzEgI21VJyPqc7EHwr6_Iob9irPPI0ynBn0w6T-zmxwppYcQNpUCNLrRnbAdqScurSMc6',
#     'width': 9248}],
#   'place_id': 'ChIJy38QPsgoQg0RaLYYUcSAY1Y',
#   'plus_code': {'compound_code': 'C8PH+4G Madrid',
#    'global_code': '8CGRC8PH+4G'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJy38QPsgoQg0RaLYYUcSAY1Y',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 201},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Pilar de Zaragoza, 95, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4383684, 'lng': -3.6748356},
#    'viewport': {'northeast': {'lat': 40.43984657989272,
#      'lng': -3.673600120107277},
#     'southwest': {'lat': 40.43714692010728, 'lng': -3.676299779892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'WAGARA Restaurante Japonés',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3468,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103310441960576498404">A Google User</a>'],
#     'photo_reference': 'AW30NDzFzYqBVprO9zzbtO7BlYq-j8euitlPHMxOglYPZ6oihmFyWwzdF04ZqC_XFI4fJVdeUXYuv2ydVIN_H6GCDf5kAsSS3cXj7kzwzPyUppeIfeCs813rtvx6w2lEqyNRy_OkNeE4_Bz6EKUwQkeBk3Zoi_WzIZ4CJwMH6ErRmCzHA_Ee',
#     'width': 4624}],
#   'place_id': 'ChIJZzTCMtApQg0RmiKJCh-Mbn4',
#   'plus_code': {'compound_code': 'C8QG+83 Madrid',
#    'global_code': '8CGRC8QG+83'},
#   'rating': 4.9,
#   'reference': 'ChIJZzTCMtApQg0RmiKJCh-Mbn4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 252},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral Oraá, 49, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4360289, 'lng': -3.6799847},
#    'viewport': {'northeast': {'lat': 40.43738372989272,
#      'lng': -3.678636720107279},
#     'southwest': {'lat': 40.43468407010728, 'lng': -3.681336379892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ramen Kagura Avenida de América',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113752504053994514943">A Google User</a>'],
#     'photo_reference': 'AW30NDxnOnVQQ9INCuGlAOvli30KbFQUTay1bS-wHRGlIVNEptr9HyR7jf9tOfruyH9Q9MCnfMV9KaHGXVR0rkYt3YBDrHsZ32ZKhvg07GpDjhz1JwaGHm2cYqpfgW3SWjIF3sni-d49EibqnJ-dNcxAKWuMhQwZCEsChaZqLdVfz1adLHa9',
#     'width': 1440}],
#   'place_id': 'ChIJQXVPKaIpQg0RSAi0VmO0gLc',
#   'plus_code': {'compound_code': 'C8PC+C2 Madrid',
#    'global_code': '8CGRC8PC+C2'},
#   'rating': 4.6,
#   'reference': 'ChIJQXVPKaIpQg0RSAi0VmO0gLc',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 561},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Príncipe de Vergara, 78, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4351449, 'lng': -3.6790985},
#    'viewport': {'northeast': {'lat': 40.43649897989272,
#      'lng': -3.677834770107279},
#     'southwest': {'lat': 40.43379932010728, 'lng': -3.680534429892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Lamonarracha Barrio de Salamanca | Restaurante japonés fusión',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 6624,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107213702010622257287">A Google User</a>'],
#     'photo_reference': 'AW30NDwsa172IHTZTKJqhSYWdV8DgfqeMOYAZOZOxOch9FgD-oCP436h1Gzm0ZashtZ_Un_6ZAQt0UkrOwAZJbEUYH-dgoV-D0tgi4rAdWMV5I8I8j_Vb4yhZiaffMIB3vZjeTppAEAzfKgyu3RXDkDVEAkCJp1-FhWEhf4zm5KLm7p_3Qxn',
#     'width': 4416}],
#   'place_id': 'ChIJcx7UO_0pQg0RVhJcLb6Sbnk',
#   'plus_code': {'compound_code': 'C8PC+39 Madrid',
#    'global_code': '8CGRC8PC+39'},
#   'rating': 4.6,
#   'reference': 'ChIJcx7UO_0pQg0RVhJcLb6Sbnk',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 143},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Padilla, 58, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4310511, 'lng': -3.67715},
#    'viewport': {'northeast': {'lat': 40.43250832989272,
#      'lng': -3.675792220107278},
#     'southwest': {'lat': 40.42980867010728, 'lng': -3.678491879892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Casa Sushi',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105675026256719084439">CASA SUSHI</a>'],
#     'photo_reference': 'AW30NDxv7ZyP0wSSc_IJcjUcm6vTgYfANgzDa62NQ9hAjqjlVznFXmJFfqu2XLLhmOTzpbj_HHVHjX3lYhvDkHYZzmZzRrgKACZ9MsMUpgmG0NSxGTEsk6Ij6Mj0rGxh3Lo03B8brlcWjJuCmUmRyWmK_KBPgIAM7WDEkujB6fxKxJWAFXwQ',
#     'width': 3500}],
#   'place_id': 'ChIJMdEFVcgoQg0RxwJRhxyBHZ8',
#   'plus_code': {'compound_code': 'C8JF+C4 Madrid',
#    'global_code': '8CGRC8JF+C4'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJMdEFVcgoQg0RxwJRhxyBHZ8',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 366},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Marqués de Villamejor, 8, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4311374, 'lng': -3.6874396},
#    'viewport': {'northeast': {'lat': 40.43249967989271,
#      'lng': -3.686102870107279},
#     'southwest': {'lat': 40.42980002010727, 'lng': -3.688802529892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'FUKU restaurante japonés',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1251,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105125855098682753689">A Google User</a>'],
#     'photo_reference': 'AW30NDxQGJECxl3vhuDaNQtC0J1K44enAOt_f8NzNYDJl6-vTYOVisy3moIkyqAb1mi2CbVlCPUlKFhLX_y9IJCIZ_jTo2DfldTS2bnZMvQ9zmq6YgrvsU9Dvg0c6UUNzUvlkxU8-ZukooIYf0fp4iMknmiPoJhHRPXvY7PAAPkDj5mKL2KX',
#     'width': 1440}],
#   'place_id': 'ChIJEWwvfpQoQg0R000wGs5dBBY',
#   'plus_code': {'compound_code': 'C8J7+C2 Madrid',
#    'global_code': '8CGRC8J7+C2'},
#   'rating': 4.3,
#   'reference': 'ChIJEWwvfpQoQg0R000wGs5dBBY',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 958},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Marqués de la Ensenada, 16, 28004 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4253974, 'lng': -3.6919884},
#    'viewport': {'northeast': {'lat': 40.42668462989272,
#      'lng': -3.690430820107277},
#     'southwest': {'lat': 40.42398497010728, 'lng': -3.693130479892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Peyote San',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2358,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102279437210728176754">A Google User</a>'],
#     'photo_reference': 'AW30NDyXAcQdc95bWlcP5DdhndEq7s6-yA_dL3CNDWCqrjEaI9s8N7HK4ac8Kco3wvZPZooUwDtnFsG-k3sWRwNKm8EV_ODmomzLg-V3LysXjF_U2NlRu37rPOGo-3-wx6XpdXEtE8dLqo_k4BbOiYbpHZnzx_0Ef1aWtr-W9zp7_c0rEUlC',
#     'width': 4199}],
#   'place_id': 'ChIJ01K8OpAoQg0R7DrdLiWcyu0',
#   'plus_code': {'compound_code': 'C8G5+56 Madrid',
#    'global_code': '8CGRC8G5+56'},
#   'price_level': 3,
#   'rating': 3.8,
#   'reference': 'ChIJ01K8OpAoQg0R7DrdLiWcyu0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1421},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 9, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.43518050000001, 'lng': -3.6845043},
#    'viewport': {'northeast': {'lat': 40.43651237989273,
#      'lng': -3.683115420107278},
#     'southwest': {'lat': 40.43381272010728, 'lng': -3.685815079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante ASADOR DE ARANDA',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110815173549276620297">El Asador de Aranda</a>'],
#     'photo_reference': 'AW30NDx5T5aZ1Arx3JzSVSlP94G1aarhW1QXsiOFf4iFyDbSvSCjkWgOi0iOyJUPGbeXnDB0kJRncsT9vEHJzG40cT_3jU3GKqeRF34W-5NVAfcjlPNxEHQqOQOtkM9MhCGPzCt0xTk0euHldyNxEN3j461OEFDnr0F5oxG1rne6hRRVKdRN',
#     'width': 2000}],
#   'place_id': 'ChIJpzmi5-ooQg0Re1HNYe1kh2g',
#   'plus_code': {'compound_code': 'C8P8+35 Madrid',
#    'global_code': '8CGRC8P8+35'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJpzmi5-ooQg0Re1HNYe1kh2g',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 884},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Padre Jesús Ordóñez, 12, 28002 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4412147, 'lng': -3.6773906},
#    'viewport': {'northeast': {'lat': 40.44254082989272,
#      'lng': -3.676091770107279},
#     'southwest': {'lat': 40.43984117010728, 'lng': -3.678791429892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'YAMATE',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106332354730684289788">A Google User</a>'],
#     'photo_reference': 'AW30NDzBMcdQqvSESYmmGhXVj89sZ5t1AJpjyCbZ3kVl05GI6G2wHIwFT3AJfXfFZkPgJqQLdn5ZSd4RB8PI9WDCdFsjxX4CNfmgjFQXLQ18WcIJljo09gERujNAbioI2CFqfCvRxXXXYOtvOBnmMmKoL5M85GI28-h1WRoKpjAgQg15csPK',
#     'width': 1920}],
#   'place_id': 'ChIJG1mmVkUpQg0Rr50nRIicBQE',
#   'plus_code': {'compound_code': 'C8RF+F2 Madrid',
#    'global_code': '8CGRC8RF+F2'},
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'ChIJG1mmVkUpQg0Rr50nRIicBQE',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 848},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral. Pardiñas, 70, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4305501, 'lng': -3.6780569},
#    'viewport': {'northeast': {'lat': 40.43190272989272,
#      'lng': -3.676772120107278},
#     'southwest': {'lat': 40.42920307010728, 'lng': -3.679471779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Kippu',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 809,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106305969113924126118">A Google User</a>'],
#     'photo_reference': 'AW30NDyXtVCKGFRvv1_wnhpEJV1BjVM1-EpHAHSVoQ1cWagsW-nVwVpbZMofPRIH7FwmlhhQqzWP7rWrV101JphIb0Oae4n_aZ7T5SrcZqLtje8svWZSSriVGn4oAuRxWWgKGSjvwr-VqPcnnRj-lJ-INDbmkiF_g9SljIl_BZnXCr9kXG2r',
#     'width': 1440}],
#   'place_id': 'ChIJkeLSuEIpQg0RVky8VYqbaE0',
#   'plus_code': {'compound_code': 'C8JC+6Q Madrid',
#    'global_code': '8CGRC8JC+6Q'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJkeLSuEIpQg0RVky8VYqbaE0',
#   'types': ['restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1374},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Cl. de Ayala, 71, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.42754679999999, 'lng': -3.6761672},
#    'viewport': {'northeast': {'lat': 40.42883042989273,
#      'lng': -3.674822920107277},
#     'southwest': {'lat': 40.42613077010729, 'lng': -3.677522579892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': '100 Por 100 Japones S.L.',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJVd3_ErwoQg0R2mqLZELeEy4',
#   'plus_code': {'compound_code': 'C8HF+3G Madrid',
#    'global_code': '8CGRC8HF+3G'},
#   'rating': 0,
#   'reference': 'ChIJVd3_ErwoQg0R2mqLZELeEy4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 30, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.434725, 'lng': -3.681753},
#    'viewport': {'northeast': {'lat': 40.43614492989272,
#      'lng': -3.680396670107278},
#     'southwest': {'lat': 40.43344527010728, 'lng': -3.683096329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Rodilla',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109494502864662967417">Rodilla</a>'],
#     'photo_reference': 'AW30NDx0rOo97XmHVmpuuDPIDWgwjdn_oY3TZYPhtpEHFDHnywW48MKrXMExZUuEBlZ3Tggw-bz3R3J4PHGd5xCvYk_wr89TFJr0vVeNJV_loQVHCdw-jH8CwlhG0BamNpXB2yN6mvm5x-D7RDBrvgGqlbTXFSE01WXQRsLRamVZFIQ7uFL8',
#     'width': 1080}],
#   'place_id': 'ChIJYUbxEMAoQg0R2TaRfb_5Q3k',
#   'plus_code': {'compound_code': 'C8M9+V7 Madrid',
#    'global_code': '8CGRC8M9+V7'},
#   'price_level': 1,
#   'rating': 3.8,
#   'reference': 'ChIJYUbxEMAoQg0R2TaRfb_5Q3k',
#   'types': ['restaurant',
#    'cafe',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 594},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Padilla, 5, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4317755, 'lng': -3.6858467},
#    'viewport': {'northeast': {'lat': 40.43307272989272,
#      'lng': -3.684500020107278},
#     'southwest': {'lat': 40.43037307010728, 'lng': -3.687199679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Tora Restaurante',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3631,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110321468975244126623">A Google User</a>'],
#     'photo_reference': 'AW30NDwOqM9Iqh32eLKU_N3TNh2qdIohOYbZTqjTPw-dPsg5U44lQTw7yfmuDuTsxnGk_MhQcEqHgV40poNycgdtxk7T3-lv1RXXDTS_LR8KmnWTGC7iKwVS09mJjp9TXJk8ORoNeYhls2Gx0BYDKX_wBBNiWbs3_goM8SjC1QKikBfcIqDx',
#     'width': 5446}],
#   'place_id': 'ChIJk_4jTtEpQg0ReZFmTRVFW6A',
#   'plus_code': {'compound_code': 'C8J7+PM Madrid',
#    'global_code': '8CGRC8J7+PM'},
#   'rating': 4.9,
#   'reference': 'ChIJk_4jTtEpQg0ReZFmTRVFW6A',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 44},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Don Ramón de la Cruz, 49, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4289801, 'lng': -3.6791357},
#    'viewport': {'northeast': {'lat': 40.43028757989273,
#      'lng': -3.677761420107278},
#     'southwest': {'lat': 40.42758792010728, 'lng': -3.680461079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Txatei',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2736,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116832657026287348103">Vasile Vancea</a>'],
#     'photo_reference': 'AW30NDxDotQyGj6r9ZMYPW02GLR1r8gIhRemtZrEJ5nOTS7xke58tI3RtrbpawvXRVd2Dj2YzEWuijQRt0BsiB1S3_b3crEJUKQybEfqXsSBLVpvlEeQcyxf5tCL8k3PbHhWjqPhSI7-kSKuG73_IvPdAtTDH6lRDHjQKv_maE4K8G11gBUy',
#     'width': 3648}],
#   'place_id': 'ChIJ11gktLwoQg0Rn4fuVLae6KI',
#   'plus_code': {'compound_code': 'C8HC+H8 Madrid',
#    'global_code': '8CGRC8HC+H8'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJ11gktLwoQg0Rn4fuVLae6KI',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 384},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Cl. de Ayala, 67, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4275083, 'lng': -3.6765193},
#    'viewport': {'northeast': {'lat': 40.42878012989271,
#      'lng': -3.675202270107278},
#     'southwest': {'lat': 40.42608047010727, 'lng': -3.677901929892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ayala Japón',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2736,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115963075328876465820">Ayala Japon Restaurante</a>'],
#     'photo_reference': 'AW30NDypXCk8yvWG76LgAQDyxx2V-U895j0YZdcb2J4cb47u5BfVUbvVfR4Ifh4Es1Vp-npRaDPF_26w8z7bQYFeh7t6vmHYcEhmgC1zghOOMPeUdp_aS27NPNuWjRU6MX3NMsK3tlbDnNysLoItaj-kDOkfWjGzPDtBKw38ALw3n0uMeVCW',
#     'width': 3648}],
#   'place_id': 'ChIJx734kbsoQg0RwbIIdoJ9HX8',
#   'plus_code': {'compound_code': 'C8HF+29 Madrid',
#    'global_code': '8CGRC8HF+29'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJx734kbsoQg0RwbIIdoJ9HX8',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 700},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Claudio Coello, 41, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4257681, 'lng': -3.6866895},
#    'viewport': {'northeast': {'lat': 40.42711052989272,
#      'lng': -3.685254020107277},
#     'southwest': {'lat': 40.42441087010727, 'lng': -3.687953679892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Shinatora Ya',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 901,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104162522721223728773">A Google User</a>'],
#     'photo_reference': 'AW30NDz2UOrnmRckHQKKY4SQXzbJTq7h2L192Qa2Cxxe3cn7dyQA1IDo5CiJWRO88trxZ5S_ie0F60DCYRqmrtQCcpXRXB-Tr3V3wVdwAY2Vc_mK8zpk2mpeRfR2OsgusoxLGU4dJgKsDsNw9CzfvysWW4BvMjPLiZ8_SE5_1n1V7phWpeVo',
#     'width': 1600}],
#   'place_id': 'ChIJo8ngI5coQg0RWf6TC_Hv0mA',
#   'plus_code': {'compound_code': 'C8G7+88 Madrid',
#    'global_code': '8CGRC8G7+88'},
#   'rating': 4.5,
#   'reference': 'ChIJo8ngI5coQg0RWf6TC_Hv0mA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 404},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Ferrer del Río, 7, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4342495, 'lng': -3.6724078},
#    'viewport': {'northeast': {'lat': 40.43557477989272,
#      'lng': -3.671027070107279},
#     'southwest': {'lat': 40.43287512010727, 'lng': -3.673726729892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'GAMAN de Luis Arévalo',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3764,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115375135432781264107">A Google User</a>'],
#     'photo_reference': 'AW30NDx89JTRkX-atnRumsOYxo_D1-_NfQAm2JVuIocY7LCB3mvS4Au4icHAGZW14sKYEdOMiMlXvc_02G-63gWEthAlBLHWlsED2YiEt7vqQrxrQZdBUJKmzSyRBC3OPKArtgRt4e9B2c4ghCj3-JZ5h0-TgMlH3uN2NCXyztA756X0gzyD',
#     'width': 5639}],
#   'place_id': 'ChIJ69eaLx0pQg0RNCrxaw9VXXc',
#   'plus_code': {'compound_code': 'C8MH+M2 Madrid',
#    'global_code': '8CGRC8MH+M2'},
#   'rating': 4.4,
#   'reference': 'ChIJ69eaLx0pQg0RNCrxaw9VXXc',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 340},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 7, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4352025, 'lng': -3.6848658},
#    'viewport': {'northeast': {'lat': 40.43643997989273,
#      'lng': -3.683503970107277},
#     'southwest': {'lat': 40.43374032010728, 'lng': -3.686203629892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sugarcane Restaurant & Wetbar',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 635,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115629098592342812910">Sugarcane Restaurant &amp; Wetbar</a>'],
#     'photo_reference': 'AW30NDxJ9qdL-GSC2Fp1YMRYVkQ86-Jm_LC_eYIEyP5DJK1VmXzbjXw8qeA-DfGLYcL69pXrr02-FRIWYXzrwl_41nLyIVoBrZMc2OhB88XqJaxkiuGVN1KKOtGGbVcSE24XRQJchuqQMbj_qI1lGQA8f8VXaSrOkSaTiqoabj4IK64vO9Ow',
#     'width': 960}],
#   'place_id': 'ChIJdZHK4OooQg0Rzj-FTOf5jp4',
#   'plus_code': {'compound_code': 'C8P8+33 Madrid',
#    'global_code': '8CGRC8P8+33'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJdZHK4OooQg0Rzj-FTOf5jp4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 831},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Juan Bravo, 66, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4321568, 'lng': -3.6731312},
#    'viewport': {'northeast': {'lat': 40.43356892989273,
#      'lng': -3.671750170107277},
#     'southwest': {'lat': 40.43086927010728, 'lng': -3.674449829892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'SUMO Juan Bravo',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2250,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106028714476232335594">charlierayden</a>'],
#     'photo_reference': 'AW30NDy5N7EtuXIUBuLqNbXbzvy5HWzj8kHChj5WYRxcxmTA5PH12bUXucMwNiJ4iNqugXhznAeLD1bh7dF9W9-GDGe53-TwNNUQOWicKZTe360ZGdtm6iqPFK4KdGnh_ccqIozS1Ruto5QORhXqJLUdms_ZQ0UXgP4RYO6cYpV4LLas6Nxm',
#     'width': 4000}],
#   'place_id': 'ChIJjUp3WqwpQg0Rb5_ZeqAlyf0',
#   'plus_code': {'compound_code': 'C8JG+VP Madrid',
#    'global_code': '8CGRC8JG+VP'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJjUp3WqwpQg0Rb5_ZeqAlyf0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1534},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral. Pardiñas, 43, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4292544, 'lng': -3.678382399999999},
#    'viewport': {'northeast': {'lat': 40.43061667989272,
#      'lng': -3.676988070107277},
#     'southwest': {'lat': 40.42791702010728, 'lng': -3.679687729892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Japonés Inari',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3929,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112981284840912991129">A Google User</a>'],
#     'photo_reference': 'AW30NDySjurIvyPUOQr5CaGMhQf_zdoO8NSZbCfz-358WZriQmeLgJ08fDgeDdyBZ05AhznjDcDyg41Ar_v_no0DgKMWeclmHIuHeY91Gzou5v3CqKIzX7Xm1Jw5aNWUQolSIGqqrJ5GGy52E21iV3I3uP2Kx3wBBM2qHYfGkXfNtyetS05G',
#     'width': 5893}],
#   'place_id': 'ChIJ8wQupL4oQg0RnQbsc2t4F4c',
#   'plus_code': {'compound_code': 'C8HC+PJ Madrid',
#    'global_code': '8CGRC8HC+PJ'},
#   'price_level': 3,
#   'rating': 4.5,
#   'reference': 'ChIJ8wQupL4oQg0RnQbsc2t4F4c',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 475},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 22, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4346568, 'lng': -3.6827863},
#    'viewport': {'northeast': {'lat': 40.43613697989272,
#      'lng': -3.681425020107278},
#     'southwest': {'lat': 40.43343732010727, 'lng': -3.684124679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': 'La Ocha',
#   'opening_hours': {'open_now': True},
#   'place_id': 'ChIJN5owp-ooQg0Rg23clZwaY4w',
#   'plus_code': {'compound_code': 'C8M8+VV Madrid',
#    'global_code': '8CGRC8M8+VV'},
#   'rating': 4,
#   'reference': 'ChIJN5owp-ooQg0Rg23clZwaY4w',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º de la Castellana, 45, 28046 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.435713, 'lng': -3.689798799999999},
#    'viewport': {'northeast': {'lat': 40.43692657989271,
#      'lng': -3.688268970107278},
#     'southwest': {'lat': 40.43422692010727, 'lng': -3.690968629892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Miyama',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106342488635982767548">Shinji</a>'],
#     'photo_reference': 'AW30NDwt5aS7yXRpKBaH-yORzjsg1v91cNIiiah3qYp30O7cMbiJRM7AMAUm8_7TJ-9nfWhWygm_AwF62oYZ-Ad-CBdiraIXkb1RkfOsJjP8yLV_JV8jZezNPz3-Quc6_BbmEXuEunBRqn_nzRbYQWyKQb_ZxYa7iUpoAvEYV1pYYzcqtXbx',
#     'width': 4032}],
#   'place_id': 'ChIJP3Jf-uwoQg0Rh5coctpDKto',
#   'plus_code': {'compound_code': 'C8P6+73 Madrid',
#    'global_code': '8CGRC8P6+73'},
#   'price_level': 3,
#   'rating': 4.6,
#   'reference': 'ChIJP3Jf-uwoQg0Rh5coctpDKto',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1016},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Lagasca, 67, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4288395, 'lng': -3.6851044},
#    'viewport': {'northeast': {'lat': 40.43013837989271,
#      'lng': -3.683688920107278},
#     'southwest': {'lat': 40.42743872010727, 'lng': -3.686388579892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sushi Bar Tottori (Lagasca)',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1730,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117962330198200702483">A Google User</a>'],
#     'photo_reference': 'AW30NDyMFbVkAc7pSNn74y-MrO-c_XnQEoQbXBXAPNOkqm1m05MI8QzcuueaOClf1qnzebTwk9XCSxlbkl0eBIKPBmb28XOhwvHNerGJb0wVgnr7QKv3EV4mjHIBbZb7bbFOMMEeR-PL9SKk8xiUph3lMpVPrPKmiNzmSr6BDBBC8uQCdYyq',
#     'width': 2592}],
#   'place_id': 'ChIJL736qtgpQg0RB0f7P86q90Q',
#   'plus_code': {'compound_code': 'C8H7+GX Madrid',
#    'global_code': '8CGRC8H7+GX'},
#   'rating': 4.3,
#   'reference': 'ChIJL736qtgpQg0RB0f7P86q90Q',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 242},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 60, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4344663, 'lng': -3.6767462},
#    'viewport': {'northeast': {'lat': 40.43589082989272,
#      'lng': -3.675370120107278},
#     'southwest': {'lat': 40.43319117010727, 'lng': -3.678069779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': 'DeDIEGO Restaurante (Diego de León 60)',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 810,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116685939333044399676">Barra de pintxos</a>'],
#     'photo_reference': 'AW30NDyvbvoOAQprI9oqzUwPS2fW9Gg7rr8lSPpZVr9oPfqoC1YDOtmiZTGtzXnMu2BG4l9ryrQp0wQiAReiJN304ta371lZlGc4cXFTgo-Bon5Znu1ErBJufp5rJssGvVEE-ZDhooSnlUQyyIFU6jMljcgWCJbKSlj04tIcyo_drjN2wfIV',
#     'width': 1440}],
#   'place_id': 'ChIJCUg1WscoQg0RJ8zDe483c8Q',
#   'plus_code': {'compound_code': 'C8MF+Q8 Madrid',
#    'global_code': '8CGRC8MF+Q8'},
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'ChIJCUg1WscoQg0RJ8zDe483c8Q',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 884},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Padilla, 4, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4315886, 'lng': -3.6863311},
#    'viewport': {'northeast': {'lat': 40.43298747989272,
#      'lng': -3.684978320107279},
#     'southwest': {'lat': 40.43028782010728, 'lng': -3.687677979892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Miss Sushi Serrano',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115659449516446237999">Daniel velarde ruiz</a>'],
#     'photo_reference': 'AW30NDzC2CcJlg6YCGlsJa1IVH8UZjLXfzxfQxyCg1pbh3Ezrw4Ef79KGq_uvHv59umWXsna2nGLrzaVUCCad7wNxIqjBN97FGgo-B1duhzkZSbHBn7KFLMBRPFyvUrq-EEhiOvpBL_UW_XpXmNeTGahTIqFjfNQlz5HcBOkGBehnaUOeLff',
#     'width': 3456}],
#   'place_id': 'ChIJCUhA85QoQg0RfBbjxM7oibQ',
#   'plus_code': {'compound_code': 'C8J7+JF Madrid',
#    'global_code': '8CGRC8J7+JF'},
#   'price_level': 2,
#   'rating': 3.9,
#   'reference': 'ChIJCUhA85QoQg0RfBbjxM7oibQ',
#   'types': ['meal_takeaway',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 1113},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 60, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4344663, 'lng': -3.6767451},
#    'viewport': {'northeast': {'lat': 40.43589077989272,
#      'lng': -3.675369570107278},
#     'southwest': {'lat': 40.43319112010728, 'lng': -3.678069229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Empanadas Malvón',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2333,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113280804692130585935">A Google User</a>'],
#     'photo_reference': 'AW30NDwqEHV1bBO9rOTVLwwIiGqE5GKJONEZgYTXvVCYPmQZpyPrbEpZJ0k_tnyiaWSD97a_oWkYjlZpc7sCoi3jQ_ADwqsoIrBBbVm_buLcpr0BPQRE_VueUo6zTiyC3WYGtKMonZ2CwZXZNrB5aTefmATXQSVyR2N1W4_aFs8N5EFAvODH',
#     'width': 3500}],
#   'place_id': 'ChIJFTvPCKopQg0R2dHGn7jA_Z4',
#   'plus_code': {'compound_code': 'C8MF+Q8 Madrid',
#    'global_code': '8CGRC8MF+Q8'},
#   'price_level': 1,
#   'rating': 4.9,
#   'reference': 'ChIJFTvPCKopQg0R2dHGn7jA_Z4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 417},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. del Descubridor Diego de Ordás, 2, 28003 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4409775, 'lng': -3.700426499999999},
#    'viewport': {'northeast': {'lat': 40.44228042989273,
#      'lng': -3.699057420107279},
#     'southwest': {'lat': 40.43958077010728, 'lng': -3.701757079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Torikey',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109264166542893659076">A Google User</a>'],
#     'photo_reference': 'AW30NDyZEmJuuljN9NDtH3xxyveBVOz8MVCl6FluG8DQ99mrc4Uw1VF7bu20q6jCm-F96aaQRqTysc8EHAEMkX-ym-7GVhLAkKKLooxScV7P0EaouAyZnkdxP5t8c0zuaLq3mnkn2bBh38dBE9tx8OmGq8QJyYjXPzIXXctoefiWqbzbqeP0',
#     'width': 3024}],
#   'place_id': 'ChIJZcO2qvcoQg0RqRY6Qd1ZKo4',
#   'plus_code': {'compound_code': 'C7RX+9R Madrid',
#    'global_code': '8CGRC7RX+9R'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJZcO2qvcoQg0RqRY6Qd1ZKo4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1191},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 63, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4347986, 'lng': -3.6756006},
#    'viewport': {'northeast': {'lat': 40.43602882989272,
#      'lng': -3.674255420107277},
#     'southwest': {'lat': 40.43332917010728, 'lng': -3.676955079892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Hermanos Ordás',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 5312,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103860804986367931915">Carlos Olmo Bosco</a>'],
#     'photo_reference': 'AW30NDzGHh5rPMap0-82E4y5m_6tra6_J9JlJP-gKO8aiHMRlzaC2ktRawElrGlDae7hk_WZAQe4LmfDh4aOIkKcWwhMC8QO_QA1Dz652dimufKC4UACoiw8VUGSjWMmI7ng-x3giyAzDqjCg3b370zzHsXw080b8piB4YZIsfVirKWsqkc1',
#     'width': 2988}],
#   'place_id': 'ChIJh8heZccoQg0RA2QBcF7VpIg',
#   'plus_code': {'compound_code': 'C8MF+WQ Madrid',
#    'global_code': '8CGRC8MF+WQ'},
#   'price_level': 1,
#   'rating': 4.5,
#   'reference': 'ChIJh8heZccoQg0RA2QBcF7VpIg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1217},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Velázquez, 136, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4398018, 'lng': -3.6826258},
#    'viewport': {'northeast': {'lat': 40.44116942989272,
#      'lng': -3.681389520107278},
#     'southwest': {'lat': 40.43846977010728, 'lng': -3.684089179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ikigai Velazquez',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3012,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115707323829148311643">A Google User</a>'],
#     'photo_reference': 'AW30NDwb_AKIZlf8XXMfplyJhhqcvx9Ew2_IjieLEIro-sRQxxlGbHo5MBXvnPqGV29BikVpD72HxEmKNOZbdz3R77H8Djz9E1kIi1T-Dkv4-SsbXSzxrawXFk3S2uqDOZwIQFxX6yaFQjYrfH3HXQVy8N-PeDgBXnPK2_KSJ68b2LyuwI5f',
#     'width': 4054}],
#   'place_id': 'ChIJV_kqIwApQg0R50e9nTvsWq8',
#   'plus_code': {'compound_code': 'C8Q8+WX Madrid',
#    'global_code': '8CGRC8Q8+WX'},
#   'rating': 4.1,
#   'reference': 'ChIJV_kqIwApQg0R50e9nTvsWq8',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 71},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Cl. de Ayala, 87, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4273692, 'lng': -3.6734961},
#    'viewport': {'northeast': {'lat': 40.42864412989272,
#      'lng': -3.672211270107278},
#     'southwest': {'lat': 40.42594447010728, 'lng': -3.674910929892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Go! Sushing Barrio Salamanca',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2848,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113289726037615293457">A Google User</a>'],
#     'photo_reference': 'AW30NDy--X_DlIJAu6bhnFEp4zmyUdUFiDRjSwWHzwoq7ArAlLtm84xkQOapJ-_0Xc4ZK7q9WVt3pF4yUp90eG3_m8Be0zpUoy5rTe_EpHQU59wBrwmtHVbdnJNTorB5LSDg3hsSmr_LNAbMcU6dSkP-xb1BPutzOV_me8SfaycDFq98DI6J',
#     'width': 4288}],
#   'place_id': 'ChIJr7WtP7ooQg0R5kV4PCQhc30',
#   'plus_code': {'compound_code': 'C8GG+WJ Madrid',
#    'global_code': '8CGRC8GG+WJ'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJr7WtP7ooQg0R5kV4PCQhc30',
#   'types': ['meal_takeaway',
#    'meal_delivery',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 290},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 58, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4344696, 'lng': -3.6770871},
#    'viewport': {'northeast': {'lat': 40.43591042989272,
#      'lng': -3.675729970107278},
#     'southwest': {'lat': 40.43321077010727, 'lng': -3.678429629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': 'Daser',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 7179,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114057549960912934465">Manuel Blanco</a>'],
#     'photo_reference': 'AW30NDy05lLocZqfFN8aWj9XE9xC4iC6QOnHtT5toK1FOz76dBIMg-bdI62eHBAZPwXH2mnAcuN7bv3olS2ySk_HgM67oUSCL5kz2YjTCa1jhVH8IlIQhiBjam_gRxPfFsmNtMXUBWNPkVhuGrOHbwEcMINIJ1-QetDvXPZPGhYo3IQcmbFC',
#     'width': 6907}],
#   'place_id': 'ChIJD-ZOUMcoQg0RyahLDFNKNWQ',
#   'plus_code': {'compound_code': 'C8MF+Q5 Madrid',
#    'global_code': '8CGRC8MF+Q5'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJD-ZOUMcoQg0RyahLDFNKNWQ',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 717},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Cl. de Ayala, 65, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4275125, 'lng': -3.6767712},
#    'viewport': {'northeast': {'lat': 40.42878827989272,
#      'lng': -3.675427570107278},
#     'southwest': {'lat': 40.42608862010727, 'lng': -3.678127229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ramen Shifu',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117492152609964012409">A Google User</a>'],
# ...
#     'width': 4640}],
#   'place_id': 'ChIJJ5fkt2YpQg0Rb7L8a94f0XI',
#   'plus_code': {'compound_code': 'C7HW+PM Madrid',
#    'global_code': '8CGRC7HW+PM'},
#   'price_level': 2,
#   'rating': 4.7,
#   'reference': 'ChIJJ5fkt2YpQg0Rb7L8a94f0XI',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1099},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º de la Castellana, 2, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4263874, 'lng': -3.6894297},
#    'viewport': {'northeast': {'lat': 40.42771822989272,
#      'lng': -3.688245420107278},
#     'southwest': {'lat': 40.42501857010728, 'lng': -3.690945079892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Zuma Madrid',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 5000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115253493302688233605">A Google User</a>'],
#     'photo_reference': 'AW30NDxeHPDGjjllFAPNhTYY_Zma2U1tViCgMjTlfVuOhrVNh6y93xg7elVSH1hyLeR0jcplS7vV7Yi0cWFrmmH7VqmKauW1v8JptF4haVA_B8zFe-E3A63Q2cq-wkloNCwpOhnc5HZIxJF1CuhrGAMkPcJaThbHvmHdojvlza8RuYJ-7-8x',
#     'width': 3333}],
#   'place_id': 'ChIJ2ezaWRUpQg0RtSG-7tbzfZw',
#   'plus_code': {'compound_code': 'C8G6+H6 Madrid',
#    'global_code': '8CGRC8G6+H6'},
#   'rating': 4.3,
#   'reference': 'ChIJ2ezaWRUpQg0RtSG-7tbzfZw',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 419},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º del Marqués de Zafra, 24, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4259314, 'lng': -3.6653441},
#    'viewport': {'northeast': {'lat': 40.42733177989271,
#      'lng': -3.664053120107278},
#     'southwest': {'lat': 40.42463212010727, 'lng': -3.666752779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Casa Osaka I',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1920,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105671331832685852090">Riccardo Andrini</a>'],
#     'photo_reference': 'AW30NDx-a2k2KYZmj6tfQQ8mYaQrOOfiXhxfKLaP85bd7T08WJ1tjuIXMCOt4xVwkaiqIB_689yvSk2c8HH0u8ExzBtQH8tlgwnlNX1__U6pVMP_RrnuFe9pFU-f3Gikgv24_Rc2e4N7K9KYVhd9aQ8Li7XZeR9GibiVL0XSgVUlHAM2fHMx',
#     'width': 4160}],
#   'place_id': 'ChIJCwygW7IoQg0R55UAwm4tsjA',
#   'plus_code': {'compound_code': 'C8GM+9V Madrid',
#    'global_code': '8CGRC8GM+9V'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJCwygW7IoQg0R55UAwm4tsjA',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 360},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral Oraá, 25, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4363612, 'lng': -3.6845755},
#    'viewport': {'northeast': {'lat': 40.43764767989271,
#      'lng': -3.683242720107279},
#     'southwest': {'lat': 40.43494802010727, 'lng': -3.685942379892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Ronda 14',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102433452139228485571">A Google User</a>'],
#     'photo_reference': 'AW30NDxczUiYy7bKFVNRk-GoMgj54kNeKRURNGqcOCk8PSCFgke8uL6-MFMgEelTz2flJH8y2Mjdi5fn2H806AnfwmszYNS2RUVesZxf_QlmocX4qH_1KSyn2dKW4ZxD3MhCaOGmiIhJp6ZPqlx4StjNHd7gIZqxuCUbga7clBBnSPlp-Gzl',
#     'width': 4032}],
#   'place_id': 'ChIJS7709-ooQg0RHBMhM1M3yaA',
#   'plus_code': {'compound_code': 'C8P8+G5 Madrid',
#    'global_code': '8CGRC8P8+G5'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJS7709-ooQg0RHBMhM1M3yaA',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1981},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 13, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4352424, 'lng': -3.6839244},
#    'viewport': {'northeast': {'lat': 40.43645607989273,
#      'lng': -3.682587020107278},
#     'southwest': {'lat': 40.43375642010728, 'lng': -3.685286679892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Doli Indian Restaurant',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2795,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100495270820280635667">Doli Restaurante Indio</a>'],
#     'photo_reference': 'AW30NDwoqY1skeV5T_mHsOVnbFEPS3kjVy-6Hss3dCSsQOd60BGxT7J0jhE6wppMVKiQ4oSlBK6vv7PVRRlTIr3EnSs1hg9vLojtcn6obzMVQfBbaC3kUQ7tYy0FxkD1DAJzpcH8e2a4PpXsbjPtAFyrp8yp56KDoLQpBkYyK-R6UItRCCRF',
#     'width': 4192}],
#   'place_id': 'ChIJj95-leooQg0RODdoKMBAiPA',
#   'plus_code': {'compound_code': 'C8P8+3C Madrid',
#    'global_code': '8CGRC8P8+3C'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJj95-leooQg0RODdoKMBAiPA',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1299},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Diego de León, 34, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4346924, 'lng': -3.6813457},
#    'viewport': {'northeast': {'lat': 40.43611652989273,
#      'lng': -3.680002370107279},
#     'southwest': {'lat': 40.43341687010728, 'lng': -3.682702029892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': 'Bar La Escalera',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114931075098500987454">JUAN MARTIN</a>'],
#     'photo_reference': 'AW30NDw4Ji6uW-Lit3kxTLvpDyQeaGcwbX_JQpnV3cRQbSGhO5I-ezIO0BPAthaGzldUR-w12_HGCbumR7jjxXLW87UYHvsCxRZXJmo9AXLezzZcnV42yVmrdIqGDL8t-_2XqmSC2xAKsDM3-cxXBcDJKDr5ydqv4GuxwdF1ThnUs-NbGmfO',
#     'width': 1920}],
#   'place_id': 'ChIJqdYIiMAoQg0RB--fUzRT-vU',
#   'plus_code': {'compound_code': 'C8M9+VF Madrid',
#    'global_code': '8CGRC8M9+VF'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJqdYIiMAoQg0RB--fUzRT-vU',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 623},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Velázquez, 62, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4281142, 'lng': -3.6835392},
#    'viewport': {'northeast': {'lat': 40.42947277989271,
#      'lng': -3.682365120107278},
#     'southwest': {'lat': 40.42677312010727, 'lng': -3.685064779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Salvaje',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 720,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116561123802182814008">A Google User</a>'],
#     'photo_reference': 'AW30NDxh6ztYGaIPPc5nb5Ly37ako-15EhA2DzIlXjDItVPyEMxbxUaFtmakltXYB3EBXU6U0gpi3EaoFYV7JYNgpcR-7X_jW8xC7E1qckvUcGlAxClh4jcbNcKH9dCsi_pkX8RpF3SbPUIQMCNwgeVnsyoaLJGqylMoVThZ-2hA87C7kL49',
#     'width': 720}],
#   'place_id': 'ChIJkfS7hcopQg0R8uV_vAWQxJE',
#   'plus_code': {'compound_code': 'C8H8+6H Madrid',
#    'global_code': '8CGRC8H8+6H'},
#   'rating': 3.9,
#   'reference': 'ChIJkfS7hcopQg0R8uV_vAWQxJE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1300},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Conde de Peñalver, 55, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4326389, 'lng': -3.6752907},
#    'viewport': {'northeast': {'lat': 40.43400042989271,
#      'lng': -3.673829070107278},
#     'southwest': {'lat': 40.43130077010727, 'lng': -3.676528729892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sushi',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1936,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116705717521311217501">TEPPANYAKI SUSHI-BAR</a>'],
#     'photo_reference': 'AW30NDwaYeoRiISlndeZSl_hFep4C4IRv8jZ3sNAJIB3Qv989RXKYZhDiHummQUrSxZ4M-07t4MHSlqOD1pqhGfoLER8u30Yl1BsrHTsAvHcsQpkwOAsCGVPkzZfE1DrCP0UmVG3mJaTSyWjHCMH7gEvZswfl1mO1nBYiiL_3zSPbPNbcQxv',
#     'width': 2592}],
#   'place_id': 'ChIJ2fBl9LgoQg0RyWlSO1T-0JY',
#   'plus_code': {'compound_code': 'C8MF+3V Madrid',
#    'global_code': '8CGRC8MF+3V'},
#   'price_level': 1,
#   'rating': 4.7,
#   'reference': 'ChIJ2fBl9LgoQg0RyWlSO1T-0JY',
#   'types': ['meal_takeaway',
#    'meal_delivery',
#    'bar',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 16},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. Botánica, 1, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4358961, 'lng': -3.6715119},
#    'viewport': {'northeast': {'lat': 40.43726357989272,
#      'lng': -3.670184870107277},
#     'southwest': {'lat': 40.43456392010727, 'lng': -3.672884529892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Itacho Sushi',
#   'opening_hours': {'open_now': False},
#   'place_id': 'ChIJfeItb8goQg0Ro7l1QJ0NsWE',
#   'plus_code': {'compound_code': 'C8PH+99 Madrid',
#    'global_code': '8CGRC8PH+99'},
#   'rating': 3.5,
#   'reference': 'ChIJfeItb8goQg0Ro7l1QJ0NsWE',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 2},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de Menéndez Pelayo, 9, 28009 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4214136, 'lng': -3.6796668},
#    'viewport': {'northeast': {'lat': 40.42287802989272,
#      'lng': -3.678344670107278},
#     'southwest': {'lat': 40.42017837010728, 'lng': -3.681044329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Yoshi - Sushi & More',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 911,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107112259856270744706">A Google User</a>'],
#     'photo_reference': 'AW30NDwrAPA6MrRIEJh0CUZ80UzsdV-t9tj0hEVLLNabFRxv1hDT2iQvQ0GD_xV9JvwIz4rnaUQkqHmTGmGvUEgcs2ZveoTs_FyNpKwTdKlyIOBrBqDqKZdWgGqAIpSgoSSo4qT0hOBcguzu23f_LKZi5mjmrz_ewhzseOGDpW7hRErl3cQf',
#     'width': 1366}],
#   'place_id': 'ChIJefk7qKMoQg0RkZCqQGBxYag',
#   'plus_code': {'compound_code': 'C8CC+H4 Madrid',
#    'global_code': '8CGRC8CC+H4'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJefk7qKMoQg0RkZCqQGBxYag',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1162},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de la Princesa, 1, 28008 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4245583, 'lng': -3.7121102},
#    'viewport': {'northeast': {'lat': 40.42592252989272,
#      'lng': -3.710660670107278},
#     'southwest': {'lat': 40.42322287010727, 'lng': -3.713360329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Nigiri Plaza de España',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 413,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103103983801814233117">Nigiri</a>'],
#     'photo_reference': 'AW30NDzn4yDOuMiX4DlTIa0zYFdHXmJwEaUq_A6OQBQUKEd4HGL86yAqvqZ27DjsGGQT0iiOEx5hRyFKAmhhHG_ksua8QZmxxDtVitdTTc6xNtXAPbPtaKkHw8C_8QjzHIexwyN1u7AWDtIRHHstC8y6LGE3tYTss8_IURwqZqnFfJMt6QMU',
#     'width': 550}],
#   'place_id': 'ChIJs33MPEwpQg0RBaYMNIkvA9o',
#   'plus_code': {'compound_code': 'C7FQ+R5 Madrid',
#    'global_code': '8CGRC7FQ+R5'},
#   'rating': 4.1,
#   'reference': 'ChIJs33MPEwpQg0RBaYMNIkvA9o',
#   'types': ['meal_takeaway',
#    'meal_delivery',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 558},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Don Ramón de la Cruz, 72, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.42859079999999, 'lng': -3.6748319},
#    'viewport': {'northeast': {'lat': 40.42998717989272,
#      'lng': -3.673484070107278},
#     'southwest': {'lat': 40.42728752010727, 'lng': -3.676183729892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'KOKORO',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108274414541375333158">Eng 613</a>'],
#     'photo_reference': 'AW30NDxtU6cDSLFKMAz4VavWtBiN-bnjU-R6SX1pc1u6QDijcbQMJU2PaRQ9se_orVaCSKgyVuc7iKvwJhi7pb9ImOKVFlI4KZG3ynivkfCdrDUV_1CHYqSO4lYHFmkOZ3AATXzaDUl16_FvdKYWIzy4kBrWaKTUBrv2lf3rtX5H5zo34ZYI',
#     'width': 3024}],
#   'place_id': 'ChIJkflVLLooQg0R43eMd0tankI',
#   'plus_code': {'compound_code': 'C8HG+C3 Madrid',
#    'global_code': '8CGRC8HG+C3'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJkflVLLooQg0R43eMd0tankI',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 387},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Velázquez, 68, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4286003, 'lng': -3.6833627},
#    'viewport': {'northeast': {'lat': 40.42996757989272,
#      'lng': -3.682255270107277},
#     'southwest': {'lat': 40.42726792010728, 'lng': -3.684954929892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Monsieur Sushita',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1916,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113469088245585197743">A Google User</a>'],
#     'photo_reference': 'AW30NDx8SkB-6nnrT4W8OV8YA7zig5ENoQOwrcSIJ-VSPbqZu8do29oYT9_IFlqsAezFQfoaKjc6SMSite2H8U0J8i0VAf3EmjivTjAkwE4NmMqIYq2ZVzDkw7bbZ0v9RLRIOO3D2Kd6kXWDLwMsngL1J2MxC8eh-VrHExVmYLYYA3afQiin',
#     'width': 2874}],
#   'place_id': 'ChIJ80nYyI0pQg0RvvxpwMmzLqU',
#   'plus_code': {'compound_code': 'C8H8+CM Madrid',
#    'global_code': '8CGRC8H8+CM'},
#   'rating': 4.4,
#   'reference': 'ChIJ80nYyI0pQg0RvvxpwMmzLqU',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1946}]

# %% [markdown]
# Definimos los Custom Fields necesarios para el dataset

# %%
fecha=datetime.now().strftime("%d-%m-%Y")
hora=datetime.now().strftime("%H")
normalize['fecha']=fecha
normalize['hora']=hora
normalize['busqueda']=comida
normalize['pais']=pais
normalize['ciudad']=ciudad
normalize['zona']=barrio

normalize['name'] = normalize['name'].replace(u"\U0001F354",value="", regex=True)
normalize['name'] = normalize['name'].replace(u"\U0001F35F",value="", regex=True)

normalize['clave']= normalize['place_id']+' '+normalize['fecha']

# %% [markdown]
# Generamos la lista de campos a mostrar en el DF

# %%
df_col= [
        'business_status'
        ,'name'
        ,'opening_hours.open_now'
        ,'place_id'
        ,'price_level'
        ,'rating'
        #,'types'
        ,'user_ratings_total'
        ,'fecha'
        ,'hora'
        ,'busqueda'
        ,'geometry.location.lng'
        ,'geometry.location.lat'
        ,'formatted_address'
        ,'clave'
        ,'pais'
        ,'ciudad'
        ,'zona'
        ]
df = normalize[df_col]

# %% [markdown]
# Cargamos datos a la BBDD MariaDB

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@127.0.0.1/{db}"
                       .format(user="root",
                               pw="MariaDB1.2.3",
                               db="restaurants_maps"))

df.to_sql('restaurants_api', con=engine,if_exists='append', chunksize=1000)
# Out:
# 60
