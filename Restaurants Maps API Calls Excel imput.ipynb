# %% [markdown]
# Importamos las librerias necesarias para ejecutar el código

# %%
import googlemaps
import pandas as pd
import time
from datetime import datetime
from datetime import date
#import seaborn as sns
import pymysql
from sqlalchemy import create_engine

# %% [markdown]
# Realizamos la llamada a la API con los valores definidos en los pop ups

# %%
# Define the API Key.
API_KEY = ''#'AIzaSyAhlwCCNhis1CTsecretJiWMIThGN7DG2lhMMFY'
#API_KEY = open('API_KEy.txt','r').read()

# Define the Client
gmaps = googlemaps.Client(API_KEY)


#pip install easygui
import easygui
pais= easygui.enterbox(msg="Introduzca Pais")
ciudad= easygui.enterbox(msg="Introduzca Ciudad")
barrio= easygui.enterbox(msg="Introduzca Zona/Barrio")
comida= easygui.enterbox(msg="Introduzca Tipo de comida")
# Prints--> Bob <class 'str'> 150 <class 'int'>

#location = (40.424941441889885, -3.6581815406804017)
#search_string = 'pizza'
#distance = 100
list = []
#dir(gmaps)

response = gmaps.places(query= pais + ',' + ciudad + ',' + barrio + ',' + comida)

#response
#response.keys()

list.extend(response.get('results'))

next_page_token = response.get('next_page_token')

while next_page_token:
    time.sleep(2)
    response = gmaps.places(query= 'Restaurante, Sao Miguel, Azores',
                    page_token=next_page_token)
    list.extend(response.get('results'))
    next_page_token = response.get('next_page_token')


normalize = pd.json_normalize(list)


list
# Out:
# [{'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alberto Aguilera, 20, 28015 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4300854, 'lng': -3.7093604},
#    'viewport': {'northeast': {'lat': 40.43139882989272,
#      'lng': -3.708034920107279},
#     'southwest': {'lat': 40.42869917010728, 'lng': -3.710734579892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Fundación Casa de México en España',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2880,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105667771510654877973">A Google User</a>'],
#     'photo_reference': 'AcYSjRi9MNbt58AmGwq4_F-t4gaic0m2KioiKVY_tqv-mMF832cDaUaJRuNosUb242ywULSP_Ub3ZtgKiALMI6En0gjXMxsj-mbFP67ZVEKEgjzJxgyIPyAXnv6F4vaQEGnPDnTgBxmmfisDtGdV0ExCF4EwOYX-b43Kd8W3WI7Psmj4dk0p',
#     'width': 5120}],
#   'place_id': 'ChIJa4xB52YoQg0RZLCVcd6FJBA',
#   'plus_code': {'compound_code': 'C7JR+27 Madrid',
#    'global_code': '8CGRC7JR+27'},
#   'rating': 4.5,
#   'reference': 'ChIJa4xB52YoQg0RZLCVcd6FJBA',
#   'types': ['movie_theater',
#    'museum',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 1524},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Narváez, 61, Local, 28009 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4171515, 'lng': -3.6761171},
#    'viewport': {'northeast': {'lat': 40.41850572989272,
#      'lng': -3.674871820107278},
#     'southwest': {'lat': 40.41580607010728, 'lng': -3.677571479892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'TACAZZO',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117762587488910228772">A Google User</a>'],
#     'photo_reference': 'AcYSjRgBHxmaWh_UfbY4aM3E91-V00-xxjicHwIU0aF-2jObTUgL0uxsCUaBG0ZPrTpPm12O6x_ig321YCfqIZuK3rI26IhDVhMxuR2dvrMyjIetHY7zwqoMxP694WphWNfcRpeEQ-L5IgcxwOGCm2LBoGXaDb_F1fdAm9BUB0lqbARBtzxQ',
#     'width': 810}],
#   'place_id': 'ChIJg7eb6aYoQg0RXpu0Cdo49lA',
#   'plus_code': {'compound_code': 'C88F+VH Madrid',
#    'global_code': '8CGRC88F+VH'},
#   'price_level': 1,
#   'rating': 3.9,
#   'reference': 'ChIJg7eb6aYoQg0RXpu0Cdo49lA',
#   'types': ['liquor_store',
#    'bar',
#    'store',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 831},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral. Pardiñas, 61, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4318873, 'lng': -3.6783253},
#    'viewport': {'northeast': {'lat': 40.43324387989273,
#      'lng': -3.676852770107277},
#     'southwest': {'lat': 40.43054422010729, 'lng': -3.679552429892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sol Azteca, Madrid España',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1081,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109360246222462737888">Sol Azteca</a>'],
#     'photo_reference': 'AcYSjRjiTL9DzxqRemZo_CxmsaGiyB1cjuwebRi3twVWrLIMaompd_nfMBZsManx3Be4j68OByC8ZyXJY3lU2dxHIIxjvZYCichh3LSSdagQDrxhh7KLb5OSpHT9Vma30_4KVEiyueNfu-rw7iDUh72y0M8MkfKMalsYJ6YB2GCJ_oG8N3Kv',
#     'width': 1080}],
#   'place_id': 'ChIJVUqJJb8oQg0RA96WN3H8eXM',
#   'plus_code': {'compound_code': 'C8JC+QM Madrid',
#    'global_code': '8CGRC8JC+QM'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJVUqJJb8oQg0RA96WN3H8eXM',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 762},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de la Victoria, 5, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4161192, 'lng': -3.7016035},
#    'viewport': {'northeast': {'lat': 40.41747082989272,
#      'lng': -3.700288120107277},
#     'southwest': {'lat': 40.41477117010727, 'lng': -3.702987779892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Venta El Buscón',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2252,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111603274531460669598">Bryant Yudhistira</a>'],
#     'photo_reference': 'AcYSjRgEPUA2w91VjSGPrlv9KJNB6llqNLdlIwE0n10O3oHQMmxmpitEeLWr01sA8hvkqAyKZvQnNTBxoRiqRv8TWd4TlmcmSPi_AWL-TAJHImQxSsCtVMCiv1y3Gzb2ef5TzxjUFQ6x7VXaimwnCM6Wuh1DRxWiymKti3pxDJQSIhwHRgiU',
#     'width': 4000}],
#   'place_id': 'ChIJgTI2jYAoQg0Rwj3CHNl665Q',
#   'plus_code': {'compound_code': 'C78X+C9 Madrid',
#    'global_code': '8CGRC78X+C9'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJgTI2jYAoQg0Rwj3CHNl665Q',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 2602},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C, C. Canteras de Tilly, 3, 1ºC, 28032 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4023197, 'lng': -3.6047129},
#    'viewport': {'northeast': {'lat': 40.40361507989272,
#      'lng': -3.603365470107278},
#     'southwest': {'lat': 40.40091542010727, 'lng': -3.606065129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Mexicanos aquí',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2510,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109811692174431773521">A Google User</a>'],
#     'photo_reference': 'AcYSjRhkKSNfABOjtuY8aDV7c82QHkzsoc2eUbk5U2cSaOR_4AlWRjK_TeKCwtkSd1vbeIJ54Hjwus9_dHzV0D-R0wn6XDXiW4IYCHNiOyDQ4nJX7hMFn9U6-vP-AaEmCspR5Dy90aFowRU9LbebeIlFsy6f25lyjt-PlVcrdtzPC5Lw0ZSV',
#     'width': 3780}],
#   'place_id': 'ChIJVVX5EWklQg0RCe2fVaAsjDY',
#   'plus_code': {'compound_code': 'C92W+W4 Madrid',
#    'global_code': '8CGRC92W+W4'},
#   'rating': 0,
#   'reference': 'ChIJVVX5EWklQg0RCe2fVaAsjDY',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 0},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Hernán Cortés, 5, 28004 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4236473, 'lng': -3.7002245},
#    'viewport': {'northeast': {'lat': 40.42494057989272,
#      'lng': -3.698902970107278},
#     'southwest': {'lat': 40.42224092010728, 'lng': -3.701602629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'MICUARI Arte y Diseño Mexicano',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1249,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100742640043570782000">A Google User</a>'],
#     'photo_reference': 'AcYSjRiZd2etBS1_xv3IMmovc7R-58X2VwXHN4CGl9RI2qwJIDtuLC-Fd41CKFrtr_q15Zq-SXiu1SsrnzcPgFVlNMiRwaRFzuSSfXK3D-RcjR01vCyO-N42_AhlgcK9uF_BWq2Q2OYZ3sZnlUalXPEcGBvr9w4pWOXNCVEMQMiROrg2ZTEy',
#     'width': 1284}],
#   'place_id': 'ChIJ51XBlKQoQg0RLwz6I6LEPjg',
#   'plus_code': {'compound_code': 'C7FX+FW Madrid',
#    'global_code': '8CGRC7FX+FW'},
#   'rating': 4.6,
#   'reference': 'ChIJ51XBlKQoQg0RLwz6I6LEPjg',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 23},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Ave María, 18, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4110398, 'lng': -3.7006379},
#    'viewport': {'northeast': {'lat': 40.41241402989272,
#      'lng': -3.699218470107278},
#     'southwest': {'lat': 40.40971437010728, 'lng': -3.701918129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Shop Hammocks',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4608,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112907641897206245936">La Tienda de Las Hamacas</a>'],
#     'photo_reference': 'AcYSjRgC2aN38Am_s5iEw4hpAbuBBwZRRXG5r2MW4ld_dgKzf-FQoHaLfmAkZb7RuWfNihTM8vjUZgdaUPwq9TbRGDqXCpslNbDr0Jvaq_sDKP_W-pE--6ix3TlP1Fus6_gML1hUdsQzHCubRllALFb7FRO96yLzjua9_vSzuXjmlSWNrafY',
#     'width': 3456}],
#   'place_id': 'ChIJaXZuhSwmQg0RFidzpliGi7Q',
#   'plus_code': {'compound_code': 'C76X+CP Madrid',
#    'global_code': '8CGRC76X+CP'},
#   'price_level': 1,
#   'rating': 4.9,
#   'reference': 'ChIJaXZuhSwmQg0RFidzpliGi7Q',
#   'types': ['furniture_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 11},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alcalá, 237, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4321355, 'lng': -3.6632911},
#    'viewport': {'northeast': {'lat': 40.43360739999999,
#      'lng': -3.660391199999999},
#     'southwest': {'lat': 40.43080860000001, 'lng': -3.665705600000001}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Las Ventas Bullring',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 9000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108360417130654505652">Cesar Alfonso Franco</a>'],
#     'photo_reference': 'AcYSjRhn0TXi4mMkt9q-xHcsADtW-s6cf6zmHjWd3cMhN70hzr9kYZc3Lrb4bExNkFGxkCGX3HchTMLRgYeUkxUZHyTXxL8_YraI0w5YQTvppHM-x1PrPLa8b9kt9tmg3XGZDuTPu4-5v5e8bF7eYyjBsiCo2wB9o071ZftT_Divh4wIohie',
#     'width': 12000}],
#   'place_id': 'ChIJN9Ka0LQoQg0RyKntUElZV74',
#   'plus_code': {'compound_code': 'C8JP+VM Madrid',
#    'global_code': '8CGRC8JP+VM'},
#   'rating': 4.4,
#   'reference': 'ChIJN9Ka0LQoQg0RyKntUElZV74',
#   'types': ['tourist_attraction', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 28759},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alcalá, 227, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.430115, 'lng': -3.665160799999999},
#    'viewport': {'northeast': {'lat': 40.43147142989272,
#      'lng': -3.663780120107278},
#     'southwest': {'lat': 40.42877177010728, 'lng': -3.666479779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Los Timbales',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3489,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101838294137505506393">A Google User</a>'],
#     'photo_reference': 'AcYSjRhdk1WzhDMR-En_0_B996tg0hShjWMzs7HHSfW4Hn2H9WTlx4-BAEYrWzDqAP0ejp7K5BfvFRrqqc2Z_HF1dfwytn1peo6SXxqudg3pnFPqTde4AzR75UqLZ-qgADHuuxfzKdgdsHfAilV-7zY-1FXBvj59o038CvJTAOmEIE6mzpoa',
#     'width': 4936}],
#   'place_id': 'ChIJ5wI1Y7QoQg0RU0Da822H30o',
#   'plus_code': {'compound_code': 'C8JM+2W Madrid',
#    'global_code': '8CGRC8JM+2W'},
#   'price_level': 2,
#   'rating': 3.5,
#   'reference': 'ChIJ5wI1Y7QoQg0RU0Da822H30o',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 723},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alcalá, 233, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.43035200000001,
#     'lng': -3.664421099999999},
#    'viewport': {'northeast': {'lat': 40.43165227989272,
#      'lng': -3.663025570107278},
#     'southwest': {'lat': 40.42895262010727, 'lng': -3.665725229892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Jarritus',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104582736822363099635">Jarritus Madrid SL</a>'],
#     'photo_reference': 'AcYSjRj7f3-ev_wf7w_obNI4eEWDoqSodV1Sh0XddhOnWeWJEzxoukGsQOAqvVQvq1mjhsxprWPKSl9L0u5fjkFLBZE7BSkA7F4rUfSObUUCWbCk9b0RF9207ByKZPHbdcA4yok8Hn7bNSvMMPRt4SELgrpJdQVB95JVv5uxpXDB0CLyavkV',
#     'width': 3025}],
#   'place_id': 'ChIJyQDTjbQoQg0R0kQ2as1mbbQ',
#   'plus_code': {'compound_code': 'C8JP+46 Madrid',
#    'global_code': '8CGRC8JP+46'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJyQDTjbQoQg0R0kQ2as1mbbQ',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 1549},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Velázquez, 87, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4337274, 'lng': -3.6836099},
#    'viewport': {'northeast': {'lat': 40.43507327989271,
#      'lng': -3.682168470107278},
#     'southwest': {'lat': 40.43237362010727, 'lng': -3.684868129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Gonzalez & Co Salamanca',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117357294271934147110">Carlos leonardo Graterol Garcia</a>'],
#     'photo_reference': 'AcYSjRjyh2NHoI7o5yJpZnWuM6xVy7oI_i7WN16izXdkJNCfOd9lSmvkp05l59syFkgRZd7w43cNdXfRUOa1P9po5SkeW_LjeiSpuoWdojtmCSSVXHYtkrRzoG8g_sZXpfBKgqf4W_dJxtIJ4dHhgLNpFE1l1rMffPf22EzwltbgkgdXwRgD',
#     'width': 3000}],
#   'place_id': 'ChIJQc4HPd0pQg0RnFeH08OeSO0',
#   'plus_code': {'compound_code': 'C8M8+FH Madrid',
#    'global_code': '8CGRC8M8+FH'},
#   'rating': 4.7,
#   'reference': 'ChIJQc4HPd0pQg0RnFeH08OeSO0',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 129},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. del Marqués de Corbera, 17, 28017 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4237387, 'lng': -3.6551288},
#    'viewport': {'northeast': {'lat': 40.42509002989272,
#      'lng': -3.653788970107278},
#     'southwest': {'lat': 40.42239037010728, 'lng': -3.656488629892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Kebab Doner King',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3474,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106014389180893335523">YUMIKO T</a>'],
#     'photo_reference': 'AcYSjRivImtnbsBmgnZn0HwEwbU3JijHLmTpa2UpDwPmboe5JnIY1Eo7xpCjXQSXBgslqyLd0FFJ-Hgu9O2ZJ-Aqf1LRSyPg806PIIGYLbn6tM-daKaQg21kL004cDclC5LAAvKAOacmPBpYROkleDTSOG0qsPC13J5vONvSROJ7204qrsz5',
#     'width': 4632}],
#   'place_id': 'ChIJDXE1xHIvQg0R1HJxgMeHeNk',
#   'plus_code': {'compound_code': 'C8FV+FX Madrid',
#    'global_code': '8CGRC8FV+FX'},
#   'rating': 3.3,
#   'reference': 'ChIJDXE1xHIvQg0R1HJxgMeHeNk',
#   'types': ['liquor_store',
#    'bakery',
#    'bar',
#    'store',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 132},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Fuencarral, 105, 28004 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4285355, 'lng': -3.7023144},
#    'viewport': {'northeast': {'lat': 40.42990227989272,
#      'lng': -3.700912620107278},
#     'southwest': {'lat': 40.42720262010727, 'lng': -3.703612279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Crepes & Waffles',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102758211775384177218">partidoverde10</a>'],
#     'photo_reference': 'AcYSjRideDUzvEpKl4FNW_yJQtez35E5sb9ml1blPc_YFxpzPcNpf4zSZ00mguxC6YH1X6dEUfk-J7FAPRZLAM_KeLm4zBFo_nSX1hI3u43gbm6Dp0pUVtm29xTSYy_QRRoUcFNHr31IAMrsbtns6VMelosY0Hn5cs05FjfAv27edK9G8y7o',
#     'width': 4000}],
#   'place_id': 'ChIJPXNVA4ooQg0RHQLNVH_3ZP4',
#   'plus_code': {'compound_code': 'C7HX+C3 Madrid',
#    'global_code': '8CGRC7HX+C3'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJPXNVA4ooQg0RHQLNVH_3ZP4',
#   'types': ['restaurant',
#    'cafe',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 4516},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Mariachi mexicano en Madrid, C. Gonzalo Herrero, 27, 3B, 28039 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.46331, 'lng': -3.7000273},
#    'viewport': {'northeast': {'lat': 40.46465112989272,
#      'lng': -3.698682570107278},
#     'southwest': {'lat': 40.46195147010727, 'lng': -3.701382229892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#13B5C7',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Mariachi Charros de Jalisco en Madrid España',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 543,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113652035899264314267">Mariachi Charros de Jalisco</a>'],
#     'photo_reference': 'AcYSjRiLx42SZwlevbsCCHv2DeaSwmpM76ojUwpyxfiWfBLMES1opiVROX9DsYqrHNlLJH4sDJ43h8_FvcAFpIKEidrT1vgnofvB6wKAl8aNAc9x5GsUnughLN4B8Ix97TE0zMko4fwPnWJkpx-2-SB9ltX2_ZbkWQSvTKTMucOzT5XDLVOj',
#     'width': 967}],
#   'place_id': 'ChIJPUYLLgYpQg0RQVfbrkZofl8',
#   'plus_code': {'compound_code': 'F77X+7X Madrid',
#    'global_code': '8CGRF77X+7X'},
#   'rating': 4.7,
#   'reference': 'ChIJPUYLLgYpQg0RQVfbrkZofl8',
#   'types': ['electronics_store',
#    'home_goods_store',
#    'store',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 26},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Ricardo Ortiz, 46, Local 4, 28017 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4258969, 'lng': -3.6583192},
#    'viewport': {'northeast': {'lat': 40.42726952989273,
#      'lng': -3.656798970107278},
#     'southwest': {'lat': 40.42456987010728, 'lng': -3.659498629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#   'name': 'Desi Gourmet',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 822,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106534322827656505092">Desi Gourmet</a>'],
#     'photo_reference': 'AcYSjRiSqCJ4zzqqdeV7m0CmlDlJJbhEIhhKCzabLW77amL2so7MjqQ4LD13zCInntcQ7Sqlx5C2SXz9rooD9NjzfZyVzlKxH8xD-QSKgSh3xokUI-p9VlaGL2JyE2TGiQh_KLOfZayMrl6phmZMGFWUSVdoOjfuon-oiwG6loOPI0ErlX1E',
#     'width': 960}],
#   'place_id': 'ChIJxTH2O0wvQg0RgdJXhdaNRVk',
#   'plus_code': {'compound_code': 'C8GR+9M Madrid',
#    'global_code': '8CGRC8GR+9M'},
#   'rating': 4.6,
#   'reference': 'ChIJxTH2O0wvQg0RgdJXhdaNRVk',
#   'types': ['grocery_or_supermarket',
#    'store',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 333},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del León, 12, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.414032, 'lng': -3.698952},
#    'viewport': {'northeast': {'lat': 40.41536507989272,
#      'lng': -3.697549770107278},
#     'southwest': {'lat': 40.41266542010727, 'lng': -3.700249429892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shoppingcart_pinlet',
#   'name': 'Casa González',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 768,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112424917721435664335">Casa Gonzalez</a>'],
#     'photo_reference': 'AcYSjRjJgwgxF95D8c01mW9QHE2wbg475iLKG33JUBPza7VWGoNqMceG7jtTb_dXR3EGk1DDVdzt8HDB9r1h90oAho0Z3xb-Cmen0fLuFRW_lTbwh5Q7afV2f7UymB7IjCpQB7bb6bLMi56pKuikmWcANdTF8U_T_jhCqlDc-zKSk1dLnmgd',
#     'width': 1024}],
#   'place_id': 'ChIJnRHo64EoQg0RAlPsgcBO2XY',
#   'plus_code': {'compound_code': 'C872+JC Madrid',
#    'global_code': '8CGRC872+JC'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJnRHo64EoQg0RAlPsgcBO2XY',
#   'types': ['liquor_store',
#    'bar',
#    'grocery_or_supermarket',
#    'store',
#    'restaurant',
#    'point_of_interest',
#    'food',
#    'establishment'],
#   'user_ratings_total': 1745},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Pedro Heredia, 1, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4281722, 'lng': -3.6665661},
#    'viewport': {'northeast': {'lat': 40.42949602989272,
#      'lng': -3.665264470107278},
#     'southwest': {'lat': 40.42679637010728, 'lng': -3.667964129892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Guleria',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3120,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116390631537234110623">Oscar Rodriguez Calzado</a>'],
#     'photo_reference': 'AcYSjRibLP90ZZSdqUQcGon_UZgZv3vht2tJx4Kkc8a7Wf4M1I62Bf5fBkC7Daj9QcabXTN9DV0Cv3lMG6POZjfkKzprWPgiZc3hpBv8DWRulEBH5VCtbNsCoR0BTqxFxhMRhwlkhqhackDStoAxm_aOfFVqQfDf4Vtq3H4D3KoyVZeJ9yc7',
#     'width': 4160}],
#   'place_id': 'ChIJCcR_6bMoQg0RVYrEX1IFWPM',
#   'plus_code': {'compound_code': 'C8HM+79 Madrid',
#    'global_code': '8CGRC8HM+79'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJCcR_6bMoQg0RVYrEX1IFWPM',
#   'types': ['restaurant', 'bar', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 810},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C/ del Dr. Gómez Ulla, 12, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4295998, 'lng': -3.6677012},
#    'viewport': {'northeast': {'lat': 40.43098047989272,
#      'lng': -3.666426970107278},
#     'southwest': {'lat': 40.42828082010728, 'lng': -3.669126629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': 'Restaurante El Chorrón',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 4032,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111808091361294123144">sirio3mil</a>'],
#     'photo_reference': 'AcYSjRhEGa756y80SdlCOMW-IbXL6G0WmDxoaaZaoOmDliKPGoe2jFvPOdhjGW1BifjRcuGjMhPXOdO3MLo8pWD1C_D4oFYTQ_CCHTTzaX0nU4HYMyfm-nmTgV8Ei6e7I4-QH0lo22_K0_XtxNC862ZmjAr8QSpRh9b2pZM5tW6u-7Jd_NLP',
#     'width': 3024}],
#   'place_id': 'ChIJ6eRnrrYoQg0R7EHSZgXZdXU',
#   'plus_code': {'compound_code': 'C8HJ+RW Madrid',
#    'global_code': '8CGRC8HJ+RW'},
#   'price_level': 2,
#   'rating': 4,
#   'reference': 'ChIJ6eRnrrYoQg0R7EHSZgXZdXU',
#   'types': ['bar', 'restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 822},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. Ricardo San Juan, 20, 28043 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4650213, 'lng': -3.6532767},
#    'viewport': {'northeast': {'lat': 40.46634332989272,
#      'lng': -3.651964770107279},
#     'southwest': {'lat': 40.46364367010728, 'lng': -3.654664429892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Marisquería Hermanos Álvarez',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111852643135404633894">Marisquería Hermanos Álvarez</a>'],
#     'photo_reference': 'AcYSjRhE6O1RoKShrSYuZMTS1e00IcSz-a2cYCF8h5Z3cof8ynlZQrWJFIb_PeDsIxYwTl1gBXNMUVYXFzy4krpH9-ka3MgURg0BYNf_jbNqQW4pqYO_E4TB6dz2GHvw2Uz64BR8_svPpgNdplbeqEVFAo6Fchz_wgptcvPkfM3LmggB9YP_',
#     'width': 2048}],
#   'place_id': 'ChIJCao7H9AuQg0R02DV8oW7ozM',
#   'plus_code': {'compound_code': 'F88W+2M Madrid',
#    'global_code': '8CGRF88W+2M'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJCao7H9AuQg0R02DV8oW7ozM',
#   'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 485},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Duque de Alba, 4, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4119262, 'lng': -3.7059224},
#    'viewport': {'northeast': {'lat': 40.41325562989272,
#      'lng': -3.704561670107278},
#     'southwest': {'lat': 40.41055597010727, 'lng': -3.707261329892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'El Imparcial',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103913709654905048000">Restaurante El Imparcial</a>'],
#     'photo_reference': 'AcYSjRjYDkHf67uhxtVtqjSJ0hHOxI3CtQ32SxRSvNxsXoQsOm2eVWDk0bSI7SSnWaAR59nUNGd5_yNQQ0FcVTArvnr1-wE4muTYmwmVAWAlf11_kFk-bz78fGEF8cVmO1r66ocfVAakcK5hwUGuyAU_mZtQpjs_-52TPfUvPPuEL84I1CwQ',
#     'width': 1600}],
#   'place_id': 'ChIJOUSjm9UnQg0RjnR740kyB1I',
#   'plus_code': {'compound_code': 'C76V+QJ Madrid',
#    'global_code': '8CGRC76V+QJ'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJOUSjm9UnQg0RjnR740kyB1I',
#   'types': ['restaurant', 'bar', 'point_of_interest', 'food', 'establishment'],
#   'user_ratings_total': 2888},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Don Ramón de la Cruz, 97, 28006 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4286499, 'lng': -3.6727543},
#    'viewport': {'northeast': {'lat': 40.42996197989272,
#      'lng': -3.671468870107279},
#     'southwest': {'lat': 40.42726232010728, 'lng': -3.674168529892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Casa Baltasar',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104283030653817709912">A Google User</a>'],
#     'photo_reference': 'AcYSjRh-sr2O_Cm4KD1ymf3t1ZOgW7QSOOADIGAzU-Rw-YqKsZCflPcHpH5mCDttgkxPaFf2vd5DTQmRhE1GVrxvJljqp9wOz2nuSsLeX8wB_-bL3YrtZkea90Gxu6tdgLxMyKX3axQS-J61qSNuOh4hvSgAu6A_bmZpgo18IPlVqd7rCDXh',
#     'width': 5312}],
#   'place_id': 'ChIJZUpoBrooQg0Rs4lE-2z8rfs',
#   'plus_code': {'compound_code': 'C8HG+FV Madrid',
#    'global_code': '8CGRC8HG+FV'},
#   'price_level': 2,
#   'rating': 4.6,
#   'reference': 'ChIJZUpoBrooQg0Rs4lE-2z8rfs',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 197},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle Virgen de la Alegría, 10, local 122, mercado de ventas Calle Bernardino Obregón 5 , E-COMMERCE C.P.28012, 28027 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4331904, 'lng': -3.6570188},
#    'viewport': {'northeast': {'lat': 40.43451407989272,
#      'lng': -3.655457420107278},
#     'southwest': {'lat': 40.43181442010728, 'lng': -3.658157079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Vinos de la tierra Bodega Gárate',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 809,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106149028989743136180">bodega Garate, vinos de la tierra</a>'],
#     'photo_reference': 'AcYSjRiC7W3TQNxQgkm5IcXpvi7fSX1bEIplIwnBQvv9rVu0WGfS54kQRRr79KJFKg-H2Mm6jgAv7IWLm0h1EAiW7__iL0ceun812XFSxM0wQd_cdbfu5deok3KyCcpJ_9MWivV-bsgeKgnF591BTvOcSHq9l8leJgqMmHpXg4ZN9eDK4f-a',
#     'width': 1440}],
#   'place_id': 'ChIJbxDa90kvQg0R5rrKChFGORQ',
#   'plus_code': {'compound_code': 'C8MV+75 Madrid',
#    'global_code': '8CGRC8MV+75'},
#   'rating': 4.8,
#   'reference': 'ChIJbxDa90kvQg0R5rrKChFGORQ',
#   'types': ['liquor_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 33},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Josefa Valcárcel, 10, 28027 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4481734, 'lng': -3.6480953},
#    'viewport': {'northeast': {'lat': 40.44957222989272,
#      'lng': -3.64681712010728},
#     'southwest': {'lat': 40.44687257010727, 'lng': -3.649516779892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'By The Way, Beer & Food',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3452,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/107560747799160398533">A Google User</a>'],
#     'photo_reference': 'AcYSjRjLQkG8Wgl0lxoEDF_F4tExR_Wb5XIgGSAuSolUoesfWTzubLjhtjVPy9A3w22dGEAiuSne0YywtLF5vCijVbIZOaJS1W2hzhwwiSVctPqbEbdwWtcBnvDdr1REFvfV2fWNgWI-5Q-I8JiQjHilUdgWkd33ipQ5vwdD6xGAWp0eGKO4',
#     'width': 5183}],
#   'place_id': 'ChIJ__-bZiQvQg0RPOdU5wKG8as',
#   'plus_code': {'compound_code': 'C9X2+7Q Madrid',
#    'global_code': '8CGRC9X2+7Q'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJ__-bZiQvQg0RPOdU5wKG8as',
#   'types': ['restaurant',
#    'electronics_store',
#    'bar',
#    'home_goods_store',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 1112},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Castelló, 22, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4243016, 'lng': -3.6813454},
#    'viewport': {'northeast': {'lat': 40.42566097989273,
#      'lng': -3.680076820107279},
#     'southwest': {'lat': 40.42296132010728, 'lng': -3.682776479892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': '100% México',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2448,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/100811028075215247498">Daniel Patiño</a>'],
#     'photo_reference': 'AcYSjRgBxCVLA9yFm9Zgm0kQE3w7-9cs4XOggdGZ301Tpv8KPwElOkOX056ItBCiZbzcSFnQ9pJn_QYFR_ppcoVfHSdLES8mwVchXAwjF3IW-lJX5icNyW0p-ici1y4yuSHnCG3KUa-CkyLuQLb3XXTn0zZ_BaVmPhU_q96V28VaLk-nlFsk',
#     'width': 3264}],
#   'place_id': 'ChIJlT2YSL0oQg0RkjcMzPzqkW4',
#   'plus_code': {'compound_code': 'C8F9+PF Madrid',
#    'global_code': '8CGRC8F9+PF'},
#   'price_level': 2,
#   'rating': 4.5,
#   'reference': 'ChIJlT2YSL0oQg0RkjcMzPzqkW4',
#   'types': ['restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 426},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Barcelona, 4, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4156437, 'lng': -3.7026768},
#    'viewport': {'northeast': {'lat': 40.41665342989273,
#      'lng': -3.701270770107278},
#     'southwest': {'lat': 40.41395377010728, 'lng': -3.703970429892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Asador Vasco En Busca del Tiempo',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1707,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114846705364869831996">A Google User</a>'],
#     'photo_reference': 'AcYSjRh_Wi1VvtiU4kyXuzpGoj_BYWszEVFdt2NdserL99pzGgPUc_KqzGNBNVR5uL2jAz0oS-NC097tQ10Sp6v2zNYnSEW_bAVMwk7zvhezd4ZlkuVVRYKxNwXhhLA3UYApC2nmcIPNP-Ot2GTQQYVxNSBesfzSBMVRkPkrcHP-frzfR6lC',
#     'width': 2560}],
#   'place_id': 'ChIJ8wfcgIAoQg0RPVjnX-JJGVg',
#   'plus_code': {'compound_code': 'C78W+7W Madrid',
#    'global_code': '8CGRC78W+7W'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJ8wfcgIAoQg0RPVjnX-JJGVg',
#   'types': ['bar', 'restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2269},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Emilio Muñoz, 33, 28037 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.43213, 'lng': -3.62786},
#    'viewport': {'northeast': {'lat': 40.43341817989272,
#      'lng': -3.626461270107277},
#     'southwest': {'lat': 40.43071852010728, 'lng': -3.629160929892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'El Sabroso',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113807452378876071967">A Google User</a>'],
#     'photo_reference': 'AcYSjRjm7Xnc4onSwpS5nx82ECP9_RWnPXetIovI2ERqkUuJjdHDNPCqsyH9oq6noP_b3WcGckmYTfpB0y9G-DzXgseSENxgnr8aRgcQBLliB-fGZ96ms-n9VdkMAV4Yig6VATjT7_Cm3w-HwJ7VuSx2Qna1JYB2nmnLAo2M2FdJA1ErClow',
#     'width': 4032}],
#   'place_id': 'ChIJ3WX88nMvQg0RF9V-fpPZPfw',
#   'plus_code': {'compound_code': 'C9JC+VV Madrid',
#    'global_code': '8CGRC9JC+VV'},
#   'price_level': 1,
#   'rating': 4.2,
#   'reference': 'ChIJ3WX88nMvQg0RF9V-fpPZPfw',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1371},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Bocángel, 4, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4296067, 'lng': -3.6640837},
#    'viewport': {'northeast': {'lat': 40.43097372989272,
#      'lng': -3.662698620107278},
#     'southwest': {'lat': 40.42827407010728, 'lng': -3.665398279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'La Rodaja',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1200,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116781315706755152252">LA RODAJA</a>'],
#     'photo_reference': 'AcYSjRjvK-FiqJmRpeSHGGc0Yxz47soxpqwY5GaTqh4JIMHUfg7nRzgqXoHmM1DHsyunohoboPxEJ9b_N-pCDafXvHO8nTQLqehCw38re8UdQPM-UvyVM6ULxIh0yzK_oU6CByzruXrK5kKG_DYyvRuarDNvlYq8S_nRLkVJRAOgcYfo_XeA',
#     'width': 1600}],
#   'place_id': 'ChIJhY3znLQoQg0RCkmjBMaSaX4',
#   'plus_code': {'compound_code': 'C8HP+R9 Madrid',
#    'global_code': '8CGRC8HP+R9'},
#   'price_level': 1,
#   'rating': 4.6,
#   'reference': 'ChIJhY3znLQoQg0RCkmjBMaSaX4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1355},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Alejandro González, 8, 28028 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4298324, 'lng': -3.6636176},
#    'viewport': {'northeast': {'lat': 40.43124137989273,
#      'lng': -3.662214270107278},
#     'southwest': {'lat': 40.42854172010728, 'lng': -3.664913929892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'El Zócalo',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3456,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104792507605425700366">A Google User</a>'],
#     'photo_reference': 'AcYSjRgrK9uoo8bug_xFdhrqsC4o3xGcnEBb6AH86vXlyMwNFaMk5bIp4X0kznicwn48fBEGV01qZwJ2v3Q4Z-qKpCnAUIE03T4SEf7GGOVHBatL5ZguDi1XOzNrRAhsOR2ni7RGpnCLwN22QnOSdIiF0ZpUWB-KRyjYnWZJs0XRfXX5BFri',
#     'width': 4608}],
#   'place_id': 'ChIJ_3h4Fz4pQg0RObN6dIQIcUA',
#   'plus_code': {'compound_code': 'C8HP+WH Madrid',
#    'global_code': '8CGRC8HP+WH'},
#   'rating': 4.6,
#   'reference': 'ChIJ_3h4Fz4pQg0RObN6dIQIcUA',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 527},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Embajadores, 41, 28012 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4077339, 'lng': -3.7036534},
#    'viewport': {'northeast': {'lat': 40.40916237989272,
#      'lng': -3.702473470107277},
#     'southwest': {'lat': 40.40646272010728, 'lng': -3.705173129892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Mercado de San Fernando',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102113563843493453201">Merche Rodríguez-Piñero</a>'],
#     'photo_reference': 'AcYSjRgCf1IUNrHgt3Pszu5f7nTxLwnKoGpKDaZGHGfFmJtb4QC0MOi73Oy-hFyBZuUdgWIMJvJVyPjjFbb-xrks8GZmOM2E8ZRTZC9xdw1YFCHXd9F95mSc1qw44IkObKPFllIh_m3IZ2GfagwIJdljx-ew0R2loxStipD8JFIv7Fo5Vfx-',
#     'width': 4032}],
#   'place_id': 'ChIJu_erQjImQg0RSGdXtET1-HU',
#   'plus_code': {'compound_code': 'C75W+3G Madrid',
#    'global_code': '8CGRC75W+3G'},
#   'rating': 4.4,
#   'reference': 'ChIJu_erQjImQg0RSGdXtET1-HU',
#   'types': ['tourist_attraction',
#    'book_store',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 8101},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. Prosperidad, Número 3, 28002 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4443844, 'lng': -3.6749538},
#    'viewport': {'northeast': {'lat': 40.44562552989272,
#      'lng': -3.673637720107278},
#     'southwest': {'lat': 40.44292587010728, 'lng': -3.676337379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/bar-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/bar_pinlet',
#   'name': '“La Prospe” Tapas & Bar',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 633,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111037739695053301729">CAFETERIA PROSPERIDAD</a>'],
#     'photo_reference': 'AcYSjRihIX13ZFmOsASUVA-zwo08yGiCjo70HbIxusRLaWfY0HX9pEGi76wGrca3Q0Mn7480zXgiEfb6xBcgKaydxRZ9K1c49R49XZfwVI7w-uh5vUISPmeZbqt64T3yIzPTFL_jMcO_JCPIDJXs7q_wJ5mj8oa9cATJEyL08EtDMnhCWfoV',
#     'width': 1124}],
#   'place_id': 'ChIJ94y11dooQg0RdLT7jfm1i7o',
#   'plus_code': {'compound_code': 'C8VG+Q2 Madrid',
#    'global_code': '8CGRC8VG+Q2'},
#   'rating': 4.2,
#   'reference': 'ChIJ94y11dooQg0RdLT7jfm1i7o',
#   'types': ['cafe',
#    'bar',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 2392},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Gral. Pardiñas, 12, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4243979, 'lng': -3.6785793},
#    'viewport': {'northeast': {'lat': 40.42574952989272,
#      'lng': -3.677277520107278},
#     'southwest': {'lat': 40.42304987010728, 'lng': -3.679977179892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Cómete México - General Pardiñas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2988,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112229568145549762409">Matías Peirano</a>'],
#     'photo_reference': 'AcYSjRiWjuNehE8PB3bmkNBOTA14JXrB6sFIMnTojg7GhZlHezYhjFhpqVS6BunIrru_P41VH2OphB910k5MEFE0jxu65p4M4qB7lJ55jEwchWg0dwlznmPugksNmJ7-UVJq9_2KsiV3tHs1jntOfrqYMACyd_atkjpovxFjpUc5QnRi-hMt',
#     'width': 5312}],
#   'place_id': 'ChIJl5P6trwoQg0RG4BXlyochs8',
#   'plus_code': {'compound_code': 'C8FC+QH Madrid',
#    'global_code': '8CGRC8FC+QH'},
#   'price_level': 2,
#   'rating': 4.4,
#   'reference': 'ChIJl5P6trwoQg0RG4BXlyochs8',
#   'types': ['meal_delivery',
#    'meal_takeaway',
#    'grocery_or_supermarket',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 3176},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Claudio Coello, 70, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4291243, 'lng': -3.6858558},
#    'viewport': {'northeast': {'lat': 40.43052852989272,
#      'lng': -3.684445420107279},
#     'southwest': {'lat': 40.42782887010728, 'lng': -3.687145079892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'indiano madrid df',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3000,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116355988726330632803">Rosa Blanco</a>'],
#     'photo_reference': 'AcYSjRij2WiP1p9LOx4X_HWPLHCRTG-wKqZRqh18jmjHzliTr0XKFDQM9lLRTgWjkpTC84q8K3HOCashiEWtTZE4BwUvcTCaUH9fKzEG-u8Ei_h-UzGmoOdoFGUtpDKpcoGhI8yNKu5Zl5HIAD6sIAls_edWlkToh7XwaTHLdM401x4Et-so',
#     'width': 4000}],
#   'place_id': 'ChIJ0eE5Me4pQg0RB_IVMt9xvK0',
#   'plus_code': {'compound_code': 'C8H7+MM Madrid',
#    'global_code': '8CGRC8H7+MM'},
#   'rating': 4.6,
#   'reference': 'ChIJ0eE5Me4pQg0RB_IVMt9xvK0',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 144},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de la Independencia, 5, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4205629, 'lng': -3.6881813},
#    'viewport': {'northeast': {'lat': 40.42179562989272,
#      'lng': -3.686929320107278},
#     'southwest': {'lat': 40.41909597010728, 'lng': -3.689628979892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'BAKAN MADRID',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 2560,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111033416438119463908">A Google User</a>'],
#     'photo_reference': 'AcYSjRglU8gbGIXXQhQUpx_5ru2PS6-PD8cWN-LbSlcMKBe1-fBKlye4xKcIEXOHsWwQgKvKcmZu8aJ_ZP4nCW1hnn6j7Wrwjht8VCdmE6jy_EfbDLY6wigOdLjtat0i5sNN7GZlDrmGipTCCRaol1IqEr2U1Dn8Uy_EjBGH4vVaRjXmtqF2',
#     'width': 3840}],
#   'place_id': 'ChIJH8oCfgspQg0RwUv2K2zmQFg',
#   'plus_code': {'compound_code': 'C8C6+6P Madrid',
#    'global_code': '8CGRC8C6+6P'},
#   'rating': 4.1,
#   'reference': 'ChIJH8oCfgspQg0RwUv2K2zmQFg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 428},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Cl. de Ayala, 14, 28001 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4278335, 'lng': -3.687870899999999},
#    'viewport': {'northeast': {'lat': 40.42923722989272,
#      'lng': -3.686529820107278},
#     'southwest': {'lat': 40.42653757010728, 'lng': -3.689229479892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Restaurante Tepic',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4016,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/102506515244401635820">Restaurante Tepic</a>'],
#     'photo_reference': 'AcYSjRh4ma_plBIqhEkcZx_hIkIPcKVgHdWOwqiN60u-RAROCzy_jyGDjuP_2hJY1P3Bg8Zpi-IC0HTUTtM-0OcM-KvptS4yyLN69sXhXXHw_3u9zjHEzN6LfKz2QJAswe_FYq9iiA8c8Yk4P4uwiSI-6LPhKF6KRK9JEi4_nMdp2GDnQE3D',
#     'width': 6016}],
#   'place_id': 'ChIJH4FAFYYoQg0RrFgGyrK7nzw',
#   'plus_code': {'compound_code': 'C8H6+4V Madrid',
#    'global_code': '8CGRC8H6+4V'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJH4FAFYYoQg0RrFgGyrK7nzw',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1538},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del Duque de Medinaceli, 12, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4144177, 'lng': -3.695812},
#    'viewport': {'northeast': {'lat': 40.41577762989273,
#      'lng': -3.694414220107278},
#     'southwest': {'lat': 40.41307797010728, 'lng': -3.697113879892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': '100% México, Sucursal Medinaceli',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3144,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108551987781859167870">A Google User</a>'],
#     'photo_reference': 'AcYSjRgcFdbxKuEFqXEhWQhkQm7hkm7WDQ4DpBLMWPzsQlBjMhshd3ZPv4OCTxa-8qVUXoc8_5wujePdvh9MPDMuvZKS1kbeYE_cSwmvsUE-5Lq-0xT2SPEyi2ZqxMLVawZ5xXOrh8FBhGcnduIKzsooAkFqLiHFlV-Izdj5Sf3ZLNaD9sOu',
#     'width': 1960}],
#   'place_id': 'ChIJX0FvXYIoQg0RAq90AG37i78',
#   'plus_code': {'compound_code': 'C873+QM Madrid',
#    'global_code': '8CGRC873+QM'},
#   'rating': 4.5,
#   'reference': 'ChIJX0FvXYIoQg0RAq90AG37i78',
#   'types': ['restaurant',
#    'food',
#    'point_of_interest',
#    'store',
#    'establishment'],
#   'user_ratings_total': 127},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Campomanes, 5, 28013 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4190636, 'lng': -3.7093565},
#    'viewport': {'northeast': {'lat': 40.42037347989272,
#      'lng': -3.708014170107278},
#     'southwest': {'lat': 40.41767382010728, 'lng': -3.710713829892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Sanissimo Opera Vegan',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108355069128391529199">Nuria Cano Ortiz</a>'],
# ...
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 273},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Carrera de S. Jerónimo, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4165998, 'lng': -3.6996331},
#    'viewport': {'northeast': {'lat': 40.41791467989272,
#      'lng': -3.698284920107278},
#     'southwest': {'lat': 40.41521502010728, 'lng': -3.700984579892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Colonia Mexicana en Madrid',
#   'photos': [{'height': 1536,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101785081809477468720">A Google User</a>'],
#     'photo_reference': 'AcYSjRiDtrfij6wgfYFi_59sjZKgx0q-Z4VZeX7DqFv9umXc02M7rpGYSNivxmjzFBCCtdR3nq87zeApDCF4ZmKtNYSXjBWcWYFDaultsThrbYhKtUoOxyYCX7GLp4j-qhtkdKvvwNeO1lXwMQqCBNRiKfmyIBPsVnYPYMi8Jvhd_SpPi_sj',
#     'width': 2048}],
#   'place_id': 'ChIJj0ETF4EoQg0RJ212i1kEOks',
#   'plus_code': {'compound_code': 'C882+J4 Madrid',
#    'global_code': '8CGRC882+J4'},
#   'rating': 4.8,
#   'reference': 'ChIJj0ETF4EoQg0RJ212i1kEOks',
#   'types': ['point_of_interest', 'establishment'],
#   'user_ratings_total': 5},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Valenzuela, 7, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4190267, 'lng': -3.6892853},
#    'viewport': {'northeast': {'lat': 40.42028142989272,
#      'lng': -3.687946620107279},
#     'southwest': {'lat': 40.41758177010728, 'lng': -3.690646279892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Barracuda Mx',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3850,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105142799452975649679">A Google User</a>'],
#     'photo_reference': 'AcYSjRin3ZW2gnxeVU2_0suVImNxNFNVtx3SmpM3ozla8iuDTyE4ArJw-f7UXanDiI6GFsOEEVXgqSd8wQZ2wS9JLOb-NDvnZvPGdUCkpePcp4I2Xfz3t_S-Nib-7ZnKNorZ0qLLhqCJKg4r-TknqIPSzXckTEG42l74iVhebz6ZD-kXda4d',
#     'width': 5266}],
#   'place_id': 'ChIJZQNi-IQpQg0Rn7Miq7-cZCg',
#   'plus_code': {'compound_code': 'C896+J7 Madrid',
#    'global_code': '8CGRC896+J7'},
#   'rating': 4.3,
#   'reference': 'ChIJZQNi-IQpQg0Rn7Miq7-cZCg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 640},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'P.º del Prado, 44, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4102229, 'lng': -3.6928004},
#    'viewport': {'northeast': {'lat': 40.41154817989272,
#      'lng': -3.691702020107279},
#     'southwest': {'lat': 40.40884852010728, 'lng': -3.694401679892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Museo del Jamón',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 587,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106219948164084265391">A Google User</a>'],
#     'photo_reference': 'AcYSjRj4V6xzDeHbNvd7AlEQ4atb3UmUj3qCbsnS2ZImaJsp3QQucJooxDIrfOLBNvFNvP0rsbk__XRhJ5M-k0DlTIIfv3N9KVyjX9hKf725wq1__C9P_UH-gQ3CnQY1F81inVl1KNr_vUiCIfhFRlIZCD0Te4yHlQJw4Q3W9SguzytDJql0',
#     'width': 1024}],
#   'place_id': 'ChIJ3Rd5gigmQg0RzkCQl0gnAO8',
#   'plus_code': {'compound_code': 'C864+3V Madrid',
#    'global_code': '8CGRC864+3V'},
#   'price_level': 1,
#   'rating': 4.1,
#   'reference': 'ChIJ3Rd5gigmQg0RzkCQl0gnAO8',
#   'types': ['store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 4568},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. Puerto Guadarrama, 30, 28935 Móstoles, Madrid, Spain',
#   'geometry': {'location': {'lat': 40.3503956, 'lng': -3.8759405},
#    'viewport': {'northeast': {'lat': 40.35178572989273,
#      'lng': -3.874654420107278},
#     'southwest': {'lat': 40.34908607010728, 'lng': -3.877354079892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'Central Mexicana de Abastos, S.L.',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1322,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117650014263486119901">Central Mexicana de Abastos, S.L.</a>'],
#     'photo_reference': 'AcYSjRgAHAfUrNOiaiivyxSLbfMFHolLfcF6Q3-sZUsDMMo6cXeZ4qQM7m0VaQ0lzS5get_jKHbIR-lPqK3pit3AE4w7d2HgEz2-miofBRicE3Bz4I_Aomj6IaSlPxNZrgP0H5JTIa94C-Vt6z3Q87dGJXiZY1iRQovz0jmJu0wBf5as5nDl',
#     'width': 2048}],
#   'place_id': 'ChIJJ4rJTUOOQQ0RiLaPwZ7mk0Q',
#   'plus_code': {'compound_code': '942F+5J Móstoles',
#    'global_code': '8CGR942F+5J'},
#   'rating': 4,
#   'reference': 'ChIJJ4rJTUOOQQ0RiLaPwZ7mk0Q',
#   'types': ['store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 8},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Av. de Córdoba, 21, Bajo Nave 4, 28026 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.3836244, 'lng': -3.6974497},
#    'viewport': {'northeast': {'lat': 40.38489977989272,
#      'lng': -3.696286720107278},
#     'southwest': {'lat': 40.38220012010728, 'lng': -3.698986379892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/shopping-71.png',
#   'icon_background_color': '#4B96F3',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/shopping_pinlet',
#   'name': 'La Reina de las Tortillas',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 3024,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111785421144419659679">raul venegas</a>'],
#     'photo_reference': 'AcYSjRjcZKk7baarqwOntx016GW9ZSxArhN0ZO5SLapdy6J140Y1e1lqCJePt5GnKQVE_mM3jFA1yQcmaGNFOS78GdQ7fkxCUsOJGlzFLmBre9DQzSNbYMrRaqTEidKCySXL198N5VzgXbLbsBF-KxPmNGUcoL1oM--hqNR_8XVSQCpDrUkn',
#     'width': 4032}],
#   'place_id': 'ChIJn9_0iVMoQg0RcUWPl5ZdpiQ',
#   'plus_code': {'compound_code': '98M3+C2 Madrid',
#    'global_code': '8CGR98M3+C2'},
#   'rating': 4.6,
#   'reference': 'ChIJn9_0iVMoQg0RcUWPl5ZdpiQ',
#   'types': ['store', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 133},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. del León, 10, 28014 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.414209, 'lng': -3.698857},
#    'viewport': {'northeast': {'lat': 40.41552137989272,
#      'lng': -3.697462120107278},
#     'southwest': {'lat': 40.41282172010728, 'lng': -3.700161779892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Brown Bear Bakery',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 1600,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/116180045981010281377">Cosmen &amp; Keiless</a>'],
#     'photo_reference': 'AcYSjRg5F2RPYG7oM3kCD9w8HxsOqRgIyHK53cQdIDvguhA6nBRAAHKZMk_4jJFFW8ySvJlZR4ODVQEKFpI6rJYHYbhynlkr6uzLWPVaQldfbvu-EgKIJ6Fmst1klVnpqXaBsxUM7VjHeTuaT_lLCt67yz9bv5kBXuIFBkcvu-gqYOVU2et7',
#     'width': 2844}],
#   'place_id': 'ChIJ67R5hY8oQg0RoyfidPMc6ww',
#   'plus_code': {'compound_code': 'C872+MF Madrid',
#    'global_code': '8CGRC872+MF'},
#   'price_level': 1,
#   'rating': 4.3,
#   'reference': 'ChIJ67R5hY8oQg0RoyfidPMc6ww',
#   'types': ['bakery',
#    'store',
#    'restaurant',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 590},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Pl. de Alamillo, 8, 28005 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.41376, 'lng': -3.712399999999999},
#    'viewport': {'northeast': {'lat': 40.41506957989272,
#      'lng': -3.711101220107278},
#     'southwest': {'lat': 40.41236992010728, 'lng': -3.713800879892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Taquería del Alamillo',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 4640,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114257084614572077652">Maria DG</a>'],
#     'photo_reference': 'AcYSjRheiqt5lkJervIKnO_343vkl5Fkaw5NoPMH3KnP3C9V9fZ6C7WYQdiAxzwztlkq2x6uVjWfFcEWq0CQSJtcWkRpTeQ1WZ_CO1ikdGURTwDc5edORG6EHX4SP2UNyWem2N6OIbFqU7zgi6nsY3m_lnE5IEeMC8p5nF47DrYh2kjgAlaj',
#     'width': 3472}],
#   'place_id': 'ChIJcyRxF3goQg0RM-9qLmaDIs4',
#   'plus_code': {'compound_code': 'C77Q+G2 Madrid',
#    'global_code': '8CGRC77Q+G2'},
#   'price_level': 2,
#   'rating': 4.2,
#   'reference': 'ChIJcyRxF3goQg0RM-9qLmaDIs4',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1676},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle de Sta Engracia, 63, 28010 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4340429, 'lng': -3.6985594},
#    'viewport': {'northeast': {'lat': 40.43537222989271,
#      'lng': -3.697232820107278},
#     'southwest': {'lat': 40.43267257010726, 'lng': -3.699932479892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png',
#   'icon_background_color': '#7B9EB0',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet',
#   'name': 'Centro Veterinario Los Sauces',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 2252,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106265035493129862155">A Google User</a>'],
#     'photo_reference': 'AcYSjRijDJ-KjeQpzyYqfs7wWCFdfPH667o0sQzJsh_60P51--0Q740nTZmOq1LK2w9rWd1Sona8LgqOx8CyGpkQjkrv08GkMiW7Z0UiAb4Bz2lXtgXzBkfZnmHRimhN1rqfkoMBHxoroLgjdXhePjFlpPd8Dx8aMvK6bCr0-_Qj-RIKBjQ5',
#     'width': 4001}],
#   'place_id': 'ChIJ0306pfQoQg0R15msVNxBFZo',
#   'plus_code': {'compound_code': 'C8M2+JH Madrid',
#    'global_code': '8CGRC8M2+JH'},
#   'rating': 4.4,
#   'reference': 'ChIJ0306pfQoQg0R15msVNxBFZo',
#   'types': ['veterinary_care',
#    'store',
#    'food',
#    'point_of_interest',
#    'establishment'],
#   'user_ratings_total': 757},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Eguilaz, 2, 28010 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4288404, 'lng': -3.7006721},
#    'viewport': {'northeast': {'lat': 40.43017897989272,
#      'lng': -3.699326470107277},
#     'southwest': {'lat': 40.42747932010727, 'lng': -3.702026129892721}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'La Tomata Eguilaz',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 901,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109564805124457564108">A Google User</a>'],
#     'photo_reference': 'AcYSjRgUN_0NT4ffZgjQZFssAxoiejbnY8_UJwT9fuGZFZ62hA6-PKcq_ZR-etGJ0MwuNUp4LAcTnJTgcrCti--m-KGJAzetBZKCXvQpox5kWmo8viOY5D6gepVyr4o6lmY2DMTwy8peDAdnscMSH0gAFRsM0VNA2TwdyYq1O5HxpSQcV_xL',
#     'width': 1600}],
#   'place_id': 'ChIJZzxsHyYpQg0RNYzRymLIxRg',
#   'plus_code': {'compound_code': 'C7HX+HP Madrid',
#    'global_code': '8CGRC7HX+HP'},
#   'rating': 4.6,
#   'reference': 'ChIJZzxsHyYpQg0RNYzRymLIxRg',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 343},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'Calle del Cardenal Cisneros, 13, 28010 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.43012969999999, 'lng': -3.7018408},
#    'viewport': {'northeast': {'lat': 40.43152547989272,
#      'lng': -3.700388420107279},
#     'southwest': {'lat': 40.42882582010727, 'lng': -3.703088079892723}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Tacos Chapultepec',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1080,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/111269446658886849852">Tacos Chapultepec</a>'],
#     'photo_reference': 'AcYSjRh1ibszPDL25C8Z8eAPWRDQ3dqH19l7aLdkEV-k2l2NY2wBmU895kx7vT_0H1n5wuBlHUzLtZzatb1xoK9lTfxpWEjUu9rJp2YVjjoj5nbMGC9DkbG6VsNErmpYmpMGr0bVrExhWrLR8gEHkq0sJvL7tgRIgChAop4f74Yt0i8Sxx0z',
#     'width': 1920}],
#   'place_id': 'ChIJQeCmZ4ooQg0R_FGADG-VVbw',
#   'plus_code': {'compound_code': 'C7JX+37 Madrid',
#    'global_code': '8CGRC7JX+37'},
#   'price_level': 1,
#   'rating': 4.4,
#   'reference': 'ChIJQeCmZ4ooQg0R_FGADG-VVbw',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1536},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de Silvano, 92, 28043 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4625939, 'lng': -3.6369074},
#    'viewport': {'northeast': {'lat': 40.46397592989272,
#      'lng': -3.635561970107278},
#     'southwest': {'lat': 40.46127627010728, 'lng': -3.638261629892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'Minotauro Restaurante Taberna',
#   'opening_hours': {'open_now': True},
#   'photos': [{'height': 672,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/106825804550766707148">A Google User</a>'],
#     'photo_reference': 'AcYSjRglaJhBAJ-73-QJBCHr2HkzHk6ADqkOsHyt0T-ffZ6TzBIQxFRqJqdHH0Tr5dLj4iJNMkE4doHElJ5RfW7ssN4uXWgx0Yxrul_vlFN4Hd9-xdJGwFI8Qm60W3cLzws6aVq8Ksk3Rzo9_mijJpdsQ7b4AePD1ZCI57zePjbvYYqdRgzN',
#     'width': 1200}],
#   'place_id': 'ChIJ58dCneYuQg0RBXkEV_MUe98',
#   'plus_code': {'compound_code': 'F977+26 Madrid',
#    'global_code': '8CGRF977+26'},
#   'price_level': 2,
#   'rating': 4.1,
#   'reference': 'ChIJ58dCneYuQg0RBXkEV_MUe98',
#   'types': ['restaurant', 'bar', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 1648},
#  {'business_status': 'OPERATIONAL',
#   'formatted_address': 'C. de las Fuentes, 3, 28013 Madrid, Spain',
#   'geometry': {'location': {'lat': 40.4169641, 'lng': -3.7087625},
#    'viewport': {'northeast': {'lat': 40.41830517989272,
#      'lng': -3.707400920107279},
#     'southwest': {'lat': 40.41560552010728, 'lng': -3.710100579892722}}},
#   'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#   'icon_background_color': '#FF9E67',
#   'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#   'name': 'La Mordida Fuentes',
#   'opening_hours': {'open_now': False},
#   'photos': [{'height': 1066,
#     'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103576051014517957561">La Mordida</a>'],
#     'photo_reference': 'AcYSjRjA271VY5L-uKSRHGmBRbq9UvNCiYKmOkev2YVYeR_kx97LzQVraiDKNE9Wt3Eba7dWy9OA5XYM3I0ZRk3_w-zc4DSw0BoXk7WmwwT4sqZu3KkLWO25XlJLxl7uLgI4RYzH7EimFjEaYysWl9jP2xBrMxHY19XoSL-E6rKAq4x8ywS4',
#     'width': 1600}],
#   'place_id': 'ChIJV2X8RXkoQg0Rn4DLIk7dnHs',
#   'plus_code': {'compound_code': 'C78R+QF Madrid',
#    'global_code': '8CGRC78R+QF'},
#   'price_level': 2,
#   'rating': 4.3,
#   'reference': 'ChIJV2X8RXkoQg0Rn4DLIk7dnHs',
#   'types': ['restaurant', 'food', 'point_of_interest', 'establishment'],
#   'user_ratings_total': 2543}]

# %% [markdown]
# Definimos los Custom Fields necesarios para el dataset

# %%
fecha=datetime.now().strftime("%d-%m-%Y")
hora=datetime.now().strftime("%H")
normalize['fecha']=fecha
normalize['hora']=hora
normalize['busqueda']=comida
normalize['pais']=pais
normalize['ciudad']=ciudad
normalize['zona']=barrio

normalize['name'] = normalize['name'].replace(u"\U0001F354",value="", regex=True)
normalize['name'] = normalize['name'].replace(u"\U0001F35F",value="", regex=True)

normalize['clave']= normalize['place_id']+' '+normalize['fecha']

# %% [markdown]
# Generamos la lista de campos a mostrar en el DF

# %%
df_col= [
        'business_status'
        ,'name'
        ,'opening_hours.open_now'
        ,'place_id'
        ,'price_level'
        ,'rating'
        #,'types'
        ,'user_ratings_total'
        ,'fecha'
        ,'hora'
        ,'busqueda'
        ,'geometry.location.lng'
        ,'geometry.location.lat'
        ,'formatted_address'
        ,'clave'
        ,'pais'
        ,'ciudad'
        ,'zona'
        ]
df = normalize[df_col]

# %% [markdown]
# Cargamos datos a la BBDD MariaDB

# %%
engine = create_engine("mysql+pymysql://{user}:{pw}@127.0.0.1/{db}"
                       .format(user="root",
                               pw="MariaDB1.2.3",
                               db="restaurants_maps"))

df.to_sql('restaurants_api', con=engine,if_exists='append', chunksize=1000)
# Out:
# 60
