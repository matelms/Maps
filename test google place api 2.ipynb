# %%
import googlemaps
import pandas as pd
import time
from datetime import datetime
from datetime import date
import seaborn as sns

fecha=datetime.now().strftime("%d-%m-%Y")
hora=datetime.now().strftime("%H")

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'
#API_KEY = open('API_KEy.txt','r').read()

# Define the Client
gmaps = googlemaps.Client(API_KEY)


#pip install easygui
import easygui
#location= easygui.enterbox(msg="latitud (xx.x), longitud (yy.y)")
#search_string= easygui.enterbox(msg="introduzca tipo de comida")
#distance= easygui.enterbox(msg="radio de busqueda (m) MÁXIMO 100.000")
# Prints--> Bob <class 'str'> 150 <class 'int'>

location = (40.424941441889885, -3.6581815406804017)
search_string = 'Fisioterapia'
distance = 100
list = []
#dir(gmaps)

response = gmaps.places_nearby(location=location,
                    keyword=search_string,
                    radius=distance)

#response
#response.keys()

list.extend(response.get('results'))

next_page_token = response.get('next_page_token')

while next_page_token:
    time.sleep(2)
    response = gmaps.places_nearby(location=location,
                    keyword=search_string,
                    radius=distance,
                    page_token=next_page_token)
    list.extend(response.get('results'))
    next_page_token = response.get('next_page_token')

df = pd.DataFrame(list)
df['fecha']=fecha
df['hora']=hora
df['busqueda']=search_string
df['coordenadas']=location
df
df_col= [
        'business_status'
        ,'geometry'
        ,'formatted_phone_number'
        ,'name'
        ,'opening_hours'
        ,'place_id'
        ,'price_level'
        ,'rating'
        ,'types'
        ,'user_ratings_total'
        ,'vicinity'
        ,'fecha'
        ,'hora'
        ,'busqueda'
        ,'coordenadas'
        ]
df1 = df[df_col]

df1['name'] = df1['name'].replace(u"\U0001F354",value="", regex=True)
df1['name'] = df1['name'].replace(u"\U0001F35F",value="", regex=True)

df1['clave']=df1['place_id']+' '+df1['fecha']




df1.head(4)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# matelms\Maps\test google place api 2.ipynb Celda 1 in <cell line: 75>()
#      <a href='vscode-notebook-cell://github/matelms/Maps/test%20google%20place%20api%202.ipynb#W0sdnNjb2RlLXZmcw%3D%3D?line=56'>57</a> df
#      <a href='vscode-notebook-cell://github/matelms/Maps/test%20google%20place%20api%202.ipynb#W0sdnNjb2RlLXZmcw%3D%3D?line=57'>58</a> df_col= [
#      <a href='vscode-notebook-cell://github/matelms/Maps/test%20google%20place%20api%202.ipynb#W0sdnNjb2RlLXZmcw%3D%3D?line=58'>59</a>         'business_status'
#      <a href='vscode-notebook-cell://github/matelms/Maps/test%20google%20place%20api%202.ipynb#W0sdnNjb2RlLXZmcw%3D%3D?line=59'>60</a>         ,'geometry'
#    (...)
# ...

# %%
import googlemaps
import pandas as pd
import time
from datetime import datetime
from datetime import date
import seaborn as sns

fecha=datetime.now().strftime("%d-%m-%Y")
hora=datetime.now().strftime("%H")

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'
#API_KEY = open('API_KEy.txt','r').read()

# Define the Client
gmaps = googlemaps.Client(API_KEY)


#pip install easygui
import easygui
#location= easygui.enterbox(msg="latitud (xx.x), longitud (yy.y)")
#search_string= easygui.enterbox(msg="introduzca tipo de comida")
#distance= easygui.enterbox(msg="radio de busqueda (m) MÁXIMO 100.000")
# Prints--> Bob <class 'str'> 150 <class 'int'>

location = (40.424941441889885, -3.6581815406804017)
search_string = 'pizza'
distance = 100
list = []
dir(gmaps)

response = gmaps.places_nearby(location=location,
                    keyword=search_string,
                    radius=distance)

#response
#response.keys()

list.extend(response.get('results'))

next_page_token = response.get('next_page_token')

while next_page_token:
    time.sleep(2)
    response = gmaps.places_nearby(location=location,
                    keyword=search_string,
                    radius=distance,
                    page_token=next_page_token)
    list.extend(response.get('results'))
    next_page_token = response.get('next_page_token')

df = pd.DataFrame(list)
df
# Out:
#   business_status                                           geometry  \
# 0     OPERATIONAL  {'location': {'lat': 40.423506, 'lng': -3.6554...
#
#                                                 icon icon_background_color  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...               #FF9E67
#
#                                   icon_mask_base_uri           name  \
# 0  https://maps.gstatic.com/mapfiles/place_api/ic...  Pizza & Gatos
#
#          opening_hours                                             photos  \
# 0  {'open_now': False}  [{'height': 908, 'html_attributions': ['<a hre...
#
#                       place_id  \
# 0  ChIJg_kF6rgvQg0RYY4bD9PXcYA
#
#                                            plus_code  price_level  rating  \
# 0  {'compound_code': 'C8FV+CR Madrid', 'global_co...            1     4.8
#
#                      reference   scope  \
# 0  ChIJg_kF6rgvQg0RYY4bD9PXcYA  GOOGLE
#
# ...

# %%
df_col2= [
        'business_status'
       # ,'geometry'
        ,'name'
        ,'place_id'
        ,'price_level'
        ,'rating'
        ,'user_ratings_total'
        ,'vicinity'
        ,'busqueda'
        ,'coordenadas'
        ,'fecha'
        ,'hora'
        ,'clave'
        ]
df2 = df1[df_col2]
df2
# Out:
#    business_status                                          name  \
# 0      OPERATIONAL                                   Steakburger
# 1      OPERATIONAL                                   Steakburger
# 2      OPERATIONAL                        Naif Madrid Burger&bar
# 3      OPERATIONAL                               Criminal burger
# 4      OPERATIONAL                                 Pasion Burger
# 5      OPERATIONAL                               BASICS by Goiko
# 6      OPERATIONAL                                         Goiko
# 7      OPERATIONAL                                         VICIO
# 8      OPERATIONAL                       Chivuo's - San Bernardo
# 9      OPERATIONAL                                     Milwaukee
# 10     OPERATIONAL          Juancho's BBQ (Mercado de San Antón)
# 11     OPERATIONAL                               Makato’s Burger
# 12     OPERATIONAL                               SteakBurger Bar
# ...

# %%
#df1[['opening_hours2']]  = df1[['opening_hours']].replace('open_now',value='',regex=True)
#df1[['opening_hours']]  = df1[['opening_hours']].replace("}",value='',regex=True)
#df1[['lat','lng']]  = df1['geometry'].str.split(":",1,expand=True)
#df1

# %%
import pymysql
from sqlalchemy import create_engine

engine = create_engine("mysql+pymysql://{user}:{pw}@127.0.0.1/{db}"
                       .format(user="root",
                               pw="MariaDB1.2.3",
                               db="restaurants_maps"))

df2.to_sql('restaurants_api', con=engine,if_exists='append', chunksize=1000)
# Out:
# 35
