# %%
import selenium
from selenium import webdriver
import pandas as pd
from datetime import date
#!pip install textblob
from textblob import TextBlob
import seaborn as sns
from selenium.webdriver.common.keys import Keys

# %%
#pip install easygui
import easygui
ciudad= easygui.enterbox(msg="Introduzca Ciudad")
barrio= easygui.enterbox(msg="Introduzca Zona/Barrio")
comida= easygui.enterbox(msg="Introduzca Tipo de comida")#integerbox(msg="Introduzca Tipo de comida", upperbound=999)
print(ciudad, type(ciudad), comida, type(comida)) 
# Prints--> Bob <class 'str'> 150 <class 'int'>
# Out:
# Suances <class 'str'>  <class 'str'>

# %%
browser = webdriver.Chrome()
#ciudad ="Suances, Cantabria"
#comida = ""
browser.get('https://www.google.es/maps/search/Restaurantes+'+ciudad+'+'+barrio+'+'+comida+'/') # si queremos añadir una ciudad tenemos que meter "+Ciudad"
delay = 5 # seconds

# %%
botonaceptar = "//button[@class='VfPpkd-LgbsSe VfPpkd-LgbsSe-OWXEXe-k8QpJ VfPpkd-LgbsSe-OWXEXe-dgl2Hf nCP5yc AjY5Oe DuMIQc LQeN7 Nc7WLe']"
aceptar = browser.find_element("xpath",botonaceptar)
aceptar.click()

# %%
import ctypes
ctypes.windll.user32.MessageBoxW(0, "Please go to the google Chrome page and scroll down the left tab until all the restaurants are loaded", "Action Neccesary", 48)

## Button styles:
# 0 : OK
# 1 : OK | Cancel
# 2 : Abort | Retry | Ignore
# 3 : Yes | No | Cancel
# 4 : Yes | No
# 5 : Retry | No 
# 6 : Cancel | Try Again | Continue

## Icon styles
# 16 Stop-sign icon
# 32 Question-mark icon
# 48 Exclamation-point icon
# 64 Information-sign icon consisting of an 'i' in a circle
# Out:
# 1

# %%
num=len(browser.find_elements("xpath","//div[@class='Nv2PK THOPZb CpccDe']"))
print(num)

list_pais=[]
for i in range(0,num):
    titular=browser.find_elements("xpath","//div[@class='Nv2PK THOPZb CpccDe']")[i].text
    list_pais.append(titular)

dfMaps=pd.DataFrame(list_pais)
dfMaps['Origen']='Maps'
dfMaps
# Out:
# 73
#                                                     0 Origen
# 0   Restaurante La Solita Suances\n4,3(1.079) · €€...   Maps
# 1   Restaurante La Dársena de Suances\n4,3(4.119) ...   Maps
# 2   Restaurante Amita\n4,5(2.579) · €€\nMarisco · ...   Maps
# 3   Restaurante Bonito Verde\n4,5(720) · €€\nResta...   Maps
# 4   Restaurante la Duna\n4,5(320)\nRestaurante · P...   Maps
# ..                                                ...    ...
# 68  El Limonero De Santa Ana\nNo hay reseñas\nRest...   Maps
# 69  La casona de los judíos\nNo hay reseñas\nResta...   Maps
# 70  Buen Restaurante En...\nNo hay reseñas\nRestau...   Maps
# 71  Cerveceria La Surena\nNo hay reseñas\nRestaura...   Maps
# 72  El Bálamo\nNo hay reseñas\nRestaurante · Pl. V...   Maps
#
# [73 rows x 2 columns]

# %%
dfMaps_Columns = dfMaps[0].str.split('\n', expand=True)
dfMaps_Columns[['Rating','Reviews']] = dfMaps_Columns[1].str.split('(',1,expand=True)
dfMaps_Columns[['Reviews','Price']]  = dfMaps_Columns['Reviews'].str.split("\)",1,expand=True)
dfMaps_Columns[['Price']]            = dfMaps_Columns[['Price']].replace('·',value='')
dfMaps_Columns['Ciudad']           = ciudad
dfMaps_Columns['Tipo Busqueda']    = comida
dfMaps_Columns['Zona']             = barrio



dfMaps_Columns
# Out:
#                                     0                1  \
# 0       Restaurante La Solita Suances  4,3(1.079) · €€
# 1   Restaurante La Dársena de Suances  4,3(4.119) · €€
# 2                   Restaurante Amita  4,5(2.579) · €€
# 3            Restaurante Bonito Verde    4,5(720) · €€
# 4                 Restaurante la Duna         4,5(320)
# ..                                ...              ...
# 68           El Limonero De Santa Ana   No hay reseñas
# 69            La casona de los judíos   No hay reseñas
# 70             Buen Restaurante En...   No hay reseñas
# 71               Cerveceria La Surena   No hay reseñas
# 72                          El Bálamo   No hay reseñas
#
#                                               2  \
# 0                    Marisco · C. el Muelle, 25
# 1                Restaurante · C. el Muelle, 23
# 2                   Marisco · C. Torrelavega, 5
# 3   Restaurante · P.º de la Marina Española, 10
# 4   Restaurante · P.º de la Marina Española, 10
# ..                                          ...
# 68     Restaurante · C. de Acacio Gutiérrez, 98
# 69  Restaurante · P.º de la Marina Española, 10
# 70              Restaurante · C. Torrelavega, 5
# 71                Restaurante · C. el Muelle, 1
# 72                     Restaurante · Pl. Viares
#
#                                                     3  \
# 0                         Abierto ⋅ Cierra a las 0:00
# 1                Pescado y marisco en mesas elegantes
# 2          Restaurante rústico con comida contundente
# 3   Abierto ⋅ Cierra a las 16:00 ⋅ Próxima apertur...
# 4   Abierto ⋅ Cierra a las 17:00 ⋅ Próxima apertur...
# ..                                                ...
# 68                              Cerrado temporalmente
# 69                              Cerrado temporalmente
# 70                              Cerrado temporalmente
# 71                              Cerrado temporalmente
# 72                              Cerrado temporalmente
#
#                                                     4             5  \
# 0                                          Comer allí             ·
# 1                         Abierto ⋅ Cierra a las 0:00    Comer allí
# 2   Abierto ⋅ Cierra a las 17:00 ⋅ Próxima apertur...    Comer allí
# 3                                          Comer allí             ·
# 4                                          Comer allí             ·
# ..                                                ...           ...
# 68                                               None          None
# 69                                               None          None
# 70                                               None          None
# 71                                               None          None
# 72                                               None          None
#
#               6            7                           8  \
# 0   Para llevar            ·  No hay entrega a domicilio
# 1             ·  Para llevar                           ·
# 2             ·  Para llevar                           ·
# 3   Para llevar            ·  No hay entrega a domicilio
# 4   Para llevar            ·  No hay entrega a domicilio
# ..          ...          ...                         ...
# 68         None         None                        None
# 69         None         None                        None
# 70         None         None                        None
# 71         None         None                        None
# 72         None         None                        None
#
#                              9    10    11    12    13          Rating  \
# 0                         None  None  None  None  None             4,3
# 1                  A domicilio  None  None  None  None             4,3
# 2   No hay entrega a domicilio  None  None  None  None             4,5
# 3                         None  None  None  None  None             4,5
# 4                         None  None  None  None  None             4,5
# ..                         ...   ...   ...   ...   ...             ...
# 68                        None  None  None  None  None  No hay reseñas
# 69                        None  None  None  None  None  No hay reseñas
# 70                        None  None  None  None  None  No hay reseñas
# 71                        None  None  None  None  None  No hay reseñas
# 72                        None  None  None  None  None  No hay reseñas
#
#    Reviews  Price   Ciudad Tipo Busqueda Zona
# 0    1.079   · €€  Suances
# 1    4.119   · €€  Suances
# 2    2.579   · €€  Suances
# 3      720   · €€  Suances
# 4      320         Suances
# ..     ...    ...      ...           ...  ...
# 68    None   None  Suances
# 69    None   None  Suances
# 70    None   None  Suances
# 71    None   None  Suances
# 72    None   None  Suances
#
# [73 rows x 20 columns]

# %%
col_list = [0, 1,2,3,4,5,'Rating','Reviews','Price',"Ciudad","Tipo Busqueda","Zona"]
dfMaps_Columns_selected = dfMaps_Columns[col_list]
dfMaps_Columns_selected
# Out:
#                                     0                1  \
# 0       Restaurante La Solita Suances  4,3(1.079) · €€
# 1   Restaurante La Dársena de Suances  4,3(4.119) · €€
# 2                   Restaurante Amita  4,5(2.579) · €€
# 3            Restaurante Bonito Verde    4,5(720) · €€
# 4                 Restaurante la Duna         4,5(320)
# ..                                ...              ...
# 68           El Limonero De Santa Ana   No hay reseñas
# 69            La casona de los judíos   No hay reseñas
# 70             Buen Restaurante En...   No hay reseñas
# 71               Cerveceria La Surena   No hay reseñas
# 72                          El Bálamo   No hay reseñas
#
#                                               2  \
# 0                    Marisco · C. el Muelle, 25
# 1                Restaurante · C. el Muelle, 23
# 2                   Marisco · C. Torrelavega, 5
# 3   Restaurante · P.º de la Marina Española, 10
# 4   Restaurante · P.º de la Marina Española, 10
# ..                                          ...
# 68     Restaurante · C. de Acacio Gutiérrez, 98
# 69  Restaurante · P.º de la Marina Española, 10
# 70              Restaurante · C. Torrelavega, 5
# 71                Restaurante · C. el Muelle, 1
# 72                     Restaurante · Pl. Viares
#
#                                                     3  \
# 0                         Abierto ⋅ Cierra a las 0:00
# 1                Pescado y marisco en mesas elegantes
# 2          Restaurante rústico con comida contundente
# 3   Abierto ⋅ Cierra a las 16:00 ⋅ Próxima apertur...
# 4   Abierto ⋅ Cierra a las 17:00 ⋅ Próxima apertur...
# ..                                                ...
# 68                              Cerrado temporalmente
# 69                              Cerrado temporalmente
# 70                              Cerrado temporalmente
# 71                              Cerrado temporalmente
# 72                              Cerrado temporalmente
#
#                                                     4             5  \
# 0                                          Comer allí             ·
# 1                         Abierto ⋅ Cierra a las 0:00    Comer allí
# 2   Abierto ⋅ Cierra a las 17:00 ⋅ Próxima apertur...    Comer allí
# 3                                          Comer allí             ·
# 4                                          Comer allí             ·
# ..                                                ...           ...
# 68                                               None          None
# 69                                               None          None
# 70                                               None          None
# 71                                               None          None
# 72                                               None          None
#
#             Rating Reviews  Price   Ciudad Tipo Busqueda Zona
# 0              4,3   1.079   · €€  Suances
# 1              4,3   4.119   · €€  Suances
# 2              4,5   2.579   · €€  Suances
# 3              4,5     720   · €€  Suances
# 4              4,5     320         Suances
# ..             ...     ...    ...      ...           ...  ...
# 68  No hay reseñas    None   None  Suances
# 69  No hay reseñas    None   None  Suances
# 70  No hay reseñas    None   None  Suances
# 71  No hay reseñas    None   None  Suances
# 72  No hay reseñas    None   None  Suances
#
# [73 rows x 12 columns]

# %%
from datetime import datetime
fecha=datetime.now().strftime("%d_%m_%Y")
hora=datetime.now().strftime("%H")
dfMaps_Columns_selected.to_excel('Ficheros/'+ciudad+'&'+barrio+'&'+comida+'&'+fecha+'&'+hora+'.xlsx')

# %%
ctypes.windll.user32.MessageBoxW(0, "File has been generated successfully", "Thanks for your patience", 48)
# Out:
# 1
