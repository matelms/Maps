# %%
#ejemplo de consulta por string

import time
import googlemaps

import requests

#pip install easygui
#import easygui
#comunidad= easygui.enterbox(msg="Introduzca CCAA")
#ciudad= easygui.enterbox(msg="Introduzca Ciudad")
#barrio= easygui.enterbox(msg="Introduzca Zona/Barrio")
#comida= easygui.enterbox(msg="Introduzca Tipo de comida")#integerbox(msg="Introduzca Tipo de comida", upperbound=999)
#print(ciudad, type(ciudad), comida, type(comida)) 
# Prints--> Bob <class 'str'> 150 <class 'int'>

#url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query="+comida+"%20in%20"+comunidad+ciudad+barrio+"&key=AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY"
url = "https://maps.googleapis.com/maps/api/place/textsearch/json?query=Pizza%20in%20Elipay&key=--"

payload={}
headers = {}
list=[]
response = requests.request("GET", url, headers=headers, data=payload )
  
print(response.text)
#list.extend(response.get('results'))
#next_page_token=response.get('next_page_token')
#print(list)

#AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY
# Out:
# {
#    "html_attributions" : [],
#    "results" : [
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "C. de Máiquez, 25, 28009 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.41711610000001,
#                "lng" : -3.673079
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.41846887989272,
#                   "lng" : -3.671786120107278
#                },
#                "southwest" : {
#                   "lat" : 40.41576922010728,
#                   "lng" : -3.674485779892722
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Piazzere (Allo Pizza Maiquez)",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 800,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/114502155647528530932\"\u003eAllo Pizza\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3dUtm-DkQ1uiozfINDwuiIPZv37BqqhaU9VRHyf-fsPAE0uXjVhfUYPPzhotzdDHuBBFP37qD81iDu0w9DYhllSx0eSU3mCRrAqahXJE5tnp_RIDt35QYZV7AY7ddodtJ9FKDVtnDZACPtb8CD1aRdjDJJFCXkr4XgkhI-tKyM_LENl",
#                "width" : 1200
#             }
#          ],
#          "place_id" : "ChIJbYaCJaYoQg0Ru-fiagC6nBg",
#          "plus_code" : {
#             "compound_code" : "C88G+RQ Madrid",
#             "global_code" : "8CGRC88G+RQ"
#          },
#          "price_level" : 1,
#          "rating" : 4.1,
#          "reference" : "ChIJbYaCJaYoQg0Ru-fiagC6nBg",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "meal_delivery",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 139
#       },
#       {
#          "business_status" : "CLOSED_TEMPORARILY",
#          "formatted_address" : "Pje. Virgen de la Alegría, 6, 28027 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4342258,
#                "lng" : -3.6569603
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.43551157989272,
#                   "lng" : -3.655574770107278
#                },
#                "southwest" : {
#                   "lat" : 40.43281192010728,
#                   "lng" : -3.658274429892722
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "PDeliciousizza",
#          "permanently_closed" : true,
#          "photos" : [
#             {
#                "height" : 4032,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/105759135078057804264\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3dq3J0UNwQDqp59nuzMmaBYPClXuoRSCEM4fd6pI63cwMHSTWvk2CpO8ENCfia5vIMAsQ6L5ggCkZiVTpDPhKCrjeU5kWtLrGC0zfV5NLOdUuJq68GLIt6vGHq6-Ko0QQ-kcxQJzkDZv4a2JZkenDRlcywYc-XnNzQOUF1Yff3nfNyU",
#                "width" : 2268
#             }
#          ],
#          "place_id" : "ChIJqW6wZe4vQg0RbiwHJEjG3JQ",
#          "plus_code" : {
#             "compound_code" : "C8MV+J6 Madrid",
#             "global_code" : "8CGRC8MV+J6"
#          },
#          "rating" : 5,
#          "reference" : "ChIJqW6wZe4vQg0RbiwHJEjG3JQ",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 5
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "C. Eloy Gonzalo, 10, 28010 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4337343,
#                "lng" : -3.7027922
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.43516062989272,
#                   "lng" : -3.701585420107279
#                },
#                "southwest" : {
#                   "lat" : 40.43246097010728,
#                   "lng" : -3.704285079892723
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Perrachica",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 2160,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/101918944301376301067\"\u003eIsabel Torre Rodríguez\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3dUpskkAL5UiFW0m1J2fw-I9CfsOyBvDZsmcjhLLSmXWpOanRRRYNTBA8EabgoUFTVDjvnOxMYcELEsQ5CINJkPIFe_yja8E1ucoUHo8cos70PEuwMwa5CHOFX8sBBfRqIkzqaFQ94x7jKkKzOxKtLp-GYvkteIByhU5oPa81JiUgx5",
#                "width" : 3840
#             }
#          ],
#          "place_id" : "ChIJZ3Wh-V8oQg0RwVByFBg-6xM",
#          "plus_code" : {
#             "compound_code" : "C7MW+FV Madrid",
#             "global_code" : "8CGRC7MW+FV"
#          },
#          "price_level" : 2,
#          "rating" : 3.9,
#          "reference" : "ChIJZ3Wh-V8oQg0RwVByFBg-6xM",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 8151
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "C. de Melchor Fernández Almagro, 31, 28029 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4774855,
#                "lng" : -3.6997671
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.47891367989272,
#                   "lng" : -3.698442020107278
#                },
#                "southwest" : {
#                   "lat" : 40.47621402010728,
#                   "lng" : -3.701141679892721
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/generic_business-71.png",
#          "icon_background_color" : "#7B9EB0",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/generic_pinlet",
#          "name" : "Telepizza Barrio del Pilar - Comida a domicilio",
#          "opening_hours" : {
#             "open_now" : true
#          },
#          "photos" : [
#             {
#                "height" : 689,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/108435174895446454215\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3dWv3H9dKikjw_XLjPc1DymzfzGcXIL4hPLVXK1zwChqAGVt3rKYUj-U9DAaJV2qADSojWkyR_H2A55Oo5vGDtOkIRf-dE-oL45fZPCVFxL--ZSTm78AX-yyH-wmoOv61a1Yov7nYNNsPeWDBn4-aE_KFu8O0vEkuJiuNn9uaeFVDYi",
#                "width" : 968
#             }
#          ],
#          "place_id" : "ChIJDZjPTnQpQg0RkwADknSoVb8",
#          "plus_code" : {
#             "compound_code" : "F8G2+X3 Madrid",
#             "global_code" : "8CGRF8G2+X3"
#          },
#          "price_level" : 1,
#          "rating" : 3.6,
#          "reference" : "ChIJDZjPTnQpQg0RkwADknSoVb8",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "meal_delivery",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 67
#       },
#       {
#          "business_status" : "OPERATIONAL",
#          "formatted_address" : "Calle del Dr. Fleming, 31, 28036 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.46105,
#                "lng" : -3.6880413
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.46243872989272,
#                   "lng" : -3.686600270107278
#                },
#                "southwest" : {
#                   "lat" : 40.45973907010728,
#                   "lng" : -3.689299929892722
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Tropikal Luxury Buffet",
#          "opening_hours" : {
#             "open_now" : false
#          },
#          "photos" : [
#             {
#                "height" : 3648,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/102282320863450766713\"\u003eA Google User\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3f3dX4jaFpZTbGCpeXVybLtf4rZM7d8SXyyoSYCqCxCZcxU4_AXMNEReIdx0_aDy7USCKNcW7khf79j8nyyzfd3Ze69I_B8mecNGRsmb_xqD7eDI4FxnVXsnkwYYq76BjvtOS8eRiYmgRlBQN11tR7mx4N7gegh9jkWeElTf4HOTsnL",
#                "width" : 5472
#             }
#          ],
#          "place_id" : "ChIJCRmw0BspQg0RdHPLlxvAeqM",
#          "plus_code" : {
#             "compound_code" : "F866+CQ Madrid",
#             "global_code" : "8CGRF866+CQ"
#          },
#          "price_level" : 2,
#          "rating" : 4.3,
#          "reference" : "ChIJCRmw0BspQg0RdHPLlxvAeqM",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 1368
#       },
#       {
#          "business_status" : "CLOSED_PERMANENTLY",
#          "formatted_address" : "C. de Alcalá, 238, 28027 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4317836,
#                "lng" : -3.6568145
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.43309942989271,
#                   "lng" : -3.655476270107278
#                },
#                "southwest" : {
#                   "lat" : 40.43039977010727,
#                   "lng" : -3.658175929892722
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Net Pizza",
#          "permanently_closed" : true,
#          "place_id" : "ChIJiZEKfEkvQg0Rsn5VZFNkjbU",
#          "plus_code" : {
#             "compound_code" : "C8JV+P6 Madrid",
#             "global_code" : "8CGRC8JV+P6"
#          },
#          "rating" : 4,
#          "reference" : "ChIJiZEKfEkvQg0Rsn5VZFNkjbU",
#          "types" : [ "restaurant", "food", "point_of_interest", "establishment" ],
#          "user_ratings_total" : 1
#       },
#       {
#          "business_status" : "CLOSED_PERMANENTLY",
#          "formatted_address" : "C. de Alcalá, 211, 28028 Madrid, Spain",
#          "geometry" : {
#             "location" : {
#                "lat" : 40.4295531,
#                "lng" : -3.6663642
#             },
#             "viewport" : {
#                "northeast" : {
#                   "lat" : 40.43079212989272,
#                   "lng" : -3.664921920107278
#                },
#                "southwest" : {
#                   "lat" : 40.42809247010727,
#                   "lng" : -3.667621579892721
#                }
#             }
#          },
#          "icon" : "https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png",
#          "icon_background_color" : "#FF9E67",
#          "icon_mask_base_uri" : "https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet",
#          "name" : "Al Natural Pasta y Pizza",
#          "permanently_closed" : true,
#          "photos" : [
#             {
#                "height" : 3024,
#                "html_attributions" : [
#                   "\u003ca href=\"https://maps.google.com/maps/contrib/113399692828107314826\"\u003eMario Rodarte\u003c/a\u003e"
#                ],
#                "photo_reference" : "AeJbb3dYp7mL7MZh_xHbi9Qw0Sy82NDjXoozh888E-rlXx_qraUuTeZ8apRbeQAR4H-sYJUbUrT1SATZ1B_orSe8_fxQ8KZwITdwTb47e4UbR6ClXYZcd0jzhIw-w2yY1CrLjL2wyqdnjA7cFweuRuxOOID3Gn5S0gRjQ-pzNtpg-W2Nz_Lq",
#                "width" : 4032
#             }
#          ],
#          "place_id" : "ChIJpd3hCrQoQg0RzBfQSjJYPSA",
#          "plus_code" : {
#             "compound_code" : "C8HM+RF Madrid",
#             "global_code" : "8CGRC8HM+RF"
#          },
#          "rating" : 3.9,
#          "reference" : "ChIJpd3hCrQoQg0RzBfQSjJYPSA",
#          "types" : [
#             "meal_takeaway",
#             "restaurant",
#             "meal_delivery",
#             "food",
#             "point_of_interest",
#             "establishment"
#          ],
#          "user_ratings_total" : 20
#       }
#    ],
#    "status" : "OK"
# }

# %%
# import the library
import googlemaps
import json
import pprint
import xlsxwriter
import time

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# Do a simple nearby search where we specify the location
# in lat/lon format, along with a radius measured in meters
places_result  = gmaps.places_nearby(location='40.4260586,-3.6554541', radius = 40000, open_now =False , type = 'Pizza')

time.sleep(3)

place_result  = gmaps.places_nearby(page_token = places_result['next_page_token'])

stored_results = []

# loop through each of the places in the results, and get the place details.      
for place in places_result['results']:

    # define the place id, needed to get place details. Formatted as a string.
    my_place_id = place['place_id']

    # define the fields you would liked return. Formatted as a list.
    my_fields = ['place_id','name','formatted_phone_number','website','rating','user_ratings_total','price_level','adr_address','geometry/location/lat','geometry/viewport/southwest/lng']

    # make a request for the details.
    places_details  = gmaps.place(place_id= my_place_id , fields= my_fields)

    # print the results of the details, returned as a dictionary.
    pprint.pprint(places_details['result'])

    # store the results in a list object.
    stored_results.append(places_details['result'])

stored_results
# -------------- DUMPING VALUES IN EXCEL -----------------------

# define the headers, that is just the key of each result dictionary.
row_headers = stored_results[0].keys()

# create a new workbook and a new worksheet.
workbook = xlsxwriter.Workbook(r'C:\Users\vir_d\Desktop\Luis\Cloned Git\Maps\data.xlsx')
worksheet = workbook.add_worksheet()

# populate the header row
col = 0
for header in row_headers:
    worksheet.write(0, col, header)
    col += 1

row = 1
col = 0
# populate the other rows

# get each result from the list.
for result in stored_results:

    # get the values from each result.
    result_values = result.values()

    # loop through each value in the values component.
    for value in result_values:
        worksheet.write(row, col, value)
        col += 1
    
    # make sure to go to the next row & reset the column.
    row += 1
    col = 0

# close the workbook
workbook.close()
# Out:
# {'adr_address': '<span class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'geometry': {'location': {'lat': 40.4167754},
#               'viewport': {'southwest': {'lng': -3.834161809872056}}},
#  'name': 'Madrid',
#  'place_id': 'ChIJgTwKgJcpQg0RaSKMYcHeNsQ'}
# {'adr_address': '<span class="street-address">Calle de O&#39;Donnell, '
#                 '53</span>, <span class="postal-code">28009</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '912 21 40 60',
#  'geometry': {'location': {'lat': 40.42163979999999},
#               'viewport': {'southwest': {'lng': -3.673443830291503}}},
#  'name': 'Novotel Madrid Center',
#  'place_id': 'ChIJDwAbC68oQg0RPprMWIWGHeg',
#  'rating': 4.4,
#  'user_ratings_total': 6849,
#  'website': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=9298&merchantid=seo-maps-ES-9298&sourceid=aw-cen&utm_medium=seo+maps&utm_source=google+Maps&utm_campaign=seo+maps&y_source=1_MTUzNjI1MDQtNzE1LWxvY2F0aW9uLndlYnNpdGU%3D'}
# {'adr_address': '28007, <span class="street-address">C. del Pez Volador, 1 - '
#                 '11</span>, <span class="postal-code">28007</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '914 00 99 00',
#  'geometry': {'location': {'lat': 40.413348},
#               'viewport': {'southwest': {'lng': -3.670349799999999}}},
#  'name': 'Ayre Gran Hotel Colón',
#  'place_id': 'ChIJVRM2bwImQg0Re_AMhbbsz4o',
#  'rating': 4.2,
#  'user_ratings_total': 4108,
#  'website': 'https://www.ayrehoteles.com/hoteles/ayre-gran-hotel-colon/?utm_source=mybusiness&utm_medium=organic&utm_campaign=colon'}
# {'adr_address': '<span class="street-address">Avenida de América, 32</span>, '
#                 '<span class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '912 12 50 00',
#  'geometry': {'location': {'lat': 40.438834},
#               'viewport': {'southwest': {'lng': -3.674161430291501}}},
#  'name': 'Abba Madrid Hotel',
#  'place_id': 'ChIJ7YAcBMYoQg0RRIktdFKHSE0',
#  'rating': 4.4,
#  'user_ratings_total': 2006,
#  'website': 'https://www.abbahoteles.com/es/destinos/abba-madrid-hotel/hotel.html'}
# {'adr_address': '<span class="street-address">C. de Torrelaguna, 69</span>, '
#                 '<span class="postal-code">28027</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '914 05 73 93',
#  'geometry': {'location': {'lat': 40.4444102},
#               'viewport': {'southwest': {'lng': -3.656453580291502}}},
#  'name': 'Travelodge Madrid Torrelaguna',
#  'place_id': 'ChIJFXHC0jEvQg0RZotgZajZCjA',
#  'rating': 3.8,
#  'user_ratings_total': 1314,
#  'website': 'https://travelodge.es/travelodge-destino-madrid/hotel-travelodge-madrid-torrelaguna-googleads/?utm_source=GOOGLE-MY-BUSINESS&utm_medium=ESP-TORRELAGUNA&utm_campaign=TORRELAGUNA-GOOGLE-MY-BUSINESS'}
# {'adr_address': '<span class="street-address">C. de Alcalá, 269</span>, <span '
#                 'class="postal-code">28027</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '913 26 16 20',
#  'geometry': {'location': {'lat': 40.4320781},
#               'viewport': {'southwest': {'lng': -3.657894430291502}}},
#  'name': 'Rafaelhoteles Ventas',
#  'place_id': 'ChIJDaRGeEkvQg0R8FVvVgPwPwc',
#  'rating': 4,
#  'user_ratings_total': 1145,
#  'website': 'https://www.rafaelhoteles.com/es/hoteles/madrid-ventas/hotel.html'}
# {'adr_address': '<span class="street-address">C. de Alcántara, 63</span>, '
#                 '<span class="postal-code">28006</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '914 01 16 50',
#  'geometry': {'location': {'lat': 40.4319527},
#               'viewport': {'southwest': {'lng': -3.674903330291502}}},
#  'name': 'Hotel Zenit Abeba',
#  'place_id': 'ChIJ7V4WN7goQg0RiblVWt36UTI',
#  'rating': 4.3,
#  'user_ratings_total': 1214,
#  'website': 'https://abeba.zenithoteles.com/'}
# {'adr_address': '<span class="street-address">C. de Ardemans, 13</span>, <span '
#                 'class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '689 35 75 33',
#  'geometry': {'location': {'lat': 40.433898},
#               'viewport': {'southwest': {'lng': -3.673186980291502}}},
#  'name': 'Homeabout Quo Eraso',
#  'place_id': 'ChIJTyJZ-7coQg0R1kf9vrbNO34',
#  'rating': 4,
#  'user_ratings_total': 337,
#  'website': 'https://www.aparthotelquoeraso.com/'}
# {'adr_address': '<span class="street-address">C. Biarritz, 2</span>, <span '
#                 'class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '913 61 02 88',
#  'geometry': {'location': {'lat': 40.435455},
#               'viewport': {'southwest': {'lng': -3.665213480291502}}},
#  'name': 'Hotel NH Madrid Ventas',
#  'place_id': 'ChIJj42WkcooQg0Rf9RBLoWoEIM',
#  'rating': 4.3,
#  'user_ratings_total': 2832,
#  'website': 'https://www.nh-hotels.com/hotel/nh-madrid-ventas?utm_campaign=local-gmb&utm_medium=organic_search&utm_source=google_gmb'}
# {'adr_address': '<span class="street-address">C/ de Francisco Silvela, '
#                 '30</span>, <span class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '914 17 57 05',
#  'geometry': {'location': {'lat': 40.4321534},
#               'viewport': {'southwest': {'lng': -3.673335180291502}}},
#  'name': 'Restaurante Milos - La Parrilla Griega',
#  'place_id': 'ChIJpR8EhbcoQg0RG-j_jBFhI0U',
#  'price_level': 2,
#  'rating': 4.1,
#  'user_ratings_total': 1138,
#  'website': 'https://restaurantemilos.es/'}
# {'adr_address': '<span class="street-address">C. de Ibiza, 42</span>, <span '
#                 'class="postal-code">28009</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '915 73 67 70',
#  'geometry': {'location': {'lat': 40.4179938},
#               'viewport': {'southwest': {'lng': -3.674869930291502}}},
#  'name': 'Restaurante Fathe Pur',
#  'place_id': 'ChIJHYoKE6YoQg0RIIc11zyCrcU',
#  'price_level': 2,
#  'rating': 4.3,
#  'user_ratings_total': 1167,
#  'website': 'https://losmejoresrestaurantesindios.com/fathe-pur'}
# {'adr_address': 'C Julio Camba, 1 Esquina, <span class="street-address">C. de '
#                 'Alcalá, 233</span>, <span class="postal-code">28028</span> '
#                 '<span class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '910 80 37 10',
#  'geometry': {'location': {'lat': 40.4305943},
#               'viewport': {'southwest': {'lng': -3.665523480291502}}},
#  'name': 'ibis Madrid Centro las Ventas',
#  'place_id': 'ChIJE2JOkrQoQg0Rz3_F_5VT1qU',
#  'rating': 4.2,
#  'user_ratings_total': 1706,
#  'website': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=7438&merchantid=seo-maps-ES-7438&sourceid=aw-cen&utm_medium=seo+maps&utm_source=google+Maps&utm_campaign=seo+maps&y_source=1_MTUzNjA3NDQtNzE1LWxvY2F0aW9uLndlYnNpdGU%3D'}
# {'adr_address': '<span class="street-address">Calle de Goya, 54</span>, <span '
#                 'class="postal-code">28001</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '915 77 50 35',
#  'geometry': {'location': {'lat': 40.42477109999999},
#               'viewport': {'southwest': {'lng': -3.679444480291503}}},
#  'name': 'Restaurante Tía María',
#  'place_id': 'ChIJn6OppLwoQg0RV-ZAEi31esA',
#  'price_level': 1,
#  'rating': 3.6,
#  'user_ratings_total': 767,
#  'website': 'https://www.casadelatiamaria.com/'}
# {'adr_address': '<span class="street-address">Calle de Goya, 79</span>, <span '
#                 'class="postal-code">28001</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '914 35 75 45',
#  'geometry': {'location': {'lat': 40.4250624},
#               'viewport': {'southwest': {'lng': -3.679498830291503}}},
#  'name': 'Hotel Vincci Soma',
#  'place_id': 'ChIJfegVorwoQg0RD5bq7YYEqdk',
#  'rating': 4.2,
#  'user_ratings_total': 1975,
#  'website': 'https://www.vinccisoma.com/'}
# {'adr_address': '<span class="street-address">C. de Azcona, 46</span>, <span '
#                 'class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '913 55 27 86',
#  'geometry': {'location': {'lat': 40.4346777},
#               'viewport': {'southwest': {'lng': -3.669780430291502}}},
#  'name': 'Los Montes de Galicia',
#  'place_id': 'ChIJkxzJ5skoQg0RDcLhWHmhX-s',
#  'price_level': 2,
#  'rating': 4.7,
#  'user_ratings_total': 5426,
#  'website': 'http://losmontesdegalicia.es/'}
# {'adr_address': '<span class="street-address">C. de Lope de Rueda, 4</span>, '
#                 '<span class="postal-code">28009</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '915 75 69 16',
#  'geometry': {'location': {'lat': 40.4236435},
#               'viewport': {'southwest': {'lng': -3.678759730291502}}},
#  'name': 'Horno de Juan',
#  'place_id': 'ChIJmxAcq6QoQg0RBo4baWSiVY8',
#  'price_level': 2,
#  'rating': 4.1,
#  'user_ratings_total': 652,
#  'website': 'http://www.hornodejuan.net/'}
# {'adr_address': 'Albacete, <span class="street-address">Av. de Badajoz, 1 '
#                 'Esquina</span>, <span class="postal-code">28027</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '917 24 76 00',
#  'geometry': {'location': {'lat': 40.441311},
#               'viewport': {'southwest': {'lng': -3.658554430291502}}},
#  'name': 'Novotel Madrid City Las Ventas',
#  'place_id': 'ChIJSd3b-TAvQg0RCJg4376KFaM',
#  'rating': 4.2,
#  'user_ratings_total': 2643,
#  'website': 'https://all.accor.com/lien_externe.svlt?goto=fiche_hotel&code_hotel=0843&merchantid=seo-maps-ES-0843&sourceid=aw-cen&utm_medium=seo+maps&utm_source=google+Maps&utm_campaign=seo+maps&y_source=1_MTUzNTgwODAtNzE1LWxvY2F0aW9uLndlYnNpdGU%3D'}
# {'adr_address': '<span class="street-address">Calle del Gral. Pardiñas, '
#                 '21</span>, BAJO, <span class="postal-code">28001</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '915 75 23 29',
#  'geometry': {'location': {'lat': 40.42632020000001},
#               'viewport': {'southwest': {'lng': -3.679944130291502}}},
#  'name': 'Taberna de la Daniela',
#  'place_id': 'ChIJAdDzirwoQg0RTO4ZOhuU4Pg',
#  'price_level': 2,
#  'rating': 4.1,
#  'user_ratings_total': 1593,
#  'website': 'http://www.tabernadeladaniela.com/'}
# {'adr_address': '<span class="street-address">C. de Cartagena, 83-85</span>, '
#                 '<span class="postal-code">28028</span> <span '
#                 'class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'formatted_phone_number': '917 24 42 40',
#  'geometry': {'location': {'lat': 40.4380379},
#               'viewport': {'southwest': {'lng': -3.673973530291502}}},
#  'name': 'AC Hotel by Marriott Avenida de America',
#  'place_id': 'ChIJu5GwH8YoQg0RlpW-RaREiv0',
#  'rating': 4.2,
#  'user_ratings_total': 1370,
#  'website': 'https://www.marriott.com/en-us/hotels/madav-ac-hotel-avenida-de-america/overview/?scid=f2ae0541-1279-4f24-b197-a979c79310b0'}
# {'adr_address': 'Ciudad Lineal, <span class="locality">Madrid</span>, <span '
#                 'class="country-name">Spain</span>',
#  'geometry': {'location': {'lat': 40.4456678},
#               'viewport': {'southwest': {'lng': -3.674342055294443}}},
#  'name': 'Ciudad Lineal',
#  'place_id': 'ChIJ0fSMdiQvQg0Rd6NnZEtZumk'}
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\vir_d\AppData\Local\Programs\Python\Python310\lib\site-packages\xlsxwriter\worksheet.py:512, in Worksheet._write(self, row, col, *args)
#     511 try:
# --> 512     f = float(token)
#     513     return self._write_number(row, col, f, *args[1:])
#
# TypeError: float() argument must be a string or a real number, not 'dict'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# matelms\Maps\Test Google Places API.ipynb Celda 2 in <cell line: 63>()
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W1sdnNjb2RlLXZmcw%3D%3D?line=67'>68</a> # loop through each value in the values component.
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W1sdnNjb2RlLXZmcw%3D%3D?line=68'>69</a> for value in result_values:
# ---> <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W1sdnNjb2RlLXZmcw%3D%3D?line=69'>70</a>     worksheet.write(row, col, value)
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W1sdnNjb2RlLXZmcw%3D%3D?line=70'>71</a>     col += 1
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W1sdnNjb2RlLXZmcw%3D%3D?line=72'>73</a> # make sure to go to the next row & reset the column.
#
# File c:\Users\vir_d\AppData\Local\Programs\Python\Python310\lib\site-packages\xlsxwriter\worksheet.py:85, in convert_cell_args.<locals>.cell_wrapper(self, *args, **kwargs)
#      82     new_args = xl_cell_to_rowcol(first_arg)
#      83     args = new_args + args[1:]
# ---> 85 return method(self, *args, **kwargs)
#
# File c:\Users\vir_d\AppData\Local\Programs\Python\Python310\lib\site-packages\xlsxwriter\worksheet.py:445, in Worksheet.write(self, row, col, *args)
#     428 @convert_cell_args
#     429 def write(self, row, col, *args):
#     430     """
#     431     Write data to a worksheet cell by calling the appropriate write_*()
#     432     method based on the type of data being passed.
#    (...)
#     443
#     444     """
# --> 445     return self._write(row, col, *args)
#
# File c:\Users\vir_d\AppData\Local\Programs\Python\Python310\lib\site-packages\xlsxwriter\worksheet.py:517, in Worksheet._write(self, row, col, *args)
#     515     pass
#     516 except TypeError:
# --> 517     raise TypeError("Unsupported type %s in write()" % type(token))
#     519 # Finally try string.
#     520 try:
#
# TypeError: Unsupported type <class 'dict'> in write()

# %%
# import the library
import googlemaps
import json
import pprint
import xlsxwriter
import time

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# Do a simple nearby search where we specify the location
# in lat/lon format, along with a radius measured in meters
places_result  = gmaps.places(query='Pizza, La elipa' )

time.sleep(3)

place_result  = gmaps.places(page_token = places_result['next_page_token'])

stored_results = []

# loop through each of the places in the results, and get the place details.      
for place in places_result['results']:

    # define the place id, needed to get place details. Formatted as a string.
    my_place_id = place['place_id']

    # define the fields you would liked return. Formatted as a list.
    my_fields = ['place_id','name','formatted_phone_number','website','rating','user_ratings_total','price_level','adr_address','geometry/location/lat','geometry/viewport/southwest/lng']

    # make a request for the details.
    places_details  = gmaps.place(place_id= my_place_id , fields= my_fields)

    # print the results of the details, returned as a dictionary.
    pprint.pprint(places_details['result'])

    # store the results in a list object.
    stored_results.append(places_details['result'])

stored_results
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# matelms\Maps\Test Google Places API.ipynb Celda 3 in <cell line: 20>()
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W2sdnNjb2RlLXZmcw%3D%3D?line=15'>16</a> places_result  = gmaps.places(query='Pizza, La elipa' )
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W2sdnNjb2RlLXZmcw%3D%3D?line=17'>18</a> time.sleep(3)
# ---> <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W2sdnNjb2RlLXZmcw%3D%3D?line=19'>20</a> place_result  = gmaps.places(page_token = places_result['next_page_token'])
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W2sdnNjb2RlLXZmcw%3D%3D?line=21'>22</a> stored_results = []
#      <a href='vscode-notebook-cell://github%2B7b2276223a312c22726566223a7b2274797065223a342c226964223a224d6170735f41505f646576656c6f706d656e7473227d7d/matelms/Maps/Test%20Google%20Places%20API.ipynb#W2sdnNjb2RlLXZmcw%3D%3D?line=23'>24</a> # loop through each of the places in the results, and get the place details.
#
# KeyError: 'next_page_token'

# %%
# import the library
import googlemaps
import json
import pprint
import xlsxwriter
import time

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# Do a simple nearby search where we specify the location
# in lat/lon format, along with a radius measured in meters
places_result  = gmaps.places(query='Hamburguesa, Noviciado, Madrid' )

time.sleep(3)

place_result  = gmaps.places(page_token = places_result['next_page_token'])

stored_results = []

# loop through each of the places in the results, and get the place details.      
for place in places_result['results']:

    # define the place id, needed to get place details. Formatted as a string.
    my_place_id = place['place_id']

    # define the fields you would liked return. Formatted as a list.
    my_fields = ['place_id','name',]

    # make a request for the details.
    places_details  = gmaps.place(place_id= my_place_id , fields= my_fields)

    # print the results of the details, returned as a dictionary.
    pprint.pprint(places_details['result'])

    # store the results in a list object.
    stored_results.append(places_details['result'])

stored_results

# -------------- DUMPING VALUES IN EXCEL -----------------------

# define the headers, that is just the key of each result dictionary.
row_headers = stored_results[0].keys()

# create a new workbook and a new worksheet.
workbook = xlsxwriter.Workbook(r'C:\Users\vir_d\Desktop\Luis\Cloned Git\Maps\data.xlsx')
worksheet = workbook.add_worksheet()

# populate the header row
col = 0
for header in row_headers:
    worksheet.write(0, col, header)
    col += 1

row = 1
col = 0
# populate the other rows

# get each result from the list.
for result in stored_results:

    # get the values from each result.
    result_values = result.values()

    # loop through each value in the values component.
    for value in result_values:
        worksheet.write(row, col, value)
        col += 1
    
    # make sure to go to the next row & reset the column.
    row += 1
    col = 0

# close the workbook
workbook.close()
# Out:
# {'name': 'Goiko', 'place_id': 'ChIJo_IdPmMoQg0Rc0_CIjfqd84'}
# {'name': 'Criminal burger', 'place_id': 'ChIJWdygQOMpQg0R5LkNL6r7KRo'}
# {'name': 'Hamburguesería Don Oso', 'place_id': 'ChIJRz32gEIoQg0RghOH7aX7riA'}
# {'name': "Chivuo's - San Bernardo", 'place_id': 'ChIJDfiYsEIpQg0RHP_vUDNuuZA'}
# {'name': 'Hamburguesería Don Oso', 'place_id': 'ChIJ1118vUMoQg0R4If-ChIffG4'}
# {'name': 'VICIO', 'place_id': 'ChIJAW0j-dIpQg0RCBsGZoKjss8'}
# {'name': 'Goiko', 'place_id': 'ChIJ1Zu9TG8oQg0RGg8A1C2dUWM'}
# {'name': 'Naif Madrid Burger&bar', 'place_id': 'ChIJ9-kdPogoQg0RYmgVlTWts1U'}
# {'name': 'Hamburguesa Nostra', 'place_id': 'ChIJU0cryn0oQg0Rlxj5UQn123I'}
# {'name': 'Milwaukee', 'place_id': 'ChIJD_4K0B4pQg0RJvurfkYF2zw'}
# {'name': 'Five Guys Gran Vía', 'place_id': 'ChIJGzX3_3woQg0RyGVge53P-m8'}
# {'name': "Juancho's BBQ (Mercado de San Antón)",
#  'place_id': 'ChIJIx56yFApQg0Rs3d4-tMT7Tw'}
# {'name': 'Goiko Grill', 'place_id': 'ChIJbyGlEoooQg0RinIyc9HsNKM'}
# {'name': 'Bululú Bar and Coffee', 'place_id': 'ChIJAQC0pGYoQg0RrMqWP4ZnvcQ'}
# {'name': 'SteakBurger Bar', 'place_id': 'ChIJj1OC7oYoQg0RZvKKm9dDdHw'}
# {'name': 'TGB - The Good Burger', 'place_id': 'ChIJMwRD_YYoQg0RKUDfgsEYXdo'}
# {'name': 'Makato’s Burger', 'place_id': 'ChIJN-XWvIMpQg0RAqK_jjfuhZo'}
# {'name': 'The Butlers Madrid', 'place_id': 'ChIJb9aIqrApQg0RL7frOFfQKgA'}
# {'name': "Carl's Jr", 'place_id': 'ChIJBTVDhXwoQg0RaO8X-AOJyLU'}
# {'name': 'Steakburger', 'place_id': 'ChIJoysFW4goQg0RXmzeEFsDvzQ'}

# %%
# import the library
import googlemaps
import json
import pprint
import xlsxwriter
import time

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# Do a simple nearby search where we specify the location
# in lat/lon format, along with a radius measured in meters
places_result  = gmaps.places(query='Restaurante, Sao Miguel, Azores' )

time.sleep(3)

#place_result  = gmaps.places(page_token = places_result['next_page_token'])
places_result
# 
#stored_results = []

# loop through each of the places in the results, and get the place details.      
#for place in places_result['results']:

    # define the place id, needed to get place details. Formatted as a string.
#    my_place_id = place['place_id']

    # define the fields you would liked return. Formatted as a list.
#    my_fields = [
        'business_status'
        ,'formatted_phone_number'#'geometry'
        ,'name'
        ,'place_id'
        ,'price_level'
        ,'rating'
        ,'user_ratings_total'
        ,'vicinity'
        ]#['place_id','name',]

    # make a request for the details.
    places_details  = gmaps.place(place_id= my_place_id , fields= my_fields)

    # print the results of the details, returned as a dictionary.
    pprint.pprint(places_details['result'])

    # store the results in a list object.
    stored_results.append(places_details['result'])

stored_results
# Out:
# " \nstored_results = []\n\n# loop through each of the places in the results, and get the place details.      \nfor place in places_result['results']:\n\n    # define the place id, needed to get place details. Formatted as a string.\n    my_place_id = place['place_id']\n\n    # define the fields you would liked return. Formatted as a list.\n    my_fields = [\n        'business_status'\n        ,'formatted_phone_number'#'geometry'\n        ,'name'\n        ,'place_id'\n        ,'price_level'\n        ,'rating'\n        ,'user_ratings_total'\n        ,'vicinity'\n        ]#['place_id','name',]\n\n    # make a request for the details.\n    places_details  = gmaps.place(place_id= my_place_id , fields= my_fields)\n\n    # print the results of the details, returned as a dictionary.\n    pprint.pprint(places_details['result'])\n\n    # store the results in a list object.\n    stored_results.append(places_details['result'])\n\nstored_results "

# %%
# import the library
import googlemaps
import json
import pprint
import xlsxwriter
import time

# Define the API Key.
API_KEY = 'AIzaSyAhlwCCNhis1CT_JiWMIThGN7DG2lhMMFY'

# Define the Client
gmaps = googlemaps.Client(key = API_KEY)

# Do a simple nearby search where we specify the location
# in lat/lon format, along with a radius measured in meters
places_result  = gmaps.places(query='Restaurante, Sao Miguel, Azores' )

time.sleep(3)

#place_result  = gmaps.places(page_token = places_result['next_page_token'])
places_result
# Out:
# {'html_attributions': [],
#  'next_page_token': 'AW30NDwWWbne-hRNBIPKJOGtuHyA5LZROIkVFkTFfcl47XGKLSzELAUE1_eoPmc1UeS76LKN5jzSzRN_b_RMg85alSaMuQ8KiPRH9g_xgV8MWUNVrn66UZgmrA45aJKcne16B3dttCohM_6dwj9ZzLWWhMkZiSWz-1CY0P9VcVYVyYK02AqozXj7cHc5k7bg_62C9OYiWth6BdY0z4Gdrf-ChDf6NSVRs-2ccflvlyNKGURuyppCZaJQHpIKCL0YEmNBlgvRVINcT6kadOQyru3loL06JKGOR4Q1mmTKOAp_X84rqOwSs9Ru1Pcrsls2kRkFXQBISr6bOcZdIK5uKiLpVP4jJ_rQnmBv6e_vErG1jAaU9DpYj0gvEyXiEK9LwffdSmy2MCfqnnrJYou-_xzIl7GETLaFDyZKqy-EO9E',
#  'results': [{'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. Hintze Ribeiro 5, 9500-049 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7403576, 'lng': -25.6684053},
#     'viewport': {'northeast': {'lat': 37.74171222989272,
#       'lng': -25.66703982010728},
#      'southwest': {'lat': 37.73901257010728, 'lng': -25.66973947989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Õtaka',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101646977381815059636">Rocco Gisonno</a>'],
#      'photo_reference': 'AW30NDwiudOs_mA-w31apOyIK75xW6VZumqaGvWrA6AnpH_NjwJSO5nUvSqHC0Soen9RsE6Rf53wwrCse88mr1WfxWEnTMlLbDhtjb6Sm8UjtC_cdeVjL0H3pZRB_gZb9IgYCtE6JIxtLqefN5ewqpE_Z_0Wzfw-GrxYIU-zxXoTUi5fpXoy',
#      'width': 4032}],
#    'place_id': 'ChIJ172MAMoqQwsRz0S4fDB7Z-8',
#    'plus_code': {'compound_code': 'P8RJ+4J Ponta Delgada, Portugal',
#     'global_code': '899PP8RJ+4J'},
#    'price_level': 3,
#    'rating': 4.8,
#    'reference': 'ChIJ172MAMoqQwsRz0S4fDB7Z-8',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 594},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Rua Engº José Cordeiro Antiga da Calheta 55, 9500-311 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7426613, 'lng': -25.6585805},
#     'viewport': {'northeast': {'lat': 37.74397257989272,
#       'lng': -25.65721462010728},
#      'southwest': {'lat': 37.74127292010728, 'lng': -25.65991427989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Michel Restaurant',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112251430629974786949">Leonardo da Ponte</a>'],
#      'photo_reference': 'AW30NDzpC7oPa4IwEOgQNAvmC76-ETfL4TPCsW-fzdHmUNf7UQqHIJtsDeO7NOvdA3zVfV8WiAB4-Cude31uSKSCQ3d75KeAUM5x-HQVrCE0SGmjK_Mt84JL6cHKrmlWYFf2lsee59sbXn5hsmIN-Hp5dMZ3_QR0wBy1LNfLmBa4qFYI7kKi',
#      'width': 4032}],
#    'place_id': 'ChIJz1V2o0nVXAsR8bHcG_1YOd0',
#    'plus_code': {'compound_code': 'P8VR+3H Ponta Delgada, Portugal',
#     'global_code': '899PP8VR+3H'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJz1V2o0nVXAsR8bHcG_1YOd0',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 587},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. do Aljube 16, 9500-018 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.74097, 'lng': -25.6674014},
#     'viewport': {'northeast': {'lat': 37.74228587989272,
#       'lng': -25.66604032010728},
#      'southwest': {'lat': 37.73958622010728, 'lng': -25.66873997989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'A Tasca',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2268,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114509123850134129670">Easy2You Invenções C.F.</a>'],
#      'photo_reference': 'AW30NDw5SA0TMrFaCLRxbu8KkS29KgtmTbi-omJzoHfqoEGHx-nNUg0D8eJwjJ9-d5erQVuQIPlRY6T2VSZzu05oJWTm_d7KTzuhHu4Y3C6E5kBTimj1Dg4qDijBgWnlixDdlt-lPuHNpSP1HnZC9-U9MW9Y_Rxa8or87V7abQ423ByxzDHg',
#      'width': 4032}],
#    'place_id': 'ChIJgXv_CsoqQwsRxyxX6XfRAD4',
#    'plus_code': {'compound_code': 'P8RM+93 Ponta Delgada, Portugal',
#     'global_code': '899PP8RM+93'},
#    'price_level': 2,
#    'rating': 4.4,
#    'reference': 'ChIJgXv_CsoqQwsRxyxX6XfRAD4',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 6751},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': '9600-151 Rabo de Peixe, Portugal',
#    'geometry': {'location': {'lat': 37.7917594, 'lng': -25.5833358},
#     'viewport': {'northeast': {'lat': 37.79307737989272,
#       'lng': -25.58196852010727},
#      'southwest': {'lat': 37.79037772010728, 'lng': -25.58466817989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Quinta dos Sabores',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108837402083129950896">Judy Yang</a>'],
#      'photo_reference': 'AW30NDw1C7uJBeZbeSAjB8fBdpck2B7D2-jwVF48eAmMGEdaNp44kMN9AhogI4Kk6AytbIJPNoEUtZbFc9SUS9iOIzNeFk_SjPZMZqQgcS2qfYXgDiTUpKP80azKy9Qp4ME_5-UpH7lhzEicm97JekYQlW3OKaEihMTDdQpAMKBYqFa61J6y',
#      'width': 3024}],
#    'place_id': 'ChIJc7giXDrUXAsRZfVO1wxWNHM',
#    'plus_code': {'compound_code': 'QCR8+PM Rabo de Peixe, Portugal',
#     'global_code': '899PQCR8+PM'},
#    'price_level': 2,
#    'rating': 4.8,
#    'reference': 'ChIJc7giXDrUXAsRZfVO1wxWNHM',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 348},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. da Boa Nova, 9500-296 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.742729, 'lng': -25.6536899},
#     'viewport': {'northeast': {'lat': 37.74406577989272,
#       'lng': -25.65233617010728},
#      'southwest': {'lat': 37.74136612010728, 'lng': -25.65503582989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Gastrónomo',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3882,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103151855341692473665">Paulo Cunha</a>'],
#      'photo_reference': 'AW30NDxOzLZs4ICEapGJkce-EWT7uLohFWy1mTSYKGWCnbHKT9fhMWXdJJwtzlhCbf5NZJPfj3FzRXPn4TEVVqOpHP8oJMFg83UW5HU-tUFqXk43J0YGBbQS9CFhv-9ITlnoewPAmy0O_SqZZg2KiC8vD_qzT4f8UMAYOKwAWw97OvHXqUlo',
#      'width': 6324}],
#    'place_id': 'ChIJkUvDSkjVXAsRQ1A9-KLcoq0',
#    'plus_code': {'compound_code': 'P8VW+3G Ponta Delgada, Portugal',
#     'global_code': '899PP8VW+3G'},
#    'price_level': 2,
#    'rating': 4.7,
#    'reference': 'ChIJkUvDSkjVXAsRQ1A9-KLcoq0',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 1336},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Campo Do Santana, Recinto Da Feira Rabo de Peixe 37.808820, -25.565567, 9600-096 Ribeira Grande, Portugal',
#    'geometry': {'location': {'lat': 37.808864, 'lng': -25.5652942},
#     'viewport': {'northeast': {'lat': 37.81010867989272,
#       'lng': -25.56401107010728},
#      'southwest': {'lat': 37.80740902010727, 'lng': -25.56671072989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Associação Agrícola de São Miguel',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5472,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/113968276867712495786">Nuno Martins</a>'],
#      'photo_reference': 'AW30NDxZ4ObbfBsNfpnvdZRvVCjMpLCHq4IX28OHH1Fwf293rIzKP5VD8MpNJeYf0lUI1Vbeo3QiEJHmPb2b4If6ZFl_3L8vdWkFQL5Zf0YuqHA7bRLh0jflc6ECRIEF8EI_DnItFluuoW-TnVdziy5P1KLvbWnEnZm9MxAkJ_QBzlZi2qIs',
#      'width': 7296}],
#    'place_id': 'ChIJ2VSABKHWXAsRIrbODPhOHqU',
#    'plus_code': {'compound_code': 'RC5M+GV Ribeira Grande, Portugal',
#     'global_code': '899PRC5M+GV'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJ2VSABKHWXAsRIrbODPhOHqU',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 9954},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. Hintze Ribeiro 67, 9500-049 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.741015, 'lng': -25.6687005},
#     'viewport': {'northeast': {'lat': 37.74236207989272,
#       'lng': -25.66735867010728},
#      'southwest': {'lat': 37.73966242010728, 'lng': -25.67005832989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante Alcides',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3366,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/110341285685638070931">Magnus Michael</a>'],
#      'photo_reference': 'AW30NDyvEeeuf81IVuAG0vIRNhwSUPaLL-Nh6dvxuL-RgPTFgIriEY5n00VBRTBDXHaHTQ8DDUXj1vz3L8bIKXkmaFgCWJ8x7_1m5hQUq-bD4lIlD9tK0UYuKxbc7YS6ECschG9x041UaZT2ZhMyXNyzoiKnhG5tV6RHyZRBmflgJKBDZb1d',
#      'width': 5984}],
#    'place_id': 'ChIJ5x3WA8oqQwsRkuE4uMxhWgw',
#    'plus_code': {'compound_code': 'P8RJ+CG Ponta Delgada, Portugal',
#     'global_code': '899PP8RJ+CG'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJ5x3WA8oqQwsRkuE4uMxhWgw',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 1037},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Rua Nossa Senhora das Necessidades 30, Atalhada, 9560-418 Lagoa, Portugal',
#    'geometry': {'location': {'lat': 37.7452184, 'lng': -25.5915361},
#     'viewport': {'northeast': {'lat': 37.74658772989272,
#       'lng': -25.59019522010728},
#      'southwest': {'lat': 37.74388807010728, 'lng': -25.59289487989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante José do Rego',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3904,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/114509123850134129670">Easy2You Invenções C.F.</a>'],
#      'photo_reference': 'AW30NDwTlRkfnF_zdF5KONTEuK9v0FoHgjvv5zGFgtX1J8t5kMlBU1UKNIEgA_ZsZv_KQULcwTBym52i3x6x946vgNyQl_LnXjKoE32whe7aVWJY9u8Jj4ZF5jD-Dk2AWpPzrGktlUvie99HLZE3auMsgBhQb1t4XxBIqrA8JbaGWaKd-WLI',
#      'width': 5760}],
#    'place_id': 'ChIJm-TzM_PVXAsRVfy6t2YjJz4',
#    'plus_code': {'compound_code': 'PCW5+39 Lagoa, Portugal',
#     'global_code': '899PPCW5+39'},
#    'price_level': 2,
#    'rating': 4.1,
#    'reference': 'ChIJm-TzM_PVXAsRVfy6t2YjJz4',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 1228},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. da Praia dos Santos 61, Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7450723, 'lng': -25.6447203},
#     'viewport': {'northeast': {'lat': 37.74649547989272,
#       'lng': -25.64341502010728},
#      'southwest': {'lat': 37.74379582010728, 'lng': -25.64611467989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante Mariserra',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4032,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/115776630510326365891">A Google User</a>'],
#      'photo_reference': 'AW30NDyzKQu1Y3gpGsuqsizJegUG4OIgiZqSehTYQWn9TbSbEal9afGIh4MqqH44vfIpdgDnm1JctoptBfDO1HZy-hBMdEoxrRLU04TEDmtnWFmbqERP06OFjWpl-ue3h9SNmyH5D4oCPxoQC2kEa4CSDptcpTRH6Rmtq8PdQsjSVNEG7JlR',
#      'width': 3024}],
#    'place_id': 'ChIJodTzNkfVXAsRnfFGNElf6Kc',
#    'plus_code': {'compound_code': 'P9W4+24 Ponta Delgada, Portugal',
#     'global_code': '899PP9W4+24'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJodTzNkfVXAsRnfFGNElf6Kc',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 1568},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. Nova 50, Relva, Portugal',
#    'geometry': {'location': {'lat': 37.7501746, 'lng': -25.7158104},
#     'viewport': {'northeast': {'lat': 37.75149807989271,
#       'lng': -25.71448377010728},
#      'southwest': {'lat': 37.74879842010727, 'lng': -25.71718342989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Saca-Rolhas Taberna',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4608,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/105046666581926094945">Susana Santos</a>'],
#      'photo_reference': 'AW30NDylw34g0rt7srmslQLJbxhUaFPHBqXrhxNXf6neyQUWbsKOSkJJs21pCDOsBfqw9nlYaHWCn4GZmAbzi83y7Fm2T8MQ8iiMV-8bEn3hDi3mbGBdnC7KCaZr5okH2ujqAAu_Y0BbjQ9p6LxO71pByCHZABxdkBppsumMKgLq3E85ISY',
#      'width': 3456}],
#    'place_id': 'ChIJtf5bV6srQwsRKpI8OuIHM2A',
#    'plus_code': {'compound_code': 'Q72M+3M Relva, Portugal',
#     'global_code': '899PQ72M+3M'},
#    'price_level': 3,
#    'rating': 4.5,
#    'reference': 'ChIJtf5bV6srQwsRKpI8OuIHM2A',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 847},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Bairro da Praia dos Santos 21, 9500-706 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7446708, 'lng': -25.6464443},
#     'viewport': {'northeast': {'lat': 37.74601777989272,
#       'lng': -25.64510317010728},
#      'southwest': {'lat': 37.74331812010728, 'lng': -25.64780282989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'O Galego',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 4640,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/104926697198871917978">Julien Bourzac</a>'],
#      'photo_reference': 'AW30NDwpOgloD1fZ7bRVbEF8fP2Jvos4D2bb0wZ2CplJrp1pJUvyieIQhdXIfQlwt8mpyW3qh8KgmMpPsITTiiPaEzv8v3xl1ShNMmSb4LJbCvYUHL_2m4EQewbvB66J2L9EezRHcBQLoay_u0wpyelp6t14OT3R9NaOLIe4V63ddc7NRqJ2',
#      'width': 3480}],
#    'place_id': 'ChIJsyWJQEfVXAsRyWBbjtu-Yl8',
#    'plus_code': {'compound_code': 'P9V3+VC Ponta Delgada, Portugal',
#     'global_code': '899PP9V3+VC'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJsyWJQEfVXAsRyWBbjtu-Yl8',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 2474},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Rua Engenheiro José Cordeiro, 127, Ponta Delgada, Ilha De São Miguel, Portugal',
#    'geometry': {'location': {'lat': 37.742348, 'lng': -25.655866},
#     'viewport': {'northeast': {'lat': 37.74369892989272,
#       'lng': -25.65447182010728},
#      'southwest': {'lat': 37.74099927010727, 'lng': -25.65717147989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Casa Marisca',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117459887300662678813">Rui Ferreira</a>'],
#      'photo_reference': 'AW30NDw5wSl66X-hWeJxuwgfL1QvHb9R8tfm34d8Z-Xg-6PJLByorQA1hIA8ouQtYZTgqsqdaYx1CX-dYJGt8yYBWEc71KtUYU7gKD2hm2j49RMxHKLxGtjYireAcKIPKTNQLBkA7ko600P-sEttKks2DTFhjd9cbckCzFR4S1AhJpupZ3nP',
#      'width': 5312}],
#    'place_id': 'ChIJS6FOk0nVXAsRa_SNw5ijR1k',
#    'plus_code': {'compound_code': 'P8RV+WM Ponta Delgada, Portugal',
#     'global_code': '899PP8RV+WM'},
#    'price_level': 2,
#    'rating': 4.2,
#    'reference': 'ChIJS6FOk0nVXAsRa_SNw5ijR1k',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 736},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Rua da Caloura, 20, 9560-211 Água de Pau, Portugal',
#    'geometry': {'location': {'lat': 37.7137819, 'lng': -25.4960382},
#     'viewport': {'northeast': {'lat': 37.71517287989273,
#       'lng': -25.49471332010727},
#      'southwest': {'lat': 37.71247322010728, 'lng': -25.49741297989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Bar Caloura',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 2160,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/108694501118882866118">Yuri Barseghyan</a>'],
#      'photo_reference': 'AW30NDx_jZyBov6dQPfg0tWCDtEgXiHeDMUKl52DNgGZ7zIRoSa7RhrVg1jlVDW2Pf_WVPEAURmd0c1hhIYY689OygAfhxJkJ8cJz7utENc4OPDdCkXXCPT_XVrpcifU8GOauXK1B6PIHgC_g3fZB5MRR5knNYCIFSqjDW4NTRx4koTjNY8s',
#      'width': 3840}],
#    'place_id': 'ChIJPSm-2IwoXQsRGR0JPFEhR4o',
#    'plus_code': {'compound_code': 'PG73+GH Agua de Pau, Portugal',
#     'global_code': '899PPG73+GH'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJPSm-2IwoXQsRGR0JPFEhR4o',
#    'types': ['restaurant',
#     'bar',
#     'point_of_interest',
#     'food',
#     'establishment'],
#    'user_ratings_total': 4633},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Restaurante Ramires Galerias das Portas do Mar, Av. Infante Dom Henrique, 9500-770 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7388725, 'lng': -25.662321},
#     'viewport': {'northeast': {'lat': 37.74076682989272,
#       'lng': -25.66129847010728},
#      'southwest': {'lat': 37.73806717010728, 'lng': -25.66399812989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Ramires',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/118170138674965517205">Rodrigo Freitas</a>'],
#      'photo_reference': 'AW30NDxfaCjL2HD_mE69L8gq-iB43HJo_8UMRuG34mhTZtKFUW8GQem_1gG-ax4AsBWclUyNOtX_Cbfpv4G8u2cdGQPq9BcvDwwvCgOkYBB9UffIzNn7cALIYbja4OC1S2UqjwtosjPmqYOp-7rEVpn89eCNRrF2e2k2I4w8LMIjN5Xgk6-B',
#      'width': 4032}],
#    'place_id': 'ChIJVX73MEvVXAsR0gxHJSXWGzM',
#    'plus_code': {'compound_code': 'P8QQ+G3 Ponta Delgada, Portugal',
#     'global_code': '899PP8QQ+G3'},
#    'price_level': 2,
#    'rating': 4.3,
#    'reference': 'ChIJVX73MEvVXAsR0gxHJSXWGzM',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 672},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'rua caminho fundo n 20, 9630-049 Achadinha, Portugal',
#    'geometry': {'location': {'lat': 37.8540598, 'lng': -25.2819026},
#     'viewport': {'northeast': {'lat': 37.85539157989272,
#       'lng': -25.28053537010728},
#      'southwest': {'lat': 37.85269192010728, 'lng': -25.28323502989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Os Melos Restaurante',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3456,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/109424705113358811727">Osvaldo Janeiro</a>'],
#      'photo_reference': 'AW30NDzTmkx-T_O996WtdmuxgOba4xg8vq7TWvYir5q3aGrE7LDZolrRQIEWrG7YRvfocN4dDA2iAIMYWwA8PdcREoKsLR8XGnfNRob0OH50u4fMw74qRSob1CeNlM41EJBEZUv7GhwUdZhrbGgQv9BSY2sD-I0soIxo5wFBjxJKtsNKd3tG',
#      'width': 4608}],
#    'place_id': 'ChIJgacgkoHgXAsRxqGYMEMuiFs',
#    'plus_code': {'compound_code': 'VP39+J6 Achadinha, Portugal',
#     'global_code': '899PVP39+J6'},
#    'price_level': 1,
#    'rating': 4.5,
#    'reference': 'ChIJgacgkoHgXAsRxqGYMEMuiFs',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 1034},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. João Francisco Cabral 49C, 9500-208 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.73790270000001, 'lng': -25.6755427},
#     'viewport': {'northeast': {'lat': 37.73924772989272,
#       'lng': -25.67421007010728},
#      'southwest': {'lat': 37.73654807010728, 'lng': -25.67690972989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Restaurante O Baco',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3840,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103741672933269271956">A Google User</a>'],
#      'photo_reference': 'AW30NDyQY9aY0h0pUZeez2U83v3124GDJSa5iVJdLzpBErQQfcOuVghcxfhQQJcZl1p-yX-kLPovWtFSlR1bsW8z0UFacXbwM0iaLQ3RYQql3FinTgENEYAbuQPu4V1ubSzTeqburLhZVXV4W6lTxnKGEc-MRLR40uxEJuZAdJyH3l7Op3VR',
#      'width': 5760}],
#    'place_id': 'ChIJ95a6F7gqQwsR6aBfhB-_kkY',
#    'plus_code': {'compound_code': 'P8QF+5Q Ponta Delgada, Portugal',
#     'global_code': '899PP8QF+5Q'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJ95a6F7gqQwsR6aBfhB-_kkY',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 419},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Rua António Joaquim Nunes da Silva 21, 9500-056 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.74106510000001, 'lng': -25.6669121},
#     'viewport': {'northeast': {'lat': 37.74240517989273,
#       'lng': -25.66551967010728},
#      'southwest': {'lat': 37.73970552010728, 'lng': -25.66821932989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Tasquinha Vieira',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 2988,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/101647693624828809245">Joao Pires - PLEXUS</a>'],
#      'photo_reference': 'AW30NDxq5JLKhF9MiOt248jcXqnaG4kNR6xyJ2zbQ99bemcIUnnqKtvZZXz69F0PeN2fTMKT0RI-Cmk3kmTj3aNeL8QzCIg8SbBOV0hZbgcTYNwGj3UHwaIJ50WhDY6cZ03LteqZd7QhewAMBlZasdSkqjQvUwwZE2r3-w8_GEruPg44FwYu',
#      'width': 5312}],
#    'place_id': 'ChIJv7UDdsoqQwsR3jbZXHKHMx4',
#    'plus_code': {'compound_code': 'P8RM+C6 Ponta Delgada, Portugal',
#     'global_code': '899PP8RM+C6'},
#    'price_level': 2,
#    'rating': 4.6,
#    'reference': 'ChIJv7UDdsoqQwsR3jbZXHKHMx4',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 734},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. de São João 4, 9500-105 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7416066, 'lng': -25.6653862},
#     'viewport': {'northeast': {'lat': 37.74293377989272,
#       'lng': -25.66408317010728},
#      'southwest': {'lat': 37.74023412010728, 'lng': -25.66678282989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Boca de Cena',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 3024,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/117920582211956312197">Sérgio Ramos</a>'],
#      'photo_reference': 'AW30NDxdZlrI6KVYAtxEdBCnIMg-ubNN91j8atrUUFAZowxEYDt0SS21OXN_h-G6-dsW2cG5dZUAhPZfQd5DeZNZzo9EyKTtzgk4LF0_W9sUX0slAGISGpZJlpBFTQNteTPFWEdWjMgdGxPWRymrowRcZHgwAyxtC8GgtkxhLFv6vYKu0YRO',
#      'width': 4032}],
#    'place_id': 'ChIJS24fgcoqQwsRUIaiNGacqq8',
#    'plus_code': {'compound_code': 'P8RM+JR Ponta Delgada, Portugal',
#     'global_code': '899PP8RM+JR'},
#    'price_level': 2,
#    'rating': 4.5,
#    'reference': 'ChIJS24fgcoqQwsRUIaiNGacqq8',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 456},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'R. de Pedro Homem 49, 9500-099 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.7422238, 'lng': -25.6690479},
#     'viewport': {'northeast': {'lat': 37.74357607989272,
#       'lng': -25.66768422010728},
#      'southwest': {'lat': 37.74087642010728, 'lng': -25.67038387989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Rotas da Ilha Verde',
#    'opening_hours': {'open_now': True},
#    'photos': [{'height': 5312,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/112705568295563581479">Danubis 666</a>'],
#      'photo_reference': 'AW30NDxb1flubbR32r7gVeks2gttKI5sXmE7BepKFlW-IKJzouKBu3yYzl62YeSKWoX_1yN12TqYPpYqNmAwK1P9Z8jZmSK-xgkbxfquekrhRkni1wa4AWfWSFactx2IV1Ba7fCdsmrgC6ri0wLcWcEg9ES9GEFneKtuzFnod6tepi5dPlP0',
#      'width': 2988}],
#    'place_id': 'ChIJlUxq9skqQwsR1cP_cS5H_R8',
#    'plus_code': {'compound_code': 'P8RJ+V9 Ponta Delgada, Portugal',
#     'global_code': '899PP8RJ+V9'},
#    'price_level': 2,
#    'rating': 4.8,
#    'reference': 'ChIJlUxq9skqQwsR1cP_cS5H_R8',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 937},
#   {'business_status': 'OPERATIONAL',
#    'formatted_address': 'Av. Infante Dom Henrique 113, 9500-150 Ponta Delgada, Portugal',
#    'geometry': {'location': {'lat': 37.74038, 'lng': -25.6618625},
#     'viewport': {'northeast': {'lat': 37.74170172989273,
#       'lng': -25.66048917010728},
#      'southwest': {'lat': 37.73900207010728, 'lng': -25.66318882989272}}},
#    'icon': 'https://maps.gstatic.com/mapfiles/place_api/icons/v1/png_71/restaurant-71.png',
#    'icon_background_color': '#FF9E67',
#    'icon_mask_base_uri': 'https://maps.gstatic.com/mapfiles/place_api/icons/v2/restaurant_pinlet',
#    'name': 'Balcony Restaurant',
#    'opening_hours': {'open_now': False},
#    'photos': [{'height': 1280,
#      'html_attributions': ['<a href="https://maps.google.com/maps/contrib/103195116215469508709">A Google User</a>'],
#      'photo_reference': 'AW30NDwvmQgB0LzkeBwBxkMBOkQ0o0LZfc8_4_j8OnTogsTcnNbTdYrqCF3EcDgLnW6TLuP4IEWhH0djpvXw-oKR93Pkzak2BCgMfqLwVXp9EiamcU3rUp5rILN_fFiqze6J3KPuDKIEaskeBhZ8UuBKCuTo9BYdfeaKjsnKTUv6h4sB3URc',
#      'width': 1920}],
#    'place_id': 'ChIJZbT9ZWTVXAsRggrlYclCo0Q',
#    'plus_code': {'compound_code': 'P8RQ+57 Ponta Delgada, Portugal',
#     'global_code': '899PP8RQ+57'},
#    'rating': 4.4,
#    'reference': 'ChIJZbT9ZWTVXAsRggrlYclCo0Q',
#    'types': ['restaurant', 'point_of_interest', 'food', 'establishment'],
#    'user_ratings_total': 68}],
#  'status': 'OK'}

# %%
import pandas as pd
df=pd.DataFrame(stored_results)
df
# Out:
#    business_status                                     name  \
# 0      OPERATIONAL                       Quinta dos Sabores
# 1      OPERATIONAL                                  A Tasca
# 2      OPERATIONAL                                    Õtaka
# 3      OPERATIONAL                        Michel Restaurant
# 4      OPERATIONAL  Louvre Michaelense Bar Bistro Mercearia
# 5      OPERATIONAL             Restaurante Ponta do Garajau
# 6      OPERATIONAL                               Gastrónomo
# 7      OPERATIONAL                      Restaurante Alcides
# 8      OPERATIONAL        Associação Agrícola de São Miguel
# 9      OPERATIONAL                                 O Galego
# 10     OPERATIONAL                                  Ramires
# 11     OPERATIONAL                              Bar Caloura
# 12     OPERATIONAL                    Restaurante Mariserra
# 13     OPERATIONAL                      Saca-Rolhas Taberna
# 14     OPERATIONAL                       Restaurante O Baco
# 15     OPERATIONAL                 Restaurante José do Rego
# 16     OPERATIONAL                       Balcony Restaurant
# 17     OPERATIONAL                         Tasquinha Vieira
# 18     OPERATIONAL         Sunset Beach - Restaurante & Bar
# 19     OPERATIONAL                     Os Melos Restaurante
#
#                        place_id  price_level  rating  user_ratings_total  \
# 0   ChIJc7giXDrUXAsRZfVO1wxWNHM          2.0     4.8                 332
# 1   ChIJgXv_CsoqQwsRxyxX6XfRAD4          2.0     4.4                6448
# 2   ChIJ172MAMoqQwsRz0S4fDB7Z-8          3.0     4.8                 569
# 3   ChIJz1V2o0nVXAsR8bHcG_1YOd0          2.0     4.7                 536
# 4   ChIJOW8P_rUqQwsRCO68QGnYG5M          2.0     4.6                1753
# 5   ChIJHefV0_EhXQsROwCckLkoqjs          NaN     4.6                1004
# 6   ChIJkUvDSkjVXAsRQ1A9-KLcoq0          2.0     4.7                1271
# 7   ChIJ5x3WA8oqQwsRkuE4uMxhWgw          2.0     4.4                 991
# 8   ChIJ2VSABKHWXAsRIrbODPhOHqU          2.0     4.6                9646
# 9   ChIJsyWJQEfVXAsRyWBbjtu-Yl8          2.0     4.6                2342
# 10  ChIJVX73MEvVXAsR0gxHJSXWGzM          2.0     4.3                 655
# 11  ChIJPSm-2IwoXQsRGR0JPFEhR4o          2.0     4.6                4452
# 12  ChIJodTzNkfVXAsRnfFGNElf6Kc          2.0     4.2                1527
# 13  ChIJtf5bV6srQwsRKpI8OuIHM2A          3.0     4.5                 819
# 14  ChIJ95a6F7gqQwsR6aBfhB-_kkY          2.0     4.5                 390
# 15  ChIJm-TzM_PVXAsRVfy6t2YjJz4          2.0     4.1                1190
# 16  ChIJZbT9ZWTVXAsRggrlYclCo0Q          NaN     4.4                  58
# 17  ChIJv7UDdsoqQwsR3jbZXHKHMx4          2.0     4.6                 705
# 18  ChIJb5wnHHXVXAsR29f5sf0bQS8          2.0     4.3                1333
# 19  ChIJgacgkoHgXAsRxqGYMEMuiFs          1.0     4.5                 978
#
#                                              vicinity
# 0                                          São Miguel
# 1                     Rua do Aljube 16, Ponta Delgada
# 2                 Rua Hintze Ribeiro 5, Ponta Delgada
# 3   Rua Engº José Cordeiro Antiga da Calheta 55, P...
# 4         Rua António José D'Almeida 8, Ponta Delgada
# 5   Rua Doutor Frederico Moniz Pereira 9, Ribeira ...
# 6                      Rua da Boa Nova, Ponta Delgada
# 7                Rua Hintze Ribeiro 67, Ponta Delgada
# 8   Campo Do Santana, Recinto Da Feira Rabo de Pei...
# 9        Bairro da Praia dos Santos 21, Ponta Delgada
# 10  Restaurante Ramires Galerias das Portas do Mar...
# 11                    Rua da Caloura, 20, Água de Pau
# 12          Rua da Praia dos Santos 61, Ponta Delgada
# 13                                 Rua Nova 50, Relva
# 14       Rua João Francisco Cabral 49C, Ponta Delgada
# 15  Rua Nossa Senhora das Necessidades 30, Atalhad...
# 16    Avenida Infante Dom Henrique 113, Ponta Delgada
# 17  Rua António Joaquim Nunes da Silva 21, Ponta D...
# 18          Estrada Regional do Pópulo, Ponta Delgada
# 19                  rua caminho fundo n 20, Achadinha
